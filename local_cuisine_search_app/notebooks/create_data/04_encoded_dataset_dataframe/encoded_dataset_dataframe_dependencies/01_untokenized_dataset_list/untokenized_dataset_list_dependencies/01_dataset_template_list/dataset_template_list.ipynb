# %% [markdown]
# # import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from typing import List, Dict, Tuple
import random
import pandas as pd

import sys
sys.path.append('/content/drive/MyDrive/local_cuisine_search_app/modules')

from utility import dump_obj_as_json, RandomPicker

# %% [markdown]
# # 関数とクラスの定義

# %%
def create_and_save(
        sos_df_path: str, eos_df_path: str, file_name: str, save_dir: str
) -> List[str]:
    """
    データセットのテンプレートの作成と保存

    Parameters
    ----------
    sos_df_path : str
        文頭表現のデータフレームが保存されているパス
    eos_df_path : str
        文末表現のデータフレームが保存されているパス
    file_name : str
        保存するデータセットテンプレートのファイル名
    save_dir : str
        データセットテンプレートの保存先ディレクトリ

    Returns
    -------
    List[str]
        データセットテンプレート
    """
    sos_df = pd.read_csv(sos_df_path)
    templates_maker = TemplatesMaker(eos_df_path, sos_df)

    templates = []
    random.seed(42)
    sos_df.apply(
        templates_maker.extend_templates,
        args=(templates,),
        axis=1
    )

    dump_obj_as_json(templates, file_name, save_dir)

    return templates


class TemplatesMaker:
    """
    テンプレート作成用クラス

    Attributes
    ----------
    _almighty_class : str
        全てのクラスの文末表現に繋がるクラス
    _class_col : str
        文末表現データフレームのクラス列の列名
    _eos_col : str
        文末表現データフレームの文末表現列の列名
    _eos_df : pd.DataFrame
        文末表現データフレーム
    _pickers : Dict[str, RandomPicker]
        文末表現のクラスと、クラスに応じた文末表現のRandomPickerの辞書
    """
    _almighty_class = 'almighty'
    _class_col = 'class'
    _eos_col = '文末表現'

    def __init__(self, eos_df_path: str, sos_df: pd.DataFrame):
        """
        コンストラクタ

        _eos_df、_pickersの作成と、文頭表現、文末表現のクラスのチェックを行う

        Parameters
        ----------
        eos_df_path : str
            文末表現データフレームが保存されているパス
        sos_df : pd.DataFrame
            文頭表現データフレーム
        """
        self._eos_df = TemplatesMaker._create_eos_df(eos_df_path)
        eos_classes = TemplatesMaker._create_classes(self._eos_df)

        TemplatesMaker._check_sos_and_eos_classes(sos_df, eos_classes)

        self._pickers = self._create_pickers(eos_classes)

    @staticmethod
    def _create_eos_df(eos_df_path: str) -> pd.DataFrame:
        """
        文末表現データフレームの作成

        Parameters
        ----------
        eos_df_path : str
            文末表現データフレームが保存されているパス

        Returns
        -------
        pd.DataFrame
            文末表現データフレーム
        """
        eos_df = pd.read_csv(eos_df_path)
        eos_df.fillna('', inplace=True)  # ※１

        return eos_df

    @staticmethod
    def _create_classes(df: pd.DataFrame) -> List[str]:
        """
        全クラスのリストの作成

        渡されたデータフレームに含まれる全てのクラスを持ったリストを作る

        Parameters
        ----------
        df : pd.DataFrame
            文頭表現か、文末表現のデータフレーム

        Returns
        -------
        List[str]
            データフレームに含まれる全クラスのリスト
        """
        class_value_counts = df[TemplatesMaker._class_col].value_counts()
        classes: List[str] = class_value_counts.keys().tolist()

        return classes

    @staticmethod
    def _check_sos_and_eos_classes(
            sos_df: pd.DataFrame, eos_classes: List[str]
    ) -> None:
        """
        クラスの確認

        文頭表現のクラスに、文末表現にないクラスが含まれていないか確認する
        各文頭表現は、後に続くことができる文末表現のクラスを指定している

        Parameters
        ----------
        sos_df : pd.DataFrame
            文頭表現データフレーム
        eos_classes : List[str]
            文末表現の全クラス

        Raises
        ------
        ValueError
            ある文頭表現が、文末表現にないクラスを指定していた場合
        """
        sos_classes = TemplatesMaker._create_classes(sos_df)
        sos_classes.remove(TemplatesMaker._almighty_class)

        extra_sos_classes = [
            sos_cls for sos_cls in sos_classes if sos_cls not in eos_classes
        ]

        if extra_sos_classes:
            extra_sos_classes_str = '、'.join(extra_sos_classes)

            raise ValueError(
                f'{extra_sos_classes_str}というクラスは文末表現にありません'
            )

    def _create_pickers(self, eos_classes: List[str]) -> Dict[str, RandomPicker]:
        """
        _pickersの作成

        Parameters
        ----------
        eos_classes : List[str]
            文末表現の全クラス

        Returns
        -------
        Dict[str, RandomPicker]
            文末表現のクラスと、クラスに応じた文末表現のRandomPickerの辞書
        """
        pickers: Dict[str, RandomPicker] = {}

        for eos_class in eos_classes:
            class_idxs = self._create_class_idxs(eos_class)
            pickers[eos_class] = RandomPicker(class_idxs)

        return pickers

    def _create_class_idxs(self, eos_class: str) -> List[int]:
        """
        class_idxsの作成

        文末表現の各クラスに該当する文末表現データフレームの
        行インデックスのリストを作成する

        Parameters
        ----------
        eos_class : str
            文末表現のクラス

        Returns
        -------
        List[int]
            eos_classに該当する行インデックスのリスト
        """
        is_class_row = self._eos_df[self._class_col] == eos_class
        class_idxs: List[int] = self._eos_df[is_class_row].index.tolist()

        return class_idxs

    def extend_templates(self, row: pd.Series, templates: List[str]) -> None:
        """
        templatesの拡張

        Parameters
        ----------
        row : pd.Series
            文頭表現とその文頭表現に続く文末表現のクラスの情報を持つ行
        templates : List[str]
            テンプレートのリスト
        """
        sos, sos_class = row.values

        if sos_class == self._almighty_class:
            for eos_class in self._pickers.keys():
                self._append_template(sos, eos_class, templates)

        else:
            self._append_template(sos, sos_class, templates)

    def _append_template(
            self, sos: str, s_class: str, templates: List[str]
    ) -> None:
        """
        テンプレートの作成と追加

        Parameters
        ----------
        sos : str
            文頭表現
        s_class : str
            表現のクラス
        templates : List[str]
            テンプレートのリスト
        """
        eos = self._pick_eos(s_class)

        template = sos + eos
        templates.append(template)

    def _pick_eos(self, s_class: str) -> str:
        """
        文末表現の参照

        Parameters
        ----------
        s_class : str
            表現のクラス

        Returns
        -------
        str
            ランダムに参照した文末表現
        """
        picker = self._pickers[s_class]
        eos_idx: int = picker.pick()
        eos: str = self._eos_df.at[eos_idx, self._eos_col]

        return eos

# %% [markdown]
# # 実行

# %%
sos_df_path = '/content/drive/MyDrive/local_cuisine_search_app/data/processed_data/04_encoded_dataset_dataframe/encoded_dataset_dataframe_dependencies/01_untokenized_dataset_list/untokenized_dataset_list_dependencies/01_dataset_template_list/dataset_template_list_dependencies/01_start_of_sentences_dataframe/start_of_sentences_dataframe_v4_added_comma_and_parallelize.csv'
eos_df_path = '/content/drive/MyDrive/local_cuisine_search_app/data/processed_data/04_encoded_dataset_dataframe/encoded_dataset_dataframe_dependencies/01_untokenized_dataset_list/untokenized_dataset_list_dependencies/01_dataset_template_list/dataset_template_list_dependencies/02_end_of_sentences_dataframe/end_of_sentences_dataframe.csv'
file_name = 'dataset_template_list'
save_dir = '/content/drive/MyDrive/local_cuisine_search_app/data/processed_data/04_encoded_dataset_dataframe/encoded_dataset_dataframe_dependencies/01_untokenized_dataset_list/untokenized_dataset_list_dependencies/01_dataset_template_list'

template_list = create_and_save(sos_df_path, eos_df_path, file_name, save_dir)

# %% [markdown]
# # 出力結果の確認

# %%
print(f'template数: {len(template_list)}\n')
template_list
# Out:
# template数: 1929
# ['[AREA]または、[AREA]の[PRON]を、検索してくれませんか？',
#  '[AREA]または、[AREA]の[PRON]が、あれば探して？',
#  '[AREA]と[AREA]で食べられる、[PRON]を知ってたら、教えて？',
#  '[AREA]と[AREA]で食べられる、[PRON]が、あったら探してくれませんか？',
#  '[AREA]か[AREA]で食べられている、[PRON]を、ご存じでしたら、調べて？',
#  '[AREA]か[AREA]で食べられている、[PRON]があったら検索しろ',
#  '[TYPE]か[TYPE]について、知ってたら、検索して頂きたいです',
#  '[TYPE]か[TYPE]が、あれば、検索して？',
#  '[SZN]の[PRON]について、知ってたら、検索しろ。',
#  '[SZN]の[PRON]が、あれば、探して下さい',
#  '[SZN]に食べられる[PRON]について、ご存じでしたら探して欲しいです',
#  '[SZN]に食べられる[PRON]があったら、探して。',
#  '[SZN]に食べられている[PRON]について、探して？',
#  '[SZN]に食べられている[PRON]があれば、探してくれませんか？',
#  '[INGR]を使った、[PRON]を、知ってたら探して？',
#  '[INGR]を使った、[PRON]があれば調べて？',
#  '[INGR]または、[INGR]を使用した[PRON]について、知ってたら教えろ',
#  '[INGR]または、[INGR]を使用した[PRON]があれば、検索。',
#  '[INGR]が使われている[PRON]をご存じであれば、教えて',
#  '[INGR]が使われている[PRON]があったら検索して頂きたいです',
#  '[AREA]の[TYPE]あるいは[TYPE]について教えろ',
#  '[AREA]の[TYPE]あるいは[TYPE]があれば調べて',
#  '[AREA]で食べられる[TYPE]について、ご存じでしたら、検索してくれませんか？',
#  '[AREA]で食べられる[TYPE]があれば検索しろ',
#  '[AREA]で食べられている[TYPE]について検索して下さい',
#  '[AREA]で食べられている[TYPE]が、あれば、調べて頂きたいです。',
#  '[AREA]に[TYPE]か[TYPE]があったら、探して頂きたいです',
#  '[TYPE]で[AREA]の[PRON]を、ご存じでしたら探して頂きたいです',
#  '[TYPE]で[AREA]の[PRON]があれば、調べろ。',
#  '[TYPE]または、[TYPE]で[AREA]で食べられる[PRON]についてご存じであれば探して下さい。',
#  '[TYPE]または、[TYPE]で[AREA]で食べられる[PRON]が、あれば教えて頂きたいです',
#  '[TYPE]で[AREA]で食べられている[PRON]についてご存じであれば調べて？',
#  '[TYPE]で[AREA]で食べられている[PRON]が、あったら、調べて下さい。',
#  '[TYPE]に、[AREA]あるいは、[AREA]の[PRON]は、ありますか？',
#  '[TYPE]または[TYPE]に[AREA]で食べられる[PRON]が、あったら、教えて下さい',
#  '[TYPE]、または、[TYPE]に[AREA]で食べられている[PRON]が、あったら、調べて欲しいです',
#  '[AREA]の、[SZN]の[PRON]を、知ってたら、検索して頂きたいです',
#  '[AREA]の、[SZN]の[PRON]が、あったら教えて下さい',
#  '[AREA]の[SZN]に食べられる[PRON]を、ご存じでしたら検索して頂きたいです。',
#  '[AREA]の[SZN]に食べられる[PRON]があれば教えて欲しいです。',
#  '[AREA]または[AREA]の[SZN]に食べられている、[PRON]についてご存じであれば、教えて。',
#  '[AREA]または[AREA]の[SZN]に食べられている、[PRON]が、あったら調べて',
#  '[AREA]で[SZN]に食べられる[PRON]について、知ってたら、探してくれませんか？',
#  '[AREA]で[SZN]に食べられる[PRON]が、あったら、教えて頂けませんか？',
#  '[AREA]で、[SZN]に食べられている[PRON]をご存じであれば、教えて頂けませんか？',
#  '[AREA]で、[SZN]に食べられている[PRON]が、あれば探して。',
#  '[AREA]あるいは[AREA]で食べられる[SZN]の、[PRON]について知ってたら、調べろ',
#  '[AREA]あるいは[AREA]で食べられる[SZN]の、[PRON]があれば調べて欲しいです',
#  '[AREA]で食べられている[SZN]の[PRON]について、知ってたら調べろ。',
#  '[AREA]で食べられている[SZN]の[PRON]があれば検索してくれませんか？',
#  '[AREA]に[SZN]または[SZN]の[PRON]があれば探して下さい',
#  '[SZN]と[SZN]の[AREA]の[PRON]について、検索しろ',
#  '[SZN]と[SZN]の[AREA]の[PRON]が、あれば検索しろ。',
#  '[SZN]の[AREA]と[AREA]で食べられる[PRON]について知ってたら探して？',
#  '[SZN]の[AREA]と[AREA]で食べられる[PRON]が、あったら調べて下さい。',
#  '[SZN]の[AREA]か[AREA]で食べられている[PRON]についてご存じであれば、探して下さい',
#  '[SZN]の[AREA]か[AREA]で食べられている[PRON]があったら、検索して下さい。',
#  '[SZN]または[SZN]に[AREA]の[PRON]が、あれば、探して？',
#  '[SZN]に、[AREA]で食べられる[PRON]を、ご存じであれば教えて下さい',
#  '[SZN]に、[AREA]で食べられる[PRON]があったら、探して',
#  '[SZN]、と[SZN]に[AREA]で食べられている[PRON]について、ご存じでしたら、探して下さい。',
#  '[SZN]、と[SZN]に[AREA]で食べられている[PRON]が、あったら検索。',
#  '[SZN]に食べられる[AREA]の、[PRON]を、検索して頂きたいです',
#  '[SZN]に食べられる[AREA]の、[PRON]が、あれば、教えて下さい',
#  '[SZN]に食べられている、[AREA]の[PRON]をご存じでしたら調べて頂きたいです。',
#  '[SZN]に食べられている、[AREA]の[PRON]が、あれば探して欲しいです。',
#  '[AREA]の[INGR]か[INGR]を使った[PRON]について知ってたら、調べて欲しいです。',
#  '[AREA]の[INGR]か[INGR]を使った[PRON]が、あったら検索して欲しいです',
#  '[AREA]の[INGR]を使用した[PRON]を知ってたら、探せ',
#  '[AREA]の[INGR]を使用した[PRON]があれば、調べて。',
#  '[AREA]と[AREA]の[INGR]が使われている[PRON]について、調べて頂きたいです',
#  '[AREA]と[AREA]の[INGR]が使われている[PRON]があったら、教えろ。',
#  '[AREA]と、[AREA]で食べられる[INGR]を使った[PRON]についてご存じでしたら、検索して。',
#  '[AREA]と、[AREA]で食べられる[INGR]を使った[PRON]があったら、検索して',
#  '[AREA]か、[AREA]で食べられる[INGR]を使用した[PRON]をご存じであれば、検索して？',
#  '[AREA]か、[AREA]で食べられる[INGR]を使用した[PRON]が、あれば検索して？',
#  '[AREA]で食べられる[INGR]が使われている[PRON]を、ご存じであれば探して下さい。',
#  '[AREA]で食べられる[INGR]が使われている[PRON]が、あったら教えろ。',
#  '[AREA]で食べられている[INGR]を使った[PRON]についてご存じであれば、教えて欲しいです。',
#  '[AREA]で食べられている[INGR]を使った[PRON]が、あれば、検索して下さい。',
#  '[AREA]で食べられている、[INGR]を使用した[PRON]をご存じでしたら、探して下さい。',
#  '[AREA]で食べられている、[INGR]を使用した[PRON]が、あったら、検索して？',
#  '[AREA]、と[AREA]で食べられている[INGR]が使われている[PRON]をご存じでしたら、検索して頂きたいです。',
#  '[AREA]、と[AREA]で食べられている[INGR]が使われている[PRON]があれば調べて下さい。',
#  '[AREA]か、[AREA]に[INGR]を使った[PRON]があったら検索',
#  '[AREA]に[INGR]、と、[INGR]を使用した[PRON]が、あったら探して欲しいです',
#  '[AREA]と[AREA]に[INGR]が使われている[PRON]が、あれば、検索しろ。',
#  '[INGR]あるいは[INGR]を使った[AREA]の[PRON]について、探してくれませんか？',
#  '[INGR]あるいは[INGR]を使った[AREA]の[PRON]があったら、教えて',
#  '[INGR]と[INGR]を使用した[AREA]の[PRON]を検索して頂きたいです',
#  '[INGR]と[INGR]を使用した[AREA]の[PRON]が、あれば、調べてくれませんか？',
#  '[INGR]が使われている[AREA]の[PRON]について知ってたら検索して下さい。',
#  '[INGR]が使われている[AREA]の[PRON]があったら、調べて頂けませんか？',
#  '[INGR]を使った[AREA]で食べられる[PRON]をご存じでしたら、調べて？',
#  '[INGR]を使った[AREA]で食べられる[PRON]が、あったら、調べて。',
#  '[INGR]を使用した、[AREA]で食べられる[PRON]についてご存じであれば、調べて欲しいです。',
#  '[INGR]を使用した、[AREA]で食べられる[PRON]があれば、探して頂きたいです。',
#  '[INGR]が使われている[AREA]あるいは[AREA]で食べられる[PRON]についてご存じであれば探して。',
#  '[INGR]が使われている[AREA]あるいは[AREA]で食べられる[PRON]が、あれば、調べて頂けませんか？',
#  '[INGR]を使った[AREA]、か[AREA]で食べられている、[PRON]を探して',
#  '[INGR]を使った[AREA]、か[AREA]で食べられている、[PRON]があったら、検索',
#  '[INGR]を使用した、[AREA]で食べられている[PRON]をご存じであれば調べてくれませんか？',
#  '[INGR]を使用した、[AREA]で食べられている[PRON]があったら探して。',
#  '[INGR]が使われている[AREA]、と、[AREA]で食べられている[PRON]をご存じであれば、教えて？',
#  '[INGR]が使われている[AREA]、と、[AREA]で食べられている[PRON]があれば、探して',
#  '[TYPE]で[SZN]または、[SZN]の[PRON]をご存じであれば教えて頂けませんか？',
#  '[TYPE]で[SZN]または、[SZN]の[PRON]があれば、調べて頂きたいです',
#  '[TYPE]で[SZN]に食べられる[PRON]についてご存じであれば教えて。',
#  '[TYPE]で[SZN]に食べられる[PRON]があったら調べて？',
#  '[TYPE]で[SZN]に食べられている、[PRON]について、知ってたら、教えて頂きたいです。',
#  '[TYPE]で[SZN]に食べられている、[PRON]が、あれば調べて下さい。',
#  '[TYPE]または、[TYPE]に[SZN]の、[PRON]が、あったら、検索して頂きたいです',
#  '[SZN]、か、[SZN]の[TYPE]をご存じであれば探してくれませんか？',
#  '[SZN]、か、[SZN]の[TYPE]があったら、探せ。',
#  '[SZN]に、[TYPE]が、あったら検索して下さい。',
#  '[SZN]に食べられる[TYPE]について、ご存じであれば検索してくれませんか？',
#  '[SZN]に食べられる[TYPE]があれば、調べて欲しいです。',
#  '[SZN]に食べられている、[TYPE]について、探して欲しいです',
#  '[SZN]に食べられている、[TYPE]があったら調べて頂けませんか？',
#  '[TYPE]と[TYPE]で[INGR]を使った[PRON]を、知ってたら検索して頂けませんか？',
#  '[TYPE]と[TYPE]で[INGR]を使った[PRON]が、あったら検索しろ',
#  '[TYPE]で[INGR]または、[INGR]を使用した、[PRON]を、知ってたら検索してくれませんか？',
#  '[TYPE]で[INGR]または、[INGR]を使用した、[PRON]が、あれば、検索',
#  '[TYPE]で[INGR]が使われている[PRON]を、調べて。',
#  '[TYPE]で[INGR]が使われている[PRON]が、あれば検索してくれませんか？',
#  '[TYPE]に[INGR]を使った、[PRON]が、あったら検索しろ。',
#  '[TYPE]に、[INGR]を使用した[PRON]が、あれば、探して頂きたいです',
#  '[TYPE]に[INGR]が使われている[PRON]があったら検索して下さい。',
#  '[INGR]か[INGR]を使った、[TYPE]について探せ。',
#  '[INGR]か[INGR]を使った、[TYPE]があったら教えて欲しいです',
#  '[INGR]を使用した[TYPE]、か[TYPE]をご存じでしたら、検索してくれませんか？',
#  '[INGR]を使用した[TYPE]、か[TYPE]があったら、調べろ。',
#  '[INGR]が使われている[TYPE]を、知ってたら探して頂きたいです。',
#  '[INGR]が使われている[TYPE]が、あれば教えて欲しいです',
#  '[SZN]の、[INGR]を使った[PRON]について、ご存じであれば探してくれませんか？',
#  '[SZN]の、[INGR]を使った[PRON]が、あれば検索して。',
#  '[SZN]の[INGR]を使用した[PRON]について知ってたら、教えて？',
#  '[SZN]の[INGR]を使用した[PRON]が、あれば、調べて',
#  '[SZN]の[INGR]か[INGR]が使われている[PRON]を、知ってたら、検索してくれませんか？',
#  '[SZN]の[INGR]か[INGR]が使われている[PRON]が、あったら検索して下さい',
#  '[SZN]または[SZN]に食べられる[INGR]を使った[PRON]について知ってたら教えてくれませんか？',
#  '[SZN]または[SZN]に食べられる[INGR]を使った[PRON]が、あったら、検索して下さい。',
#  '[SZN]に食べられる[INGR]か[INGR]を使用した[PRON]を、ご存じでしたら、検索して頂きたいです',
#  '[SZN]に食べられる[INGR]か[INGR]を使用した[PRON]が、あれば、調べて欲しいです。',
#  '[SZN]に食べられる、[INGR]が使われている[PRON]を知ってたら教えろ。',
#  '[SZN]に食べられる、[INGR]が使われている[PRON]があれば、調べて頂けませんか？',
#  '[SZN]に食べられている[INGR]を使った[PRON]を、ご存じであれば、教えて下さい',
#  '[SZN]に食べられている[INGR]を使った[PRON]が、あったら教えてくれませんか？',
#  '[SZN]、か、[SZN]に食べられている[INGR]を使用した[PRON]についてご存じでしたら調べて下さい。',
#  '[SZN]、か、[SZN]に食べられている[INGR]を使用した[PRON]が、あれば検索して欲しいです。',
#  '[SZN]に食べられている[INGR]が使われている、[PRON]を、ご存じであれば、調べて。',
#  '[SZN]に食べられている[INGR]が使われている、[PRON]が、あれば、教えて欲しいです。',
#  '[INGR]を使った[SZN]の[PRON]について知ってますか',
#  '[INGR]を使った[SZN]の[PRON]が、あったら、調べて下さい',
#  '[INGR]を使用した、[SZN]の[PRON]を知ってたら、教えてくれませんか？',
#  '[INGR]を使用した、[SZN]の[PRON]が、あったら、調べて頂きたいです',
#  '[INGR]、あるいは、[INGR]が使われている[SZN]の[PRON]について、ご存じでしたら、探して頂けませんか？',
#  '[INGR]、あるいは、[INGR]が使われている[SZN]の[PRON]が、あったら、探せ。',
#  '[INGR]を使った[SZN]か、[SZN]に食べられる[PRON]について、調べて下さい。',
#  '[INGR]を使った[SZN]か、[SZN]に食べられる[PRON]があれば、教えて頂きたいです',
#  '[INGR]を使用した[SZN]に食べられる、[PRON]を知ってたら調べて下さい。',
#  '[INGR]を使用した[SZN]に食べられる、[PRON]があれば探して下さい。',
#  '[INGR]が使われている[SZN]に食べられる[PRON]についてご存じであれば検索して頂けませんか？',
#  '[INGR]が使われている[SZN]に食べられる[PRON]があれば教えろ。',
#  '[INGR]を使った、[SZN]に食べられている[PRON]についてご存じでしたら教えて下さい。',
#  '[INGR]を使った、[SZN]に食べられている[PRON]はありますか？',
#  '[INGR]を使用した[SZN]に食べられている[PRON]についてご存じであれば検索して',
#  '[INGR]を使用した[SZN]に食べられている[PRON]が、あれば探して下さい',
#  '[INGR]が使われている[SZN]に食べられている[PRON]について知ってたら、探して欲しいです。',
#  '[INGR]が使われている[SZN]に食べられている[PRON]が、あれば探して頂きたいです。',
#  '[AREA]の、[TYPE]で[SZN]の[PRON]を知ってたら探して頂けませんか？',
#  '[AREA]の、[TYPE]で[SZN]の[PRON]が、あったら、教えてくれませんか？',
#  '[AREA]の[TYPE]または、[TYPE]で[SZN]に食べられる[PRON]について、ご存じでしたら、教えて',
#  '[AREA]の[TYPE]または、[TYPE]で[SZN]に食べられる[PRON]が、あったら、探して下さい。',
#  '[AREA]の[TYPE]で[SZN]に食べられている[PRON]について、ご存じであれば、調べてくれませんか？',
#  '[AREA]の[TYPE]で[SZN]に食べられている[PRON]が、あったら検索して頂きたいです。',
#  '[AREA]の[TYPE]に[SZN]の[PRON]があったら調べろ。',
#  '[AREA]で[TYPE]または、[TYPE]に、[SZN]の[PRON]があれば教えろ',
#  '[AREA]か[AREA]で食べられる、[TYPE]で[SZN]の[PRON]を、ご存じであれば調べて下さい',
#  '[AREA]か[AREA]で食べられる、[TYPE]で[SZN]の[PRON]があれば検索しろ。',
#  '[AREA]で食べられている[TYPE]で[SZN]の[PRON]について、ご存じでしたら、調べて頂けませんか？',
#  '[AREA]で食べられている[TYPE]で[SZN]の[PRON]が、あれば、教えて下さい。',
#  '[AREA]で食べられる[TYPE]に[SZN]の、[PRON]はある？',
#  '[AREA]で食べられている[TYPE]に[SZN]の[PRON]が、あったら検索して頂けませんか？',
#  '[AREA]あるいは[AREA]に[TYPE]で[SZN]の、[PRON]があれば、教えて欲しいです',
#  '[AREA]の[SZN]の[TYPE]について、ご存じであれば検索して下さい。',
#  '[AREA]の[SZN]の[TYPE]があれば検索して？',
#  '[AREA]の[SZN]に[TYPE]が、あったら教えて？',
#  '[AREA]の[SZN]または[SZN]に食べられる[TYPE]を、ご存じであれば教えて下さい。',
#  '[AREA]の[SZN]または[SZN]に食べられる[TYPE]があれば調べて頂きたいです',
#  '[AREA]の[SZN]または、[SZN]に食べられている[TYPE]を、ご存じであれば探して',
#  '[AREA]の[SZN]または、[SZN]に食べられている[TYPE]があったら調べて。',
#  '[AREA]か、[AREA]で[SZN]に食べられる[TYPE]を、ご存じであれば検索して。',
#  '[AREA]か、[AREA]で[SZN]に食べられる[TYPE]が、あったら教えて頂きたいです。',
#  '[AREA]、あるいは、[AREA]で[SZN]に食べられている[TYPE]を、知ってたら、検索。',
#  '[AREA]、あるいは、[AREA]で[SZN]に食べられている[TYPE]が、あれば調べて。',
#  '[AREA]で食べられる[SZN]の、[TYPE]について、ご存じであれば検索して下さい',
#  '[AREA]で食べられる[SZN]の、[TYPE]があったら、調べて。',
#  '[AREA]で食べられている[SZN]の、[TYPE]について、ご存じでしたら、検索して頂けませんか？',
#  '[AREA]で食べられている[SZN]の、[TYPE]が、あったら、教えて？',
#  '[AREA]に[SZN]の[TYPE]が、あったら、探して。',
#  '[TYPE]で[AREA]の[SZN]の[PRON]についてご存じでしたら、調べて下さい',
#  '[TYPE]で[AREA]の[SZN]の[PRON]が、あれば、調べて頂きたいです',
#  '[TYPE]で[AREA]で[SZN]に食べられる[PRON]について知ってたら検索して欲しいです',
#  '[TYPE]で[AREA]で[SZN]に食べられる[PRON]があれば教えて頂けませんか？',
#  '[TYPE]で[AREA]で[SZN]に食べられている[PRON]について、ご存じでしたら、探して頂きたいです',
#  '[TYPE]で[AREA]で[SZN]に食べられている[PRON]が、あったら、探して頂きたいです',
#  '[TYPE]で、[AREA]で食べられる[SZN]、または、[SZN]の[PRON]についてご存じであれば探してくれませんか？',
#  '[TYPE]で、[AREA]で食べられる[SZN]、または、[SZN]の[PRON]が、あれば、探せ',
#  '[TYPE]で[AREA]で食べられている[SZN]の[PRON]を、教えて',
#  '[TYPE]で[AREA]で食べられている[SZN]の[PRON]が、あれば検索。',
#  '[TYPE]と[TYPE]に[AREA]の、[SZN]の[PRON]があれば、探して欲しいです',
#  '[TYPE]に[AREA]で食べられる[SZN]の[PRON]があったら、教えて下さい',
#  '[TYPE]か、[TYPE]に、[AREA]で食べられている[SZN]の[PRON]があったら検索して下さい',
#  '[TYPE]で[SZN]の、[AREA]の[PRON]についてご存じであれば、探して欲しいです。',
#  '[TYPE]で[SZN]の、[AREA]の[PRON]が、あれば、探して頂けませんか？',
#  '[TYPE]で[SZN]の[AREA]または、[AREA]で食べられる[PRON]についてご存じでしたら探して下さい。',
#  '[TYPE]で[SZN]の[AREA]または、[AREA]で食べられる[PRON]が、あったら調べて？',
#  '[TYPE]で、[SZN]の[AREA]で食べられている[PRON]を、ご存じでしたら教えて。',
#  '[TYPE]で、[SZN]の[AREA]で食べられている[PRON]が、あったら調べろ',
#  '[TYPE]で[SZN]に[AREA]または[AREA]で食べられる、[PRON]を知ってたら検索',
#  '[TYPE]で[SZN]に[AREA]または[AREA]で食べられる、[PRON]があったら教えてくれませんか？',
#  '[TYPE]で[SZN]に、[AREA]で食べられている[PRON]を知ってたら検索して。',
#  '[TYPE]で[SZN]に、[AREA]で食べられている[PRON]が、あったら、探して頂きたいです。',
#  '[TYPE]で[SZN]に食べられる[AREA]の[PRON]を探せ',
#  '[TYPE]で[SZN]に食べられる[AREA]の[PRON]が、あったら、教えろ。',
#  '[TYPE]で、[SZN]に食べられている[AREA]の[PRON]を、教えて頂きたいです。',
#  '[TYPE]で、[SZN]に食べられている[AREA]の[PRON]が、あったら探せ',
#  '[TYPE]に[SZN]の[AREA]の[PRON]があれば教えて？',
#  '[TYPE]に[SZN]の[AREA]で食べられる[PRON]が、あれば教えて。',
#  '[TYPE]に[SZN]あるいは[SZN]の、[AREA]で食べられている[PRON]があったら、探して？',
#  '[SZN]の[AREA]の[TYPE]をご存じでしたら検索して？',
#  '[SZN]の[AREA]の[TYPE]が、あれば教えて',
#  '[SZN]の[AREA]で食べられる[TYPE]を、知ってたら検索して。',
#  '[SZN]の[AREA]で食べられる[TYPE]があったら教えて欲しいです。',
#  '[SZN]か[SZN]の[AREA]で食べられている[TYPE]を、知ってたら探せ',
#  '[SZN]か[SZN]の[AREA]で食べられている[TYPE]が、あれば、調べて欲しいです',
#  '[SZN]に[AREA]で食べられる[TYPE]を、ご存じであれば調べて',
#  '[SZN]に[AREA]で食べられる[TYPE]があれば調べて頂けませんか？',
#  '[SZN]、か、[SZN]に[AREA]で食べられている、[TYPE]について、ご存じであれば調べて頂きたいです。',
#  '[SZN]、か、[SZN]に[AREA]で食べられている、[TYPE]が、あったら検索',
#  '[SZN]に食べられる[AREA]の[TYPE]について教えて',
#  '[SZN]に食べられる[AREA]の[TYPE]があれば検索',
#  '[SZN]に食べられている[AREA]の[TYPE]、か、[TYPE]を教えて頂けませんか？',
#  '[SZN]に食べられている[AREA]の[TYPE]、か、[TYPE]が、あったら、検索して頂きたいです。',
#  '[SZN]あるいは、[SZN]の[TYPE]で[AREA]の[PRON]について、ご存じであれば教えてくれませんか？',
#  '[SZN]あるいは、[SZN]の[TYPE]で[AREA]の[PRON]があれば探して欲しいです',
#  '[SZN]の[TYPE]で[AREA]で食べられる[PRON]について、ご存じであれば教えて下さい',
#  '[SZN]の[TYPE]で[AREA]で食べられる[PRON]があったら、検索して頂けませんか？',
#  '[SZN]と[SZN]の[TYPE]で[AREA]で食べられている[PRON]について、知ってたら探して頂きたいです',
#  '[SZN]と[SZN]の[TYPE]で[AREA]で食べられている[PRON]が、あったら教えて',
#  '[SZN]の[TYPE]に[AREA]の、[PRON]が、あったら探して',
#  '[SZN]と、[SZN]の[TYPE]に[AREA]で食べられる[PRON]が、あれば探して下さい。',
#  '[SZN]、あるいは[SZN]の[TYPE]に、[AREA]で食べられている[PRON]があったら調べて下さい。',
#  '[SZN]、または[SZN]に食べられる[TYPE]で、[AREA]の[PRON]についてご存じであれば検索して欲しいです',
#  '[SZN]、または[SZN]に食べられる[TYPE]で、[AREA]の[PRON]があったら、調べて頂きたいです',
#  '[SZN]に食べられている[TYPE]で[AREA]の[PRON]についてご存じでしたら、検索して頂きたいです',
#  '[SZN]に食べられている[TYPE]で[AREA]の[PRON]があったら調べて',
#  '[AREA]の[TYPE]で[INGR]を使った[PRON]を知ってたら教えて欲しいです。',
#  '[AREA]の[TYPE]で[INGR]を使った[PRON]があったら、調べて',
#  '[AREA]の、[TYPE]か[TYPE]で[INGR]を使用した[PRON]を、ご存じでしたら、教えて頂きたいです。',
#  '[AREA]の、[TYPE]か[TYPE]で[INGR]を使用した[PRON]があったら検索して欲しいです',
#  '[AREA]と、[AREA]の[TYPE]で、[INGR]が使われている[PRON]を知ってたら調べて頂きたいです',
#  '[AREA]と、[AREA]の[TYPE]で、[INGR]が使われている[PRON]があれば検索して欲しいです。',
#  '[AREA]または[AREA]の[TYPE]に[INGR]を使った[PRON]が、あれば、検索。',
#  '[AREA]の[TYPE]に[INGR]を使用した[PRON]が、あれば、探せ。',
#  '[AREA]の[TYPE]に[INGR]が使われている[PRON]が、あったら、探して下さい',
#  '[AREA]または[AREA]で[TYPE]に、[INGR]を使った[PRON]が、あれば、教えて欲しいです',
#  '[AREA]で[TYPE]に[INGR]を使用した[PRON]があれば、検索しろ',
#  '[AREA]で[TYPE]に[INGR]が使われている[PRON]が、あれば検索して欲しいです',
#  '[AREA]と[AREA]で食べられる[TYPE]で、[INGR]を使った[PRON]について、知ってたら教えて下さい',
#  '[AREA]と[AREA]で食べられる[TYPE]で、[INGR]を使った[PRON]があれば、検索してくれませんか？',
#  '[AREA]で食べられる[TYPE]で[INGR]を使用した、[PRON]についてご存じでしたら、検索してくれませんか？',
#  '[AREA]で食べられる[TYPE]で[INGR]を使用した、[PRON]があれば調べてくれませんか？',
#  '[AREA]で食べられる[TYPE]で、[INGR]が使われている[PRON]を、知ってたら、探せ',
#  '[AREA]で食べられる[TYPE]で、[INGR]が使われている[PRON]が、あれば、教えて頂きたいです。',
#  '[AREA]で食べられている、[TYPE]で[INGR]を使った[PRON]を、探せ。',
#  '[AREA]で食べられている、[TYPE]で[INGR]を使った[PRON]が、あったら検索して。',
#  '[AREA]で食べられている[TYPE]で[INGR]を使用した[PRON]について、知ってたら教えて。',
#  '[AREA]で食べられている[TYPE]で[INGR]を使用した[PRON]が、あったら、調べて欲しいです。',
#  '[AREA]で食べられている[TYPE]で[INGR]が使われている[PRON]について、知ってますか',
#  '[AREA]で食べられている[TYPE]で[INGR]が使われている[PRON]が、あったら探して。',
#  '[AREA]で食べられる[TYPE]に[INGR]または[INGR]を使った[PRON]があれば検索して欲しいです',
#  '[AREA]で食べられる[TYPE]、または、[TYPE]に[INGR]を使用した、[PRON]が、あれば教えろ。',
#  '[AREA]で食べられる[TYPE]に、[INGR]、か、[INGR]が使われている[PRON]が、あれば検索して下さい',
#  '[AREA]で食べられている、[TYPE]と[TYPE]に[INGR]を使った[PRON]が、あったら検索して欲しいです。',
#  '[AREA]で食べられている、[TYPE]に[INGR]を使用した[PRON]が、あったら探して頂けませんか？',
#  '[AREA]で食べられている[TYPE]、か、[TYPE]に[INGR]が使われている[PRON]があれば教えて下さい。',
#  '[AREA]に[TYPE]で[INGR]を使った[PRON]が、あれば探して頂きたいです',
#  '[AREA]に[TYPE]で[INGR]を使用した[PRON]があったら、検索して？',
#  '[AREA]、あるいは、[AREA]に[TYPE]で[INGR]が使われている[PRON]が、あれば探せ',
#  '[AREA]の[INGR]を使った[TYPE]か[TYPE]を、ご存じであれば、調べて下さい',
#  '[AREA]の[INGR]を使った[TYPE]か[TYPE]があれば教えて',
#  '[AREA]あるいは[AREA]の[INGR]を使用した[TYPE]を、ご存じでしたら検索して下さい。',
#  '[AREA]あるいは[AREA]の[INGR]を使用した[TYPE]があれば、検索して欲しいです',
#  '[AREA]の[INGR]が使われている[TYPE]についてご存じでしたら、教えて頂きたいです',
#  '[AREA]の[INGR]が使われている[TYPE]があったら教えて頂きたいです',
#  '[AREA]で食べられる[INGR]を使った、[TYPE]についてご存じであれば調べて頂きたいです',
#  '[AREA]で食べられる[INGR]を使った、[TYPE]が、あったら、教えて欲しいです',
#  '[AREA]で食べられる[INGR]を使用した[TYPE]について知ってたら教えて頂きたいです。',
#  '[AREA]で食べられる[INGR]を使用した[TYPE]が、あったら、探せ',
#  '[AREA]あるいは[AREA]で食べられる[INGR]が使われている[TYPE]をご存じであれば教えて欲しいです。',
#  '[AREA]あるいは[AREA]で食べられる[INGR]が使われている[TYPE]があれば探して頂きたいです。',
#  '[AREA]で食べられている[INGR]または[INGR]を使った[TYPE]について、知ってたら、検索して。',
#  '[AREA]で食べられている[INGR]または[INGR]を使った[TYPE]が、あれば探して',
#  '[AREA]で食べられている[INGR]を使用した[TYPE]をご存じであれば、探して頂きたいです',
#  '[AREA]で食べられている[INGR]を使用した[TYPE]があったら、調べて？',
#  '[AREA]または[AREA]で食べられている[INGR]が使われている、[TYPE]について、知ってたら教えて？',
#  '[AREA]または[AREA]で食べられている[INGR]が使われている、[TYPE]が、あったら、教えて下さい。',
#  '[AREA]、と、[AREA]に[INGR]を使った[TYPE]が、あったら、調べて頂きたいです。',
#  '[AREA]と、[AREA]に[INGR]を使用した[TYPE]が、あれば教えろ',
#  '[AREA]に[INGR]が使われている、[TYPE]が、あれば教えて？',
#  '[TYPE]あるいは[TYPE]で、[AREA]の[INGR]を使った[PRON]について、ご存じでしたら、教えて頂きたいです',
#  '[TYPE]あるいは[TYPE]で、[AREA]の[INGR]を使った[PRON]が、あったら教えて。',
#  '[TYPE]で[AREA]の[INGR]を使用した、[PRON]について、知ってたら探して頂きたいです。',
#  '[TYPE]で[AREA]の[INGR]を使用した、[PRON]があれば、調べて？',
#  '[TYPE]で、[AREA]の[INGR]が使われている[PRON]について検索して頂けませんか？',
#  '[TYPE]で、[AREA]の[INGR]が使われている[PRON]があったら教えて',
#  '[TYPE]で、[AREA]で食べられる[INGR]を使った[PRON]を、ご存じであれば、探して',
#  '[TYPE]で、[AREA]で食べられる[INGR]を使った[PRON]があれば探して頂きたいです',
#  '[TYPE]で[AREA]あるいは[AREA]で食べられる[INGR]を使用した[PRON]を知ってたら、調べて下さい。',
#  '[TYPE]で[AREA]あるいは[AREA]で食べられる[INGR]を使用した[PRON]が、あったら、探してくれませんか？',
#  '[TYPE]で、[AREA]で食べられる[INGR]が使われている[PRON]を、教えて下さい',
#  '[TYPE]で、[AREA]で食べられる[INGR]が使われている[PRON]があったら教えろ',
#  '[TYPE]で[AREA]で食べられている、[INGR]と[INGR]を使った[PRON]を、調べてくれませんか？',
#  '[TYPE]で[AREA]で食べられている、[INGR]と[INGR]を使った[PRON]があったら調べて欲しいです。',
#  '[TYPE]で[AREA]または、[AREA]で食べられている[INGR]を使用した[PRON]について知ってたら教えて？',
#  '[TYPE]で[AREA]または、[AREA]で食べられている[INGR]を使用した[PRON]があったら、教えて頂きたいです',
#  '[TYPE]で、[AREA]で食べられている[INGR]が使われている[PRON]について知ってたら、探せ',
#  '[TYPE]で、[AREA]で食べられている[INGR]が使われている[PRON]があれば検索して頂けませんか？',
#  '[TYPE]、と、[TYPE]で[AREA]に、[INGR]を使った[PRON]があったら、検索して欲しいです',
#  '[TYPE]、または、[TYPE]で[AREA]に[INGR]を使用した[PRON]があったら調べて下さい',
#  '[TYPE]で[AREA]に[INGR]が使われている[PRON]があったら検索してくれませんか？',
#  '[TYPE]に[AREA]の、[INGR]を使った[PRON]があったら教えて下さい。',
#  '[TYPE]に[AREA]か[AREA]の[INGR]を使用した[PRON]が、あれば、教えろ',
#  '[TYPE]に[AREA]の[INGR]が使われている[PRON]が、あったら、検索して頂けませんか？',
#  '[TYPE]に、[AREA]で食べられる[INGR]を使った[PRON]があったら検索。',
#  '[TYPE]に[AREA]か[AREA]で食べられる[INGR]を使用した[PRON]があれば探せ。',
#  '[TYPE]に[AREA]で食べられる[INGR]が使われている[PRON]が、あれば教えてくれませんか？',
#  '[TYPE]と[TYPE]に[AREA]で食べられている[INGR]を使った[PRON]が、あれば調べてくれませんか？',
#  '[TYPE]に[AREA]、あるいは、[AREA]で食べられている[INGR]を使用した、[PRON]が、あれば、調べろ',
#  '[TYPE]に[AREA]で食べられている[INGR]が使われている[PRON]があれば、調べろ',
#  '[TYPE]で[INGR]を使った[AREA]の[PRON]についてご存じでしたら、探して？',
#  '[TYPE]で[INGR]を使った[AREA]の[PRON]があれば検索して頂きたいです。',
#  '[TYPE]で[INGR]を使用した[AREA]の[PRON]を、知ってたら検索して頂きたいです。',
#  '[TYPE]で[INGR]を使用した[AREA]の[PRON]が、あれば教えて頂きたいです。',
#  '[TYPE]で[INGR]が使われている[AREA]の、[PRON]をご存じであれば検索して頂けませんか？',
#  '[TYPE]で[INGR]が使われている[AREA]の、[PRON]があれば、検索して欲しいです。',
#  '[TYPE]、と[TYPE]で[INGR]を使った、[AREA]で食べられる[PRON]をご存じであれば、調べて欲しいです。',
#  '[TYPE]、と[TYPE]で[INGR]を使った、[AREA]で食べられる[PRON]が、あれば、検索してくれませんか？',
#  '[TYPE]か[TYPE]で[INGR]を使用した[AREA]で食べられる[PRON]を、知ってたら、教えろ。',
#  '[TYPE]か[TYPE]で[INGR]を使用した[AREA]で食べられる[PRON]があれば探して',
#  '[TYPE]で[INGR]が使われている[AREA]で食べられる[PRON]について、ご存じであれば教えて下さい。',
#  '[TYPE]で[INGR]が使われている[AREA]で食べられる[PRON]があったら、検索して頂きたいです。',
#  '[TYPE]で[INGR]と、[INGR]を使った[AREA]で食べられている[PRON]を調べて欲しいです。',
#  '[TYPE]で[INGR]と、[INGR]を使った[AREA]で食べられている[PRON]があったら、検索して。',
#  '[TYPE]、または[TYPE]で[INGR]を使用した[AREA]で食べられている[PRON]を、知ってたら、検索しろ',
#  '[TYPE]、または[TYPE]で[INGR]を使用した[AREA]で食べられている[PRON]があったら調べてくれませんか？',
#  '[TYPE]で[INGR]が使われている[AREA]で食べられている[PRON]をご存じであれば、検索して',
#  '[TYPE]で[INGR]が使われている[AREA]で食べられている[PRON]があったら探して欲しいです',
#  '[TYPE]に、[INGR]を使った[AREA]または[AREA]の[PRON]についてご存じでしたら、調べて？',
#  '[TYPE]に、[INGR]を使った[AREA]または[AREA]の[PRON]が、あれば、検索して',
#  '[TYPE]に[INGR]を使用した、[AREA]の[PRON]を、ご存じであれば探して欲しいです',
#  '[TYPE]に[INGR]を使用した、[AREA]の[PRON]があったら教えて？',
#  '[TYPE]、か[TYPE]に[INGR]が使われている[AREA]の、[PRON]を、ご存じでしたら、検索して？',
#  '[TYPE]、か[TYPE]に[INGR]が使われている[AREA]の、[PRON]があれば検索して下さい',
#  '[TYPE]に[INGR]を使った[AREA]で食べられる[PRON]について、ご存じでしたら、検索して',
#  '[TYPE]に[INGR]を使った[AREA]で食べられる[PRON]が、あったら、教えて。',
#  '[TYPE]に[INGR]を使用した[AREA]で食べられる、[PRON]についてご存じでしたら調べてくれませんか？',
#  '[TYPE]に[INGR]を使用した[AREA]で食べられる、[PRON]が、あったら、探して欲しいです',
#  '[TYPE]に[INGR]または[INGR]が使われている[AREA]で食べられる[PRON]について、教えろ。',
#  '[TYPE]に[INGR]または[INGR]が使われている[AREA]で食べられる[PRON]が、あれば、探して欲しいです',
#  '[TYPE]に[INGR]を使った[AREA]で食べられている[PRON]をご存じであれば、教えて欲しいです。',
#  '[TYPE]に[INGR]を使った[AREA]で食べられている[PRON]があったら、調べて欲しいです。',
#  '[TYPE]、あるいは[TYPE]に[INGR]を使用した[AREA]で食べられている、[PRON]について、調べて？',
#  '[TYPE]、あるいは[TYPE]に[INGR]を使用した[AREA]で食べられている、[PRON]があれば探して。',
#  '[TYPE]に[INGR]が使われている[AREA]で食べられている[PRON]を検索して欲しいです',
#  '[TYPE]に[INGR]が使われている[AREA]で食べられている[PRON]が、あったら調べろ。',
#  '[INGR]を使った、[AREA]の[TYPE]を知ってたら調べて欲しいです',
#  '[INGR]を使った、[AREA]の[TYPE]が、あったら探して？',
#  '[INGR]を使用した[AREA]の[TYPE]について、ご存じであれば教えて',
#  '[INGR]を使用した[AREA]の[TYPE]が、あれば、探して',
#  '[INGR]が使われている[AREA]、と、[AREA]の[TYPE]を知ってたら、教えて頂きたいです',
#  '[INGR]が使われている[AREA]、と、[AREA]の[TYPE]が、あったら探して下さい',
#  '[INGR]を使った[AREA]あるいは[AREA]で食べられる、[TYPE]を検索して頂きたいです。',
#  '[INGR]を使った[AREA]あるいは[AREA]で食べられる、[TYPE]が、あったら、検索して',
#  '[INGR]を使用した[AREA]で食べられる[TYPE]、または[TYPE]について、ご存じであれば、検索して',
#  '[INGR]を使用した[AREA]で食べられる[TYPE]、または[TYPE]が、あったら探せ。',
#  '[INGR]が使われている[AREA]で食べられる[TYPE]か[TYPE]は、ご存じでしょうか',
#  '[INGR]が使われている[AREA]で食べられる[TYPE]か[TYPE]があったら探せ',
#  '[INGR]を使った[AREA]、か、[AREA]で食べられている、[TYPE]を、ご存じであれば教えて頂きたいです',
#  '[INGR]を使った[AREA]、か、[AREA]で食べられている、[TYPE]があったら教えろ。',
#  '[INGR]を使用した[AREA]で食べられている、[TYPE]について、ご存じであれば教えて。',
#  '[INGR]を使用した[AREA]で食べられている、[TYPE]があったら、教えて欲しいです',
#  '[INGR]と[INGR]が使われている[AREA]で食べられている[TYPE]について、ご存じでしたら検索して頂きたいです。',
#  '[INGR]と[INGR]が使われている[AREA]で食べられている[TYPE]が、あれば調べろ',
#  '[INGR]を使った[TYPE]で[AREA]の[PRON]について、知ってたら検索して',
#  '[INGR]を使った[TYPE]で[AREA]の[PRON]が、あれば検索して',
#  '[INGR]を使用した、[TYPE]で[AREA]の[PRON]についてご存じでしたら教えてくれませんか？',
#  '[INGR]を使用した、[TYPE]で[AREA]の[PRON]が、あったら、検索。',
#  '[INGR]が使われている[TYPE]で[AREA]または[AREA]の、[PRON]について知ってたら、教えて。',
#  '[INGR]が使われている[TYPE]で[AREA]または[AREA]の、[PRON]は、ある？',
#  '[INGR]あるいは[INGR]を使った[TYPE]で[AREA]で食べられる[PRON]をご存じでしたら、検索して下さい。',
#  '[INGR]あるいは[INGR]を使った[TYPE]で[AREA]で食べられる[PRON]が、あったら、探して欲しいです。',
#  '[INGR]を使用した、[TYPE]で[AREA]で食べられる[PRON]を、知ってたら調べて頂きたいです',
#  '[INGR]を使用した、[TYPE]で[AREA]で食べられる[PRON]が、あれば、教えて頂けませんか？',
#  '[INGR]が使われている[TYPE]と[TYPE]で[AREA]で食べられる、[PRON]についてご存じでしたら、調べて。',
#  '[INGR]が使われている[TYPE]と[TYPE]で[AREA]で食べられる、[PRON]があれば検索。',
#  '[INGR]を使った、[TYPE]で[AREA]で食べられている[PRON]についてご存じでしたら、探して頂けませんか？',
#  '[INGR]を使った、[TYPE]で[AREA]で食べられている[PRON]があったら、調べて欲しいです',
#  '[INGR]を使用した[TYPE]あるいは[TYPE]で[AREA]で食べられている[PRON]についてご存じでしたら探して頂けませんか？',
#  '[INGR]を使用した[TYPE]あるいは[TYPE]で[AREA]で食べられている[PRON]が、あれば教えて下さい。',
#  '[INGR]が使われている[TYPE]あるいは[TYPE]で、[AREA]で食べられている[PRON]を、ご存じでしょうか。',
#  '[INGR]が使われている[TYPE]あるいは[TYPE]で、[AREA]で食べられている[PRON]が、あれば、検索して。',
#  '[INGR]を使った[TYPE]と[TYPE]に[AREA]の[PRON]があったら検索して？',
#  '[INGR]を使用した、[TYPE]に[AREA]の[PRON]が、あったら探して欲しいです。',
#  '[INGR]または、[INGR]が使われている[TYPE]に、[AREA]の[PRON]があれば探せ',
#  '[INGR]あるいは[INGR]を使った[TYPE]に[AREA]で食べられる[PRON]が、あれば教えて下さい',
#  '[INGR]を使用した[TYPE]に[AREA]で食べられる[PRON]があれば、探して？',
#  '[INGR]が使われている[TYPE]に[AREA]で食べられる[PRON]があれば、検索して頂きたいです',
#  '[INGR]あるいは[INGR]を使った[TYPE]に[AREA]で食べられている[PRON]が、あれば調べて頂きたいです',
#  '[INGR]を使用した、[TYPE]と[TYPE]に[AREA]で食べられている[PRON]が、あれば探して頂けませんか？',
#  '[INGR]が使われている[TYPE]に[AREA]で食べられている[PRON]があれば調べろ',
#  '[AREA]の[SZN]と[SZN]の[INGR]を使った[PRON]についてご存じでしたら検索して頂きたいです。',
#  '[AREA]の[SZN]と[SZN]の[INGR]を使った[PRON]が、あったら、探して',
#  '[AREA]、か[AREA]の[SZN]の[INGR]を使用した[PRON]について知ってたら調べて',
#  '[AREA]、か[AREA]の[SZN]の[INGR]を使用した[PRON]があれば調べて頂きたいです。',
#  '[AREA]の[SZN]の[INGR]が使われている[PRON]を、ご存じであれば、調べて頂けませんか？',
#  '[AREA]の[SZN]の[INGR]が使われている[PRON]があれば、検索して。',
#  '[AREA]、または[AREA]の[SZN]に食べられる[INGR]を使った[PRON]を、ご存じであれば、検索してくれませんか？',
#  '[AREA]、または[AREA]の[SZN]に食べられる[INGR]を使った[PRON]が、あれば検索しろ',
#  '[AREA]の、[SZN]に食べられる[INGR]を使用した[PRON]についてご存じであれば、調べて',
#  '[AREA]の、[SZN]に食べられる[INGR]を使用した[PRON]が、あったら調べて下さい',
#  '[AREA]の[SZN]に食べられる[INGR]、または、[INGR]が使われている[PRON]を知ってたら調べて頂けませんか？',
#  '[AREA]の[SZN]に食べられる[INGR]、または、[INGR]が使われている[PRON]があれば、検索して頂けませんか？',
#  '[AREA]の[SZN]あるいは[SZN]に食べられている[INGR]を使った、[PRON]を、調べて頂きたいです',
#  '[AREA]の[SZN]あるいは[SZN]に食べられている[INGR]を使った、[PRON]があったら探して頂けませんか？',
#  '[AREA]の[SZN]に食べられている、[INGR]を使用した[PRON]について知ってたら調べてくれませんか？',
#  '[AREA]の[SZN]に食べられている、[INGR]を使用した[PRON]が、あったら、検索しろ',
#  '[AREA]の[SZN]に食べられている、[INGR]または、[INGR]が使われている[PRON]について知ってたら、探して下さい',
#  '[AREA]の[SZN]に食べられている、[INGR]または、[INGR]が使われている[PRON]があったら、教えろ',
#  '[AREA]か、[AREA]で[SZN]の[INGR]を使った[PRON]があったら調べて欲しいです',
#  '[AREA]で[SZN]の[INGR]を使用した[PRON]があれば、教えて。',
#  '[AREA]で[SZN]か[SZN]の[INGR]が使われている[PRON]があったら、検索。',
#  '[AREA]で[SZN]に[INGR]を使った、[PRON]があれば、検索して頂きたいです。',
#  '[AREA]で[SZN]に[INGR]を使用した[PRON]があったら、教えて下さい。',
#  '[AREA]で[SZN]に[INGR]が使われている[PRON]が、あったら、検索して下さい',
#  '[AREA]で[SZN]に食べられる[INGR]を使った[PRON]についてご存じであれば、調べて。',
#  '[AREA]で[SZN]に食べられる[INGR]を使った[PRON]があれば検索して下さい。',
#  '[AREA]で[SZN]に食べられる[INGR]を使用した、[PRON]について知ってたら、教えて欲しいです',
#  '[AREA]で[SZN]に食べられる[INGR]を使用した、[PRON]が、あったら検索して？',
#  '[AREA]で[SZN]に食べられる、[INGR]が使われている[PRON]を、ご存じでしたら、検索してくれませんか？',
#  '[AREA]で[SZN]に食べられる、[INGR]が使われている[PRON]があれば、検索して？',
#  '[AREA]、あるいは[AREA]で[SZN]に食べられている[INGR]を使った[PRON]について、ご存じでしたら教えて欲しいです。',
#  '[AREA]、あるいは[AREA]で[SZN]に食べられている[INGR]を使った[PRON]が、あったら、調べろ',
#  '[AREA]で[SZN]に食べられている[INGR]を使用した[PRON]について、知ってたら、調べて頂けませんか？',
#  '[AREA]で[SZN]に食べられている[INGR]を使用した[PRON]があったら、調べて下さい。',
#  '[AREA]または[AREA]で[SZN]に食べられている[INGR]が使われている、[PRON]を、ご存じであれば、教えて頂けませんか？',
#  '[AREA]または[AREA]で[SZN]に食べられている[INGR]が使われている、[PRON]があれば、探して頂けませんか？',
#  '[AREA]または[AREA]で食べられる[SZN]の[INGR]を使った[PRON]を、ご存じであれば、検索して？',
#  '[AREA]または[AREA]で食べられる[SZN]の[INGR]を使った[PRON]があれば教えてくれませんか？',
#  '[AREA]で食べられる[SZN]の[INGR]を使用した[PRON]を知ってたら、探して。',
#  '[AREA]で食べられる[SZN]の[INGR]を使用した[PRON]が、あれば、教えろ。',
#  '[AREA]か[AREA]で食べられる、[SZN]の[INGR]が使われている[PRON]についてご存じであれば調べて欲しいです',
#  '[AREA]か[AREA]で食べられる、[SZN]の[INGR]が使われている[PRON]があったら教えて頂きたいです。',
#  '[AREA]で食べられている[SZN]の[INGR]あるいは[INGR]を使った、[PRON]をご存じであれば教えて下さい。',
#  '[AREA]で食べられている[SZN]の[INGR]あるいは[INGR]を使った、[PRON]が、あれば調べて',
#  '[AREA]で食べられている[SZN]の、[INGR]を使用した[PRON]をご存じであれば教えて頂きたいです',
#  '[AREA]で食べられている[SZN]の、[INGR]を使用した[PRON]があったら探して頂きたいです。',
#  '[AREA]で食べられている[SZN]または、[SZN]の[INGR]が使われている[PRON]について、検索して',
#  '[AREA]で食べられている[SZN]または、[SZN]の[INGR]が使われている[PRON]があったら、探して欲しいです。',
#  '[AREA]に[SZN]、と、[SZN]の[INGR]を使った、[PRON]が、あれば、調べて下さい。',
#  '[AREA]に[SZN]、と、[SZN]の[INGR]を使用した[PRON]があったら探してくれませんか？',
#  '[AREA]に[SZN]の[INGR]または[INGR]が使われている[PRON]があれば、探して。',
#  '[AREA]の、[INGR]を使った[SZN]の[PRON]を知ってたら、調べて頂きたいです。',
#  '[AREA]の、[INGR]を使った[SZN]の[PRON]があれば、教えて下さい。',
#  '[AREA]の[INGR]を使用した[SZN]の、[PRON]について、知ってたら検索して欲しいです',
#  '[AREA]の[INGR]を使用した[SZN]の、[PRON]が、あったら調べて頂きたいです。',
#  '[AREA]、と、[AREA]の、[INGR]が使われている[SZN]の[PRON]について、ご存じであれば、調べて？',
#  '[AREA]、と、[AREA]の、[INGR]が使われている[SZN]の[PRON]があったら教えて。',
#  '[AREA]の[INGR]か、[INGR]を使った[SZN]に食べられる[PRON]を知ってたら、探して頂けませんか？',
#  '[AREA]の[INGR]か、[INGR]を使った[SZN]に食べられる[PRON]が、あったら、検索してくれませんか？',
#  '[AREA]の[INGR]を使用した、[SZN]に食べられる[PRON]についてご存じでしたら、調べて欲しいです。',
#  '[AREA]の[INGR]を使用した、[SZN]に食べられる[PRON]があったら調べて頂きたいです',
#  '[AREA]の[INGR]が使われている[SZN]、あるいは、[SZN]に食べられる[PRON]をご存じでしたら調べて下さい',
#  '[AREA]の[INGR]が使われている[SZN]、あるいは、[SZN]に食べられる[PRON]が、あれば検索して頂きたいです',
#  '[AREA]の[INGR]を使った[SZN]に食べられている、[PRON]を検索しろ。',
#  '[AREA]の[INGR]を使った[SZN]に食べられている、[PRON]があれば調べろ。',
#  '[AREA]の、[INGR]または[INGR]を使用した[SZN]に食べられている[PRON]についてご存じであれば教えて下さい。',
#  '[AREA]の、[INGR]または[INGR]を使用した[SZN]に食べられている[PRON]が、あったら、教えて頂きたいです。',
#  '[AREA]の[INGR]が使われている[SZN]または[SZN]に食べられている[PRON]について、知ってたら、探して頂けませんか？',
#  '[AREA]の[INGR]が使われている[SZN]または[SZN]に食べられている[PRON]があれば、教えて頂きたいです。',
#  '[AREA]、あるいは、[AREA]で[INGR]を使った[SZN]の[PRON]があったら検索して',
#  '[AREA]、あるいは[AREA]で[INGR]を使用した[SZN]の[PRON]が、あれば調べて欲しいです',
#  '[AREA]で、[INGR]が使われている[SZN]の[PRON]があれば教えて。',
#  '[AREA]で[INGR]を使った[SZN]に食べられる[PRON]が、あったら探して頂きたいです。',
#  '[AREA]で[INGR]、と[INGR]を使用した[SZN]に食べられる[PRON]が、あったら調べて欲しいです。',
#  '[AREA]で、[INGR]が使われている[SZN]または[SZN]に食べられる[PRON]があれば教えて下さい',
#  '[AREA]で[INGR]か[INGR]を使った[SZN]に食べられている[PRON]があったら、探して頂けませんか？',
#  '[AREA]または[AREA]で[INGR]を使用した[SZN]に食べられている[PRON]が、あれば調べて頂けませんか？',
#  '[AREA]で[INGR]か[INGR]が使われている[SZN]に食べられている[PRON]が、あれば、探して。',
#  '[AREA]か、[AREA]で食べられる[INGR]を使った、[SZN]の[PRON]を、ご存じであれば教えて欲しいです。',
#  '[AREA]か、[AREA]で食べられる[INGR]を使った、[SZN]の[PRON]があったら検索して頂きたいです。',
#  '[AREA]で食べられる[INGR]を使用した[SZN]、と[SZN]の[PRON]を、知ってたら検索して頂きたいです',
#  '[AREA]で食べられる[INGR]を使用した[SZN]、と[SZN]の[PRON]があったら探して下さい。',
#  '[AREA]で食べられる[INGR]が使われている[SZN]の[PRON]を教えろ。',
#  '[AREA]で食べられる[INGR]が使われている[SZN]の[PRON]があったら検索して頂けませんか？',
#  '[AREA]で食べられている、[INGR]あるいは[INGR]を使った[SZN]の[PRON]についてご存じでしたら教えて下さい',
#  '[AREA]で食べられている、[INGR]あるいは[INGR]を使った[SZN]の[PRON]があったら、教えて頂けませんか？',
#  '[AREA]で食べられている[INGR]、か、[INGR]を使用した[SZN]の[PRON]についてご存じであれば、検索して欲しいです',
#  '[AREA]で食べられている[INGR]、か、[INGR]を使用した[SZN]の[PRON]があったら探して下さい',
#  '[AREA]、か、[AREA]で食べられている[INGR]が使われている、[SZN]の[PRON]について探して頂けませんか？',
#  '[AREA]、か、[AREA]で食べられている[INGR]が使われている、[SZN]の[PRON]があったら探せ。',
#  '[AREA]に、[INGR]または[INGR]を使った[SZN]の[PRON]があれば教えて頂きたいです',
#  '[AREA]または[AREA]に[INGR]を使用した[SZN]の[PRON]が、あれば、探して頂きたいです。',
#  '[AREA]に、[INGR]が使われている[SZN]の[PRON]が、あれば検索して頂きたいです。',
#  '[SZN]の、[AREA]の[INGR]を使った[PRON]について、知ってたら探して下さい。',
#  '[SZN]の、[AREA]の[INGR]を使った[PRON]があったら、教えてくれませんか？',
#  '[SZN]の[AREA]または[AREA]の、[INGR]を使用した[PRON]についてご存じであれば、調べて頂きたいです',
#  '[SZN]の[AREA]または[AREA]の、[INGR]を使用した[PRON]があれば探して？',
#  '[SZN]の[AREA]の[INGR]が使われている[PRON]をご存じでしたら探してくれませんか？',
#  '[SZN]の[AREA]の[INGR]が使われている[PRON]があったら探して頂きたいです',
#  '[SZN]の[AREA]で食べられる[INGR]と、[INGR]を使った[PRON]をご存じでしたら調べて。',
#  '[SZN]の[AREA]で食べられる[INGR]と、[INGR]を使った[PRON]が、あったら教えて下さい。',
#  '[SZN]または[SZN]の[AREA]で食べられる[INGR]を使用した[PRON]は、ご存じでしょうか？',
#  '[SZN]または[SZN]の[AREA]で食べられる[INGR]を使用した[PRON]があったら、検索してくれませんか？',
#  '[SZN]の[AREA]で食べられる[INGR]が使われている、[PRON]について、ご存じでしたら検索して下さい。',
#  '[SZN]の[AREA]で食べられる[INGR]が使われている、[PRON]が、あったら探して下さい。',
#  '[SZN]または[SZN]の[AREA]で食べられている[INGR]を使った[PRON]について、ご存じであれば、教えてくれませんか？',
#  '[SZN]または[SZN]の[AREA]で食べられている[INGR]を使った[PRON]があったら、調べて下さい',
#  '[SZN]の[AREA]で食べられている[INGR]を使用した[PRON]をご存じでしたら、検索して',
#  '[SZN]の[AREA]で食べられている[INGR]を使用した[PRON]があれば、調べてくれませんか？',
#  '[SZN]あるいは[SZN]の[AREA]で食べられている、[INGR]が使われている[PRON]について、ご存じでしたら、探してくれませんか？',
#  '[SZN]あるいは[SZN]の[AREA]で食べられている、[INGR]が使われている[PRON]が、あれば、検索して欲しいです',
#  '[SZN]に[AREA]で食べられる、[INGR]を使った[PRON]について、知ってたら教えてくれませんか？',
#  '[SZN]に[AREA]で食べられる、[INGR]を使った[PRON]があったら、調べてくれませんか？',
#  '[SZN]に[AREA]で食べられる[INGR]を使用した、[PRON]について、知ってたら調べろ',
#  '[SZN]に[AREA]で食べられる[INGR]を使用した、[PRON]があったら、調べろ',
#  '[SZN]に[AREA]で食べられる[INGR]が使われている[PRON]について、調べろ',
#  '[SZN]に[AREA]で食べられる[INGR]が使われている[PRON]が、あれば教えて欲しいです。',
#  '[SZN]に[AREA]、または[AREA]で食べられている[INGR]を使った[PRON]を、ご存じであれば調べて下さい。',
#  '[SZN]に[AREA]、または[AREA]で食べられている[INGR]を使った[PRON]があったら、教えて？',
#  '[SZN]に[AREA]で食べられている[INGR]、と、[INGR]を使用した[PRON]についてご存じであれば探して？',
#  '[SZN]に[AREA]で食べられている[INGR]、と、[INGR]を使用した[PRON]が、あれば検索して下さい。',
#  '[SZN]に[AREA]あるいは[AREA]で食べられている[INGR]が使われている[PRON]をご存じでしたら調べて欲しいです。',
#  '[SZN]に[AREA]あるいは[AREA]で食べられている[INGR]が使われている[PRON]があれば、検索',
#  '[SZN]または[SZN]に食べられる、[AREA]の[INGR]を使った[PRON]をご存じであれば検索して？',
#  '[SZN]または[SZN]に食べられる、[AREA]の[INGR]を使った[PRON]が、あったら調べて。',
#  '[SZN]に食べられる[AREA]または、[AREA]の、[INGR]を使用した[PRON]を知ってたら、検索して。',
#  '[SZN]に食べられる[AREA]または、[AREA]の、[INGR]を使用した[PRON]があれば、検索して',
#  '[SZN]に食べられる[AREA]の[INGR]が使われている[PRON]についてご存じでしたら調べて',
#  '[SZN]に食べられる[AREA]の[INGR]が使われている[PRON]があれば、調べて下さい',
#  '[SZN]に食べられている[AREA]の[INGR]を使った[PRON]について知ってたら探せ',
#  '[SZN]に食べられている[AREA]の[INGR]を使った[PRON]があれば、検索して下さい',
#  '[SZN]に食べられている[AREA]あるいは、[AREA]の[INGR]を使用した[PRON]についてご存じでしたら、教えて欲しいです',
#  '[SZN]に食べられている[AREA]あるいは、[AREA]の[INGR]を使用した[PRON]が、あったら、調べて頂けませんか？',
#  '[SZN]と[SZN]に食べられている[AREA]の[INGR]が使われている[PRON]をご存じであれば教えて。',
#  '[SZN]と[SZN]に食べられている[AREA]の[INGR]が使われている[PRON]が、あれば、検索して欲しいです。',
#  '[SZN]の、[INGR]を使った[AREA]の[PRON]についてご存じであれば検索して頂きたいです',
#  '[SZN]の、[INGR]を使った[AREA]の[PRON]があったら教えて頂けませんか？',
#  '[SZN]の、[INGR]と、[INGR]を使用した[AREA]の[PRON]についてご存じであれば、調べて頂けませんか？',
#  '[SZN]の、[INGR]と、[INGR]を使用した[AREA]の[PRON]があったら、検索しろ。',
#  '[SZN]あるいは[SZN]の[INGR]が使われている[AREA]の[PRON]について知ってたら探して頂けませんか？',
#  '[SZN]あるいは[SZN]の[INGR]が使われている[AREA]の[PRON]が、あれば、教えてくれませんか？',
#  '[SZN]か[SZN]の[INGR]を使った、[AREA]で食べられる[PRON]をご存じでしょうか。',
#  '[SZN]か[SZN]の[INGR]を使った、[AREA]で食べられる[PRON]が、あったら探して頂きたいです',
#  '[SZN]の[INGR]を使用した[AREA]で食べられる[PRON]を知ってたら、検索してくれませんか？',
#  '[SZN]の[INGR]を使用した[AREA]で食べられる[PRON]が、あったら調べて欲しいです',
#  '[SZN]の[INGR]が使われている[AREA]で食べられる[PRON]について、ご存じであれば探して下さい。',
#  '[SZN]の[INGR]が使われている[AREA]で食べられる[PRON]があったら調べろ',
#  '[SZN]の[INGR]を使った[AREA]で食べられている[PRON]について、知ってたら調べて下さい',
#  '[SZN]の[INGR]を使った[AREA]で食べられている[PRON]が、あったら、探して頂けませんか？',
#  '[SZN]の[INGR]を使用した[AREA]で食べられている[PRON]を調べてくれませんか？',
#  '[SZN]の[INGR]を使用した[AREA]で食べられている[PRON]があれば、調べて頂きたいです。',
#  '[SZN]の[INGR]が使われている[AREA]で食べられている[PRON]について、知ってたら調べて？',
#  '[SZN]の[INGR]が使われている[AREA]で食べられている[PRON]があったら、検索して欲しいです。',
#  '[SZN]と、[SZN]に食べられる[INGR]を使った[AREA]の[PRON]について、ご存じであれば検索して？',
#  '[SZN]と、[SZN]に食べられる[INGR]を使った[AREA]の[PRON]が、あれば、調べて？',
#  '[SZN]に食べられる[INGR]を使用した[AREA]または[AREA]の[PRON]について、ご存じでしたら調べてくれませんか？',
#  '[SZN]に食べられる[INGR]を使用した[AREA]または[AREA]の[PRON]が、あったら、探して？',
#  '[SZN]に食べられる[INGR]が使われている、[AREA]か[AREA]の[PRON]について、ご存じでしたら、探して頂きたいです。',
#  '[SZN]に食べられる[INGR]が使われている、[AREA]か[AREA]の[PRON]が、あれば、検索して頂けませんか？',
#  '[SZN]に食べられている、[INGR]を使った[AREA]、か[AREA]の[PRON]を、調べて頂けませんか？',
#  '[SZN]に食べられている、[INGR]を使った[AREA]、か[AREA]の[PRON]が、あれば教えて頂けませんか？',
#  '[SZN]に食べられている[INGR]を使用した[AREA]の[PRON]をご存じでしたら、調べて欲しいです',
#  '[SZN]に食べられている[INGR]を使用した[AREA]の[PRON]が、あったら、検索して欲しいです',
#  '[SZN]に食べられている、[INGR]が使われている[AREA]の[PRON]について、ご存じであれば、調べて下さい',
#  '[SZN]に食べられている、[INGR]が使われている[AREA]の[PRON]が、あれば、探してくれませんか？',
#  '[INGR]を使った[AREA]の、[SZN]の[PRON]について、調べろ。',
#  '[INGR]を使った[AREA]の、[SZN]の[PRON]があれば、検索して下さい。',
#  '[INGR]を使用した[AREA]と[AREA]の[SZN]の、[PRON]について、探して下さい。',
#  '[INGR]を使用した[AREA]と[AREA]の[SZN]の、[PRON]があったら探して欲しいです。',
#  '[INGR]が使われている[AREA]の[SZN]の[PRON]について知ってたら、検索してくれませんか？',
#  '[INGR]が使われている[AREA]の[SZN]の[PRON]があったら、教えて頂きたいです。',
#  '[INGR]を使った、[AREA]または、[AREA]の[SZN]に食べられる[PRON]について、ご存じでしたら探して欲しいです。',
#  '[INGR]を使った、[AREA]または、[AREA]の[SZN]に食べられる[PRON]が、あったら教えろ',
#  '[INGR]を使用した[AREA]の[SZN]に食べられる[PRON]について、ご存じであれば探して？',
#  '[INGR]を使用した[AREA]の[SZN]に食べられる[PRON]が、あったら教えて欲しいです。',
#  '[INGR]か[INGR]が使われている、[AREA]の[SZN]に食べられる[PRON]をご存じであれば調べて頂けませんか？',
#  '[INGR]か[INGR]が使われている、[AREA]の[SZN]に食べられる[PRON]があったら、調べて頂きたいです。',
#  '[INGR]を使った[AREA]の[SZN]に食べられている、[PRON]について、教えて？',
#  '[INGR]を使った[AREA]の[SZN]に食べられている、[PRON]が、あったら教えて頂きたいです',
#  '[INGR]を使用した、[AREA]の[SZN]に食べられている[PRON]についてご存じでしたら探して？',
#  '[INGR]を使用した、[AREA]の[SZN]に食べられている[PRON]が、あったら、検索しろ。',
#  '[INGR]か[INGR]が使われている[AREA]の[SZN]に食べられている[PRON]について、ご存じであれば、検索して頂きたいです。',
#  '[INGR]か[INGR]が使われている[AREA]の[SZN]に食べられている[PRON]があったら、教えて。',
#  '[INGR]を使った[AREA]で、[SZN]に食べられる[PRON]をご存じであれば、検索して頂きたいです。',
#  '[INGR]を使った[AREA]で、[SZN]に食べられる[PRON]が、あれば、検索しろ',
#  '[INGR]を使用した[AREA]で[SZN]と[SZN]に食べられる[PRON]をご存じであれば検索して欲しいです',
#  '[INGR]を使用した[AREA]で[SZN]と[SZN]に食べられる[PRON]があれば、教えてくれませんか？',
#  '[INGR]が使われている、[AREA]で[SZN]に食べられる[PRON]を、ご存じであれば探して頂きたいです',
#  '[INGR]が使われている、[AREA]で[SZN]に食べられる[PRON]が、あれば、探して下さい。',
#  '[INGR]を使った[AREA]で[SZN]か[SZN]に食べられている[PRON]について、知ってたら検索',
#  '[INGR]を使った[AREA]で[SZN]か[SZN]に食べられている[PRON]が、あったら、調べて',
#  '[INGR]を使用した[AREA]で[SZN]に食べられている[PRON]について知ってたら調べて頂きたいです',
#  '[INGR]を使用した[AREA]で[SZN]に食べられている[PRON]が、あれば、調べろ。',
#  '[INGR]が使われている[AREA]で[SZN]に食べられている[PRON]についてご存じであれば、探してくれませんか？',
#  '[INGR]が使われている[AREA]で[SZN]に食べられている[PRON]があれば、教えろ。',
#  '[INGR]を使った[AREA]か[AREA]で食べられる[SZN]の[PRON]を、ご存じであれば、教えて？',
#  '[INGR]を使った[AREA]か[AREA]で食べられる[SZN]の[PRON]があったら検索して。',
#  '[INGR]を使用した、[AREA]で食べられる[SZN]か[SZN]の[PRON]について、ご存じであれば教えて欲しいです',
#  '[INGR]を使用した、[AREA]で食べられる[SZN]か[SZN]の[PRON]があったら、探して下さい',
#  '[INGR]か[INGR]が使われている[AREA]で食べられる[SZN]の[PRON]を、ご存じであれば、探して欲しいです。',
#  '[INGR]か[INGR]が使われている[AREA]で食べられる[SZN]の[PRON]が、あったら教えて欲しいです',
#  '[INGR]を使った[AREA]で食べられている、[SZN]の[PRON]を検索して？',
#  '[INGR]を使った[AREA]で食べられている、[SZN]の[PRON]があったら、探して欲しいです',
#  '[INGR]を使用した[AREA]または[AREA]で食べられている[SZN]の[PRON]を知ってたら、検索しろ。',
#  '[INGR]を使用した[AREA]または[AREA]で食べられている[SZN]の[PRON]が、あれば調べろ。',
#  '[INGR]が使われている[AREA]で食べられている、[SZN]の[PRON]について、ご存じであれば検索して頂きたいです。',
#  '[INGR]が使われている[AREA]で食べられている、[SZN]の[PRON]があったら、教えて欲しいです。',
#  '[INGR]、あるいは、[INGR]を使った[SZN]の、[AREA]の[PRON]を知ってたら検索して？',
#  '[INGR]、あるいは、[INGR]を使った[SZN]の、[AREA]の[PRON]が、あったら、教えて頂きたいです',
#  '[INGR]を使用した[SZN]か[SZN]の[AREA]の[PRON]についてご存じであれば、教えて頂けませんか？',
#  '[INGR]を使用した[SZN]か[SZN]の[AREA]の[PRON]が、あれば、探して欲しいです。',
#  '[INGR]が使われている[SZN]の、[AREA]の[PRON]を、知ってる？',
#  '[INGR]が使われている[SZN]の、[AREA]の[PRON]があれば、調べて欲しいです',
#  '[INGR]または[INGR]を使った[SZN]の、[AREA]で食べられる[PRON]をご存じでしたら調べて欲しいです',
#  '[INGR]または[INGR]を使った[SZN]の、[AREA]で食べられる[PRON]があったら、探して下さい。',
#  '[INGR]、あるいは、[INGR]を使用した[SZN]の[AREA]で食べられる[PRON]について、ご存じであれば調べて下さい',
#  '[INGR]、あるいは、[INGR]を使用した[SZN]の[AREA]で食べられる[PRON]が、あったら調べて頂けませんか？',
#  '[INGR]あるいは[INGR]が使われている[SZN]の[AREA]で食べられる[PRON]は知ってますか',
#  '[INGR]あるいは[INGR]が使われている[SZN]の[AREA]で食べられる[PRON]が、あったら、調べろ。',
#  '[INGR]、と、[INGR]を使った[SZN]の[AREA]で食べられている[PRON]について検索しろ',
#  '[INGR]、と、[INGR]を使った[SZN]の[AREA]で食べられている[PRON]があれば教えて欲しいです',
#  '[INGR]あるいは、[INGR]を使用した[SZN]の[AREA]で食べられている[PRON]をご存じであれば調べて頂きたいです。',
#  '[INGR]あるいは、[INGR]を使用した[SZN]の[AREA]で食べられている[PRON]が、あれば調べて頂きたいです。',
#  '[INGR]が使われている[SZN]の[AREA]で食べられている、[PRON]について教えろ。',
#  '[INGR]が使われている[SZN]の[AREA]で食べられている、[PRON]があれば、教えて',
#  '[INGR]を使った[SZN]に[AREA]で食べられる[PRON]についてご存じでしたら教えて頂きたいです。',
#  '[INGR]を使った[SZN]に[AREA]で食べられる[PRON]があったら検索して欲しいです。',
#  '[INGR]を使用した、[SZN]または、[SZN]に[AREA]で食べられる[PRON]についてご存じでしたら、探して頂きたいです。',
#  '[INGR]を使用した、[SZN]または、[SZN]に[AREA]で食べられる[PRON]があったら、探せ',
#  '[INGR]あるいは[INGR]が使われている[SZN]に[AREA]で食べられる[PRON]について教えて。',
#  '[INGR]あるいは[INGR]が使われている[SZN]に[AREA]で食べられる[PRON]があれば、教えろ',
#  '[INGR]を使った、[SZN]に[AREA]で食べられている[PRON]について、探して頂きたいです',
#  '[INGR]を使った、[SZN]に[AREA]で食べられている[PRON]があれば、教えて？',
#  '[INGR]を使用した[SZN]あるいは、[SZN]に[AREA]で食べられている[PRON]についてご存じでしたら検索して欲しいです',
#  '[INGR]を使用した[SZN]あるいは、[SZN]に[AREA]で食べられている[PRON]があれば、探して頂きたいです',
#  '[INGR]が使われている[SZN]あるいは[SZN]に[AREA]で食べられている、[PRON]を、知ってたら探して。',
#  '[INGR]が使われている[SZN]あるいは[SZN]に[AREA]で食べられている、[PRON]があったら探して？',
#  '[INGR]、か、[INGR]を使った[SZN]に食べられる、[AREA]の[PRON]について、ご存じであれば、検索して欲しいです。',
#  '[INGR]、か、[INGR]を使った[SZN]に食べられる、[AREA]の[PRON]が、あれば、教えて？',
#  '[INGR]を使用した、[SZN]に食べられる[AREA]の[PRON]を、教えて？',
#  '[INGR]を使用した、[SZN]に食べられる[AREA]の[PRON]が、あったら、検索して。',
#  '[INGR]が使われている[SZN]に食べられる、[AREA]と、[AREA]の[PRON]について、知ってたら、探して',
#  '[INGR]が使われている[SZN]に食べられる、[AREA]と、[AREA]の[PRON]があったら、検索しろ',
#  '[INGR]を使った[SZN]に食べられている[AREA]の[PRON]についてご存じであれば、探して頂きたいです',
#  '[INGR]を使った[SZN]に食べられている[AREA]の[PRON]があれば教えて頂きたいです。',
#  '[INGR]を使用した[SZN]に食べられている、[AREA]あるいは[AREA]の[PRON]を、ご存じであれば、探して。',
#  '[INGR]を使用した[SZN]に食べられている、[AREA]あるいは[AREA]の[PRON]があれば、探して下さい',
#  '[INGR]または[INGR]が使われている[SZN]に食べられている[AREA]の[PRON]を、ご存じであれば、探して頂きたいです',
#  '[INGR]または[INGR]が使われている[SZN]に食べられている[AREA]の[PRON]があれば探して欲しいです。',
#  '[TYPE]で[SZN]の[INGR]を使った[PRON]についてご存じであれば、検索してくれませんか？',
#  '[TYPE]で[SZN]の[INGR]を使った[PRON]が、あれば検索',
#  '[TYPE]で、[SZN]の[INGR]を使用した[PRON]について、ご存じであれば、探して欲しいです',
#  '[TYPE]で、[SZN]の[INGR]を使用した[PRON]が、あれば探せ。',
#  '[TYPE]で[SZN]、か[SZN]の[INGR]が使われている[PRON]について、知ってたら、検索',
#  '[TYPE]で[SZN]、か[SZN]の[INGR]が使われている[PRON]があったら調べて頂きたいです。',
#  '[TYPE]で[SZN]、か、[SZN]に食べられる[INGR]を使った[PRON]を知ってたら調べて',
#  '[TYPE]で[SZN]、か、[SZN]に食べられる[INGR]を使った[PRON]が、あったら調べてくれませんか？',
#  '[TYPE]で[SZN]に食べられる[INGR]を使用した[PRON]は、知ってる？',
#  '[TYPE]で[SZN]に食べられる[INGR]を使用した[PRON]があれば、調べて',
#  '[TYPE]または、[TYPE]で[SZN]に食べられる[INGR]が使われている[PRON]を、ご存じでしたら、教えて頂きたいです',
#  '[TYPE]または、[TYPE]で[SZN]に食べられる[INGR]が使われている[PRON]があったら検索しろ。',
#  '[TYPE]で[SZN]に食べられている[INGR]と[INGR]を使った[PRON]について知ってたら教えろ。',
#  '[TYPE]で[SZN]に食べられている[INGR]と[INGR]を使った[PRON]が、あれば、調べて下さい',
#  '[TYPE]で、[SZN]、と、[SZN]に食べられている[INGR]を使用した[PRON]について知ってたら、探して。',
#  '[TYPE]で、[SZN]、と、[SZN]に食べられている[INGR]を使用した[PRON]があれば検索して。',
#  '[TYPE]、あるいは、[TYPE]で[SZN]に食べられている[INGR]が使われている[PRON]について、ご存じであれば、調べて。',
#  '[TYPE]、あるいは、[TYPE]で[SZN]に食べられている[INGR]が使われている[PRON]があれば、検索しろ。',
#  '[TYPE]に[SZN]の[INGR]、あるいは[INGR]を使った[PRON]があれば調べて。',
#  '[TYPE]あるいは[TYPE]に[SZN]の[INGR]を使用した[PRON]が、あったら検索してくれませんか？',
#  '[TYPE]か、[TYPE]に[SZN]の、[INGR]が使われている[PRON]があれば、探せ',
#  '[TYPE]で[INGR]あるいは[INGR]を使った[SZN]の[PRON]についてご存じでしたら、調べて',
#  '[TYPE]で[INGR]あるいは[INGR]を使った[SZN]の[PRON]が、あったら、調べて？',
#  '[TYPE]で[INGR]、と[INGR]を使用した[SZN]の[PRON]を、検索。',
#  '[TYPE]で[INGR]、と[INGR]を使用した[SZN]の[PRON]が、あったら、教えて',
#  '[TYPE]、か[TYPE]で[INGR]が使われている[SZN]の、[PRON]を、ご存じでしたら、教えて。',
#  '[TYPE]、か[TYPE]で[INGR]が使われている[SZN]の、[PRON]が、あれば調べて下さい',
#  '[TYPE]で[INGR]を使った[SZN]に食べられる[PRON]について、ご存じでしたら、調べて。',
#  '[TYPE]で[INGR]を使った[SZN]に食べられる[PRON]があったら、探して頂きたいです。',
#  '[TYPE]で[INGR]を使用した[SZN]に食べられる[PRON]について、知ってたら検索して頂きたいです',
#  '[TYPE]で[INGR]を使用した[SZN]に食べられる[PRON]が、あったら、調べてくれませんか？',
#  '[TYPE]で[INGR]が使われている[SZN]、または[SZN]に食べられる[PRON]を、知ってたら探して頂けませんか？',
#  '[TYPE]で[INGR]が使われている[SZN]、または[SZN]に食べられる[PRON]があれば探してくれませんか？',
#  '[TYPE]で[INGR]を使った、[SZN]に食べられている[PRON]を、ご存じであれば検索して下さい。',
#  '[TYPE]で[INGR]を使った、[SZN]に食べられている[PRON]が、あったら検索して',
#  '[TYPE]で[INGR]を使用した[SZN]に食べられている[PRON]を、知ってたら教えて？',
#  '[TYPE]で[INGR]を使用した[SZN]に食べられている[PRON]があったら教えて下さい',
#  '[TYPE]で[INGR]、または[INGR]が使われている[SZN]に食べられている[PRON]についてご存じであれば、検索して頂けませんか？',
#  '[TYPE]で[INGR]、または[INGR]が使われている[SZN]に食べられている[PRON]が、あれば調べて欲しいです。',
#  '[TYPE]に[INGR]を使った[SZN]の[PRON]があれば調べて欲しいです。',
#  '[TYPE]に[INGR]を使用した、[SZN]の[PRON]が、あれば、教えて。',
#  '[TYPE]に[INGR]が使われている[SZN]または[SZN]の[PRON]があれば、探して欲しいです。',
#  '[SZN]か[SZN]の[TYPE]で、[INGR]を使った[PRON]を知ってたら、検索して欲しいです',
#  '[SZN]か[SZN]の[TYPE]で、[INGR]を使った[PRON]が、あれば、教えて頂きたいです',
#  '[SZN]、または、[SZN]の[TYPE]で、[INGR]を使用した[PRON]をご存じでしたら、調べてくれませんか？',
#  '[SZN]、または、[SZN]の[TYPE]で、[INGR]を使用した[PRON]が、あったら調べて頂きたいです',
#  '[SZN]、あるいは、[SZN]の[TYPE]で、[INGR]が使われている[PRON]を、知ってたら、教えて欲しいです。',
#  '[SZN]、あるいは、[SZN]の[TYPE]で、[INGR]が使われている[PRON]が、あったら教えて頂けませんか？',
#  '[SZN]の[TYPE]または[TYPE]に[INGR]を使った、[PRON]があったら、検索して頂きたいです',
#  '[SZN]の、[TYPE]に[INGR]を使用した[PRON]が、あったら、教えて欲しいです。',
#  '[SZN]の[TYPE]に[INGR]、または、[INGR]が使われている[PRON]があったら探して',
#  '[SZN]に食べられる[TYPE]で、[INGR]を使った[PRON]を、ご存じでしたら、探して頂けませんか？',
#  '[SZN]に食べられる[TYPE]で、[INGR]を使った[PRON]が、あれば探してくれませんか？',
#  '[SZN]に食べられる、[TYPE]あるいは[TYPE]で[INGR]を使用した[PRON]について、ご存じでしたら検索して欲しいです。',
#  '[SZN]に食べられる、[TYPE]あるいは[TYPE]で[INGR]を使用した[PRON]が、あれば、検索して頂きたいです。',
#  '[SZN]、または[SZN]に食べられる、[TYPE]で[INGR]が使われている[PRON]についてご存じであれば、探して頂けませんか？',
#  '[SZN]、または[SZN]に食べられる、[TYPE]で[INGR]が使われている[PRON]が、あれば、教えて',
#  '[SZN]に食べられている[TYPE]で[INGR]を使った[PRON]について探して頂きたいです',
#  '[SZN]に食べられている[TYPE]で[INGR]を使った[PRON]が、あったら検索して頂きたいです',
#  '[SZN]に食べられている[TYPE]で[INGR]を使用した[PRON]を、ご存じでしたら、教えてくれませんか？',
#  '[SZN]に食べられている[TYPE]で[INGR]を使用した[PRON]があれば検索して',
#  '[SZN]に食べられている[TYPE]で、[INGR]が使われている[PRON]について、ご存じでしたら教えて下さい',
#  '[SZN]に食べられている[TYPE]で、[INGR]が使われている[PRON]が、あれば探して欲しいです',
#  '[SZN]の[INGR]を使った[TYPE]を知ってたら、調べて頂きたいです',
#  '[SZN]の[INGR]を使った[TYPE]があったら、探してくれませんか？',
#  '[SZN]の[INGR]か[INGR]を使用した[TYPE]についてご存じであれば調べてくれませんか？',
#  '[SZN]の[INGR]か[INGR]を使用した[TYPE]が、あれば検索して頂けませんか？',
#  '[SZN]の[INGR]が使われている[TYPE]について知ってたら、検索して頂きたいです',
#  '[SZN]の[INGR]が使われている[TYPE]があったら、検索して下さい',
#  '[SZN]に食べられる[INGR]を使った[TYPE]について、知ってたら、検索して下さい',
#  '[SZN]に食べられる[INGR]を使った[TYPE]があれば、教えて下さい',
#  '[SZN]か[SZN]に食べられる[INGR]を使用した[TYPE]を調べて頂きたいです。',
#  '[SZN]か[SZN]に食べられる[INGR]を使用した[TYPE]があれば調べて下さい',
#  '[SZN]に食べられる[INGR]が使われている、[TYPE]について、ご存じでしたら、検索して欲しいです。',
#  '[SZN]に食べられる[INGR]が使われている、[TYPE]が、あったら、検索して欲しいです。',
#  '[SZN]に食べられている[INGR]を使った[TYPE]をご存じであれば、探して欲しいです。',
#  '[SZN]に食べられている[INGR]を使った[TYPE]があれば探して頂けませんか？',
#  '[SZN]に食べられている[INGR]を使用した[TYPE]か[TYPE]について、ご存じでしたら検索して',
#  '[SZN]に食べられている[INGR]を使用した[TYPE]か[TYPE]が、あれば、調べて。',
#  '[SZN]あるいは[SZN]に食べられている[INGR]が使われている[TYPE]をご存じでしたら教えて頂けませんか？',
#  '[SZN]あるいは[SZN]に食べられている[INGR]が使われている[TYPE]があれば、探して下さい。',
#  '[INGR]か[INGR]を使った[TYPE]で[SZN]の、[PRON]について、ご存じでしたら探して',
#  '[INGR]か[INGR]を使った[TYPE]で[SZN]の、[PRON]があれば、調べて下さい。',
#  '[INGR]を使用した[TYPE]で[SZN]の[PRON]についてご存じでしたら調べて欲しいです',
#  '[INGR]を使用した[TYPE]で[SZN]の[PRON]があれば、教えて欲しいです。',
#  '[INGR]と、[INGR]が使われている[TYPE]で[SZN]の[PRON]を、知ってたら、教えて',
#  '[INGR]と、[INGR]が使われている[TYPE]で[SZN]の[PRON]が、あれば、検索して頂きたいです',
#  '[INGR]を使った[TYPE]で、[SZN]に食べられる[PRON]を、ご存じでしたら教えて欲しいです。',
#  '[INGR]を使った[TYPE]で、[SZN]に食べられる[PRON]があれば、探せ。',
#  '[INGR]を使用した[TYPE]、あるいは、[TYPE]で[SZN]に食べられる[PRON]を、検索して下さい。',
#  '[INGR]を使用した[TYPE]、あるいは、[TYPE]で[SZN]に食べられる[PRON]が、あったら、教えろ',
#  '[INGR]が使われている[TYPE]で[SZN]に食べられる、[PRON]についてご存じであれば探して頂きたいです。',
#  '[INGR]が使われている[TYPE]で[SZN]に食べられる、[PRON]があれば検索して頂きたいです',
#  '[INGR]を使った、[TYPE]か[TYPE]で[SZN]に食べられている[PRON]を、ご存じでしたら、探して欲しいです',
#  '[INGR]を使った、[TYPE]か[TYPE]で[SZN]に食べられている[PRON]があれば、教えて頂けませんか？',
#  '[INGR]を使用した[TYPE]で[SZN]、あるいは、[SZN]に食べられている[PRON]をご存じでしたら教えて欲しいです',
#  '[INGR]を使用した[TYPE]で[SZN]、あるいは、[SZN]に食べられている[PRON]が、あれば、検索して下さい',
#  '[INGR]が使われている[TYPE]か、[TYPE]で[SZN]に食べられている[PRON]について知ってますか。',
#  '[INGR]が使われている[TYPE]か、[TYPE]で[SZN]に食べられている[PRON]が、あれば調べて？',
#  '[INGR]、か、[INGR]を使った[TYPE]に[SZN]の、[PRON]が、あったら、検索',
#  '[INGR]あるいは[INGR]を使用した、[TYPE]に[SZN]の[PRON]があったら探せ。',
#  '[INGR]が使われている[TYPE]に[SZN]の[PRON]が、あれば、調べて頂きたいです',
#  '[INGR]を使った[SZN]の[TYPE]について、ご存じであれば、検索してくれませんか？',
#  '[INGR]を使った[SZN]の[TYPE]があったら教えて頂けませんか？',
#  '[INGR]と、[INGR]を使用した、[SZN]の[TYPE]について、ご存じであれば、検索して？',
#  '[INGR]と、[INGR]を使用した、[SZN]の[TYPE]が、あれば、探して頂けませんか？',
#  '[INGR]が使われている、[SZN]、あるいは、[SZN]の[TYPE]を調べて頂きたいです',
#  '[INGR]が使われている、[SZN]、あるいは、[SZN]の[TYPE]が、あれば調べてくれませんか？',
#  '[INGR]を使った、[SZN]か[SZN]に食べられる[TYPE]について教えて頂きたいです',
#  '[INGR]を使った、[SZN]か[SZN]に食べられる[TYPE]があれば、検索して下さい。',
#  '[INGR]を使用した[SZN]に食べられる、[TYPE]または[TYPE]を知ってたら探して。',
#  '[INGR]を使用した[SZN]に食べられる、[TYPE]または[TYPE]があったら、検索して。',
#  '[INGR]が使われている[SZN]に食べられる、[TYPE]をご存じでしたら、検索して頂きたいです',
#  '[INGR]が使われている[SZN]に食べられる、[TYPE]があれば、検索',
#  '[INGR]を使った[SZN]に食べられている[TYPE]と[TYPE]について、ご存じであれば、探して頂けませんか？',
#  '[INGR]を使った[SZN]に食べられている[TYPE]と[TYPE]が、あれば、検索して頂きたいです',
#  '[INGR]または、[INGR]を使用した[SZN]に食べられている、[TYPE]について、ご存じでしたら検索して？',
#  '[INGR]または、[INGR]を使用した[SZN]に食べられている、[TYPE]が、あれば、調べろ。',
#  '[INGR]が使われている[SZN]に食べられている[TYPE]と、[TYPE]についてご存じでしたら探して欲しいです',
#  '[INGR]が使われている[SZN]に食べられている[TYPE]と、[TYPE]があったら教えて欲しいです',
#  '[AREA]の[TYPE]で[SZN]あるいは、[SZN]の[INGR]を使った[PRON]を、ご存じでしたら、調べて欲しいです。',
#  '[AREA]の[TYPE]で[SZN]あるいは、[SZN]の[INGR]を使った[PRON]があれば、探して下さい',
#  '[AREA]の[TYPE]で[SZN]の[INGR]を使用した[PRON]を、ご存じでしたら調べて下さい。',
#  '[AREA]の[TYPE]で[SZN]の[INGR]を使用した[PRON]があれば教えて欲しいです。',
#  '[AREA]の[TYPE]で[SZN]の[INGR]が使われている[PRON]を、検索しろ',
#  '[AREA]の[TYPE]で[SZN]の[INGR]が使われている[PRON]が、あれば教えろ。',
#  '[AREA]か[AREA]の、[TYPE]で[SZN]に食べられる[INGR]を使った[PRON]を、ご存じであれば調べて頂きたいです',
#  '[AREA]か[AREA]の、[TYPE]で[SZN]に食べられる[INGR]を使った[PRON]があったら、教えろ。',
#  '[AREA]または、[AREA]の[TYPE]で[SZN]に食べられる[INGR]を使用した[PRON]についてご存じでしたら、探して',
#  '[AREA]または、[AREA]の[TYPE]で[SZN]に食べられる[INGR]を使用した[PRON]が、あれば調べて。',
#  '[AREA]あるいは[AREA]の[TYPE]で[SZN]に食べられる[INGR]が使われている[PRON]をご存じでしたら検索して。',
#  '[AREA]あるいは[AREA]の[TYPE]で[SZN]に食べられる[INGR]が使われている[PRON]が、あったら調べろ',
#  '[AREA]の[TYPE]または[TYPE]で[SZN]に食べられている、[INGR]を使った[PRON]を、知ってたら、教えて頂きたいです。',
#  '[AREA]の[TYPE]または[TYPE]で[SZN]に食べられている、[INGR]を使った[PRON]が、あったら調べて下さい',
#  '[AREA]の[TYPE]で[SZN]に食べられている[INGR]を使用した[PRON]をご存じであれば、探して',
#  '[AREA]の[TYPE]で[SZN]に食べられている[INGR]を使用した[PRON]があれば教えろ',
#  '[AREA]の[TYPE]で、[SZN]に食べられている[INGR]が使われている[PRON]についてご存じであれば検索して。',
#  '[AREA]の[TYPE]で、[SZN]に食べられている[INGR]が使われている[PRON]が、あったら調べてくれませんか？',
#  '[AREA]の[TYPE]に[SZN]の、[INGR]を使った[PRON]があったら検索して下さい',
#  '[AREA]の[TYPE]あるいは[TYPE]に[SZN]の、[INGR]を使用した[PRON]が、あれば調べろ',
#  '[AREA]あるいは[AREA]の[TYPE]に[SZN]の[INGR]が使われている[PRON]が、あったら検索して下さい。',
#  '[AREA]で[TYPE]で[SZN]、か、[SZN]の、[INGR]を使った[PRON]をご存じでしたら、教えて下さい',
#  '[AREA]で[TYPE]で[SZN]、か、[SZN]の、[INGR]を使った[PRON]が、あれば教えて',
#  '[AREA]で、[TYPE]か[TYPE]で[SZN]の[INGR]を使用した[PRON]をご存じでしたら、探して',
#  '[AREA]で、[TYPE]か[TYPE]で[SZN]の[INGR]を使用した[PRON]が、あったら教えろ。',
#  '[AREA]で[TYPE]、か[TYPE]で[SZN]の[INGR]が使われている、[PRON]についてご存じでしたら、教えて。',
#  '[AREA]で[TYPE]、か[TYPE]で[SZN]の[INGR]が使われている、[PRON]があれば検索して下さい',
#  '[AREA]、と[AREA]で[TYPE]で[SZN]に食べられる[INGR]を使った[PRON]について、知ってたら、調べて頂きたいです。',
#  '[AREA]、と[AREA]で[TYPE]で[SZN]に食べられる[INGR]を使った[PRON]が、あったら検索。',
#  '[AREA]、あるいは[AREA]で[TYPE]で、[SZN]に食べられる[INGR]を使用した[PRON]について、ご存じでしょうか',
#  '[AREA]、あるいは[AREA]で[TYPE]で、[SZN]に食べられる[INGR]を使用した[PRON]が、あったら探して頂きたいです。',
#  '[AREA]と、[AREA]で[TYPE]で[SZN]に食べられる[INGR]が使われている[PRON]を、知ってたら、調べて下さい',
#  '[AREA]と、[AREA]で[TYPE]で[SZN]に食べられる[INGR]が使われている[PRON]が、あれば調べろ。',
#  '[AREA]で、[TYPE]または[TYPE]で[SZN]に食べられている[INGR]を使った[PRON]について、知ってたら、教えて。',
#  '[AREA]で、[TYPE]または[TYPE]で[SZN]に食べられている[INGR]を使った[PRON]があれば、調べて？',
#  '[AREA]で、[TYPE]で[SZN]、か[SZN]に食べられている[INGR]を使用した[PRON]を、ご存じであれば教えて頂きたいです。',
#  '[AREA]で、[TYPE]で[SZN]、か[SZN]に食べられている[INGR]を使用した[PRON]が、あったら探して欲しいです',
#  '[AREA]で[TYPE]か[TYPE]で[SZN]に食べられている、[INGR]が使われている[PRON]を、知ってたら、調べて下さい。',
#  '[AREA]で[TYPE]か[TYPE]で[SZN]に食べられている、[INGR]が使われている[PRON]が、あれば、探して下さい',
#  '[AREA]と[AREA]で[TYPE]に[SZN]の[INGR]を使った[PRON]について、教えて下さい',
#  '[AREA]と[AREA]で[TYPE]に[SZN]の[INGR]を使った[PRON]が、あれば探して',
#  '[AREA]で[TYPE]または[TYPE]に[SZN]の[INGR]を使用した、[PRON]について、知ってます？',
#  '[AREA]で[TYPE]または[TYPE]に[SZN]の[INGR]を使用した、[PRON]が、あれば探してくれませんか？',
#  '[AREA]で[TYPE]に[SZN]の[INGR]が使われている[PRON]をご存じでしたら、探して頂きたいです。',
#  '[AREA]で[TYPE]に[SZN]の[INGR]が使われている[PRON]があったら検索して欲しいです',
#  '[AREA]で食べられる、[TYPE]で[SZN]の[INGR]あるいは[INGR]を使った[PRON]について教えて頂きたいです。',
#  '[AREA]で食べられる、[TYPE]で[SZN]の[INGR]あるいは[INGR]を使った[PRON]があったら教えて下さい',
#  '[AREA]で食べられる、[TYPE]または[TYPE]で[SZN]の[INGR]を使用した[PRON]についてご存じであれば探して欲しいです',
#  '[AREA]で食べられる、[TYPE]または[TYPE]で[SZN]の[INGR]を使用した[PRON]が、あったら、調べて？',
#  '[AREA]で食べられる、[TYPE]で[SZN]の[INGR]が使われている[PRON]を知ってたら検索しろ。',
#  '[AREA]で食べられる、[TYPE]で[SZN]の[INGR]が使われている[PRON]があったら、調べろ。',
#  '[AREA]または、[AREA]で食べられている[TYPE]で[SZN]の[INGR]を使った、[PRON]について教えて頂けませんか？',
#  '[AREA]または、[AREA]で食べられている[TYPE]で[SZN]の[INGR]を使った、[PRON]が、あれば調べて？',
#  '[AREA]で食べられている[TYPE]で[SZN]の[INGR]を使用した[PRON]について知ってたら検索。',
#  '[AREA]で食べられている[TYPE]で[SZN]の[INGR]を使用した[PRON]があれば、探して頂けませんか？',
#  '[AREA]と[AREA]で食べられている[TYPE]で[SZN]の、[INGR]が使われている[PRON]について、探して頂けませんか？',
#  '[AREA]と[AREA]で食べられている[TYPE]で[SZN]の、[INGR]が使われている[PRON]があったら調べて。',
#  '[AREA]で食べられる[TYPE]に[SZN]の[INGR]あるいは[INGR]を使った[PRON]が、あれば検索して下さい。',
#  '[AREA]あるいは、[AREA]で食べられる[TYPE]に、[SZN]の[INGR]を使用した[PRON]が、あれば、検索して下さい',
#  '[AREA]で食べられる[TYPE]に、[SZN]と[SZN]の[INGR]が使われている[PRON]が、あったら検索して欲しいです。',
#  '[AREA]で食べられている[TYPE]に、[SZN]の[INGR]を使った[PRON]があったら教えて',
#  '[AREA]または[AREA]で食べられている、[TYPE]に[SZN]の[INGR]を使用した[PRON]が、あったら調べて',
#  '[AREA]で食べられている、[TYPE]に[SZN]の[INGR]が使われている[PRON]が、あったら検索して？',
#  '[AREA]に[TYPE]、か、[TYPE]で[SZN]の[INGR]を使った[PRON]が、あれば探して頂きたいです。',
#  '[AREA]に[TYPE]で、[SZN]、と[SZN]の[INGR]を使用した[PRON]が、あったら、調べろ',
#  '[AREA]と[AREA]に[TYPE]で[SZN]の[INGR]が使われている[PRON]があったら、検索して',
#  '[AREA]の[TYPE]で[INGR]を使った[SZN]または、[SZN]の[PRON]をご存じであれば検索して下さい。',
#  '[AREA]の[TYPE]で[INGR]を使った[SZN]または、[SZN]の[PRON]が、あれば、探して？',
#  '[AREA]と[AREA]の[TYPE]で、[INGR]を使用した[SZN]の[PRON]について、ご存じでしたら、検索して頂きたいです。',
#  '[AREA]と[AREA]の[TYPE]で、[INGR]を使用した[SZN]の[PRON]が、あれば、探して欲しいです',
#  '[AREA]の、[TYPE]で[INGR]が使われている[SZN]の[PRON]について、ご存じであれば探して',
#  '[AREA]の、[TYPE]で[INGR]が使われている[SZN]の[PRON]があったら、調べて欲しいです',
#  '[AREA]または[AREA]の[TYPE]で、[INGR]を使った[SZN]に食べられる[PRON]について、ご存じであれば検索して欲しいです',
#  '[AREA]または[AREA]の[TYPE]で、[INGR]を使った[SZN]に食べられる[PRON]があったら検索して頂きたいです。',
#  '[AREA]の[TYPE]で[INGR]を使用した[SZN]に食べられる[PRON]を、調べろ',
#  '[AREA]の[TYPE]で[INGR]を使用した[SZN]に食べられる[PRON]が、あったら、検索しろ。',
#  '[AREA]の、[TYPE]または[TYPE]で[INGR]が使われている[SZN]に食べられる[PRON]について探して。',
#  '[AREA]の、[TYPE]または[TYPE]で[INGR]が使われている[SZN]に食べられる[PRON]があれば教えて欲しいです',
#  '[AREA]の[TYPE]で、[INGR]を使った[SZN]に食べられている[PRON]を、知ってたら調べろ。',
#  '[AREA]の[TYPE]で、[INGR]を使った[SZN]に食べられている[PRON]が、あれば、検索して欲しいです。',
#  '[AREA]の[TYPE]で[INGR]、または[INGR]を使用した[SZN]に食べられている[PRON]を知ってたら、調べてくれませんか？',
#  '[AREA]の[TYPE]で[INGR]、または[INGR]を使用した[SZN]に食べられている[PRON]があったら教えろ。',
#  '[AREA]の[TYPE]で[INGR]と[INGR]が使われている[SZN]に食べられている[PRON]についてご存じであれば検索して？',
#  '[AREA]の[TYPE]で[INGR]と[INGR]が使われている[SZN]に食べられている[PRON]が、あれば、検索しろ。',
#  '[AREA]の[TYPE]または、[TYPE]に[INGR]を使った[SZN]の、[PRON]が、あったら検索して頂けませんか？',
#  '[AREA]の[TYPE]に[INGR]か、[INGR]を使用した[SZN]の[PRON]があったら、探して。',
#  '[AREA]あるいは[AREA]の[TYPE]に、[INGR]が使われている[SZN]の[PRON]が、あったら、探して？',
#  '[AREA]で[TYPE]で[INGR]か[INGR]を使った[SZN]の[PRON]をご存じであれば教えてくれませんか？',
#  '[AREA]で[TYPE]で[INGR]か[INGR]を使った[SZN]の[PRON]があれば検索',
#  '[AREA]で[TYPE]か[TYPE]で[INGR]を使用した[SZN]の[PRON]をご存じでしたら、教えて欲しいです。',
#  '[AREA]で[TYPE]か[TYPE]で[INGR]を使用した[SZN]の[PRON]があったら、教えて。',
#  '[AREA]で[TYPE]で、[INGR]あるいは[INGR]が使われている[SZN]の[PRON]を知ってたら教えて下さい。',
#  '[AREA]で[TYPE]で、[INGR]あるいは[INGR]が使われている[SZN]の[PRON]はありますか？',
#  '[AREA]か、[AREA]で[TYPE]で[INGR]を使った、[SZN]に食べられる[PRON]を、ご存じでしたら調べて？',
#  '[AREA]か、[AREA]で[TYPE]で[INGR]を使った、[SZN]に食べられる[PRON]があったら、教えてくれませんか？',
#  '[AREA]で、[TYPE]か[TYPE]で[INGR]を使用した[SZN]に食べられる[PRON]についてご存じであれば、探して下さい。',
#  '[AREA]で、[TYPE]か[TYPE]で[INGR]を使用した[SZN]に食べられる[PRON]が、あれば、検索して頂きたいです。',
#  '[AREA]で[TYPE]で[INGR]と、[INGR]が使われている[SZN]に食べられる[PRON]について、ご存じでしたら、教えて？',
#  '[AREA]で[TYPE]で[INGR]と、[INGR]が使われている[SZN]に食べられる[PRON]があれば教えて頂きたいです',
#  '[AREA]で[TYPE]で[INGR]、あるいは[INGR]を使った、[SZN]に食べられている[PRON]を知ってたら探して？',
#  '[AREA]で[TYPE]で[INGR]、あるいは[INGR]を使った、[SZN]に食べられている[PRON]が、あれば探せ。',
#  '[AREA]で[TYPE]で[INGR]を使用した[SZN]に食べられている[PRON]について知ってたら、検索して下さい。',
#  '[AREA]で[TYPE]で[INGR]を使用した[SZN]に食べられている[PRON]が、あったら、調べて下さい。',
#  '[AREA]で[TYPE]で[INGR]が使われている、[SZN]に食べられている[PRON]について知ってたら、探して下さい。',
#  '[AREA]で[TYPE]で[INGR]が使われている、[SZN]に食べられている[PRON]が、あったら、調べてくれませんか？',
#  '[AREA]で[TYPE]に[INGR]を使った、[SZN]の[PRON]について、調べて。',
#  '[AREA]で[TYPE]に[INGR]を使った、[SZN]の[PRON]があったら、教えて頂きたいです',
#  '[AREA]で[TYPE]に[INGR]を使用した[SZN]の、[PRON]について知ってたら調べて？',
#  '[AREA]で[TYPE]に[INGR]を使用した[SZN]の、[PRON]が、あったら、検索して下さい',
#  '[AREA]、か[AREA]で[TYPE]に[INGR]が使われている[SZN]の[PRON]を、知ってたら、探して欲しいです。',
#  '[AREA]、か[AREA]で[TYPE]に[INGR]が使われている[SZN]の[PRON]が、あったら検索しろ。',
#  '[AREA]で食べられる[TYPE]で[INGR]か、[INGR]を使った[SZN]の[PRON]について、ご存じでしたら探して下さい。',
#  '[AREA]で食べられる[TYPE]で[INGR]か、[INGR]を使った[SZN]の[PRON]が、あったら探して頂きたいです',
#  '[AREA]か[AREA]で食べられる[TYPE]で[INGR]を使用した[SZN]の[PRON]を、ご存じであれば、探して下さい',
#  '[AREA]か[AREA]で食べられる[TYPE]で[INGR]を使用した[SZN]の[PRON]が、あったら、教えて頂きたいです。',
#  '[AREA]か[AREA]で食べられる[TYPE]で[INGR]が使われている[SZN]の[PRON]について、ご存じでしたら、教えて欲しいです',
#  '[AREA]か[AREA]で食べられる[TYPE]で[INGR]が使われている[SZN]の[PRON]があったら探せ',
#  '[AREA]で食べられている[TYPE]で[INGR]を使った[SZN]の、[PRON]についてご存じであれば、調べて？',
#  '[AREA]で食べられている[TYPE]で[INGR]を使った[SZN]の、[PRON]が、あれば、検索して。',
#  '[AREA]で食べられている、[TYPE]で[INGR]を使用した[SZN]の[PRON]をご存じでしたら、教えて頂きたいです。',
#  '[AREA]で食べられている、[TYPE]で[INGR]を使用した[SZN]の[PRON]が、あれば探せ',
#  '[AREA]、か[AREA]で食べられている[TYPE]で、[INGR]が使われている[SZN]の[PRON]を、ご存じでしたら、調べて下さい',
#  '[AREA]、か[AREA]で食べられている[TYPE]で、[INGR]が使われている[SZN]の[PRON]が、あったら、探して。',
#  '[AREA]で食べられる[TYPE]、または[TYPE]に[INGR]を使った[SZN]の[PRON]が、あったら、検索',
#  '[AREA]で食べられる、[TYPE]と[TYPE]に[INGR]を使用した[SZN]の[PRON]が、あったら、教えて',
#  '[AREA]で食べられる[TYPE]、または、[TYPE]に[INGR]が使われている[SZN]の[PRON]があったら、教えて',
#  '[AREA]で食べられている[TYPE]に[INGR]を使った[SZN]の[PRON]があったら探して？',
#  '[AREA]で食べられている[TYPE]に[INGR]を使用した[SZN]の[PRON]があれば調べろ',
#  '[AREA]あるいは[AREA]で食べられている、[TYPE]に[INGR]が使われている[SZN]の[PRON]があれば調べて下さい。',
#  '[AREA]に[TYPE]で[INGR]を使った、[SZN]の[PRON]が、あったら教えて頂きたいです。',
#  '[AREA]に、[TYPE]で[INGR]または[INGR]を使用した[SZN]の[PRON]が、あれば、調べてくれませんか？',
#  '[AREA]に、[TYPE]、または、[TYPE]で[INGR]が使われている[SZN]の[PRON]があれば探して頂けませんか？',
#  '[AREA]の[SZN]、と[SZN]の[TYPE]で、[INGR]を使った[PRON]についてご存じでしたら、検索して？',
#  '[AREA]の[SZN]、と[SZN]の[TYPE]で、[INGR]を使った[PRON]が、あったら探して',
#  '[AREA]の[SZN]の[TYPE]で、[INGR]を使用した[PRON]について、ご存じでしたら、調べて',
#  '[AREA]の[SZN]の[TYPE]で、[INGR]を使用した[PRON]があれば調べて欲しいです',
#  '[AREA]、あるいは[AREA]の[SZN]の[TYPE]で[INGR]が使われている[PRON]についてご存じでしたら検索して下さい。',
#  '[AREA]、あるいは[AREA]の[SZN]の[TYPE]で[INGR]が使われている[PRON]があったら調べてくれませんか？',
#  '[AREA]か[AREA]の[SZN]の[TYPE]に[INGR]を使った[PRON]があれば探してくれませんか？',
#  '[AREA]、と、[AREA]の、[SZN]の[TYPE]に[INGR]を使用した[PRON]が、あれば検索して下さい',
#  '[AREA]の[SZN]の[TYPE]に[INGR]または、[INGR]が使われている[PRON]が、あれば、探してくれませんか？',
#  '[AREA]の、[SZN]に食べられる[TYPE]で[INGR]を使った[PRON]をご存じであれば、教えて頂きたいです。',
#  '[AREA]の、[SZN]に食べられる[TYPE]で[INGR]を使った[PRON]があったら、探して頂きたいです。',
#  '[AREA]の[SZN]に食べられる[TYPE]、または[TYPE]で、[INGR]を使用した[PRON]について、知ってたら探して',
#  '[AREA]の[SZN]に食べられる[TYPE]、または[TYPE]で、[INGR]を使用した[PRON]が、あったら調べて下さい。',
#  '[AREA]の、[SZN]に食べられる[TYPE]で[INGR]か、[INGR]が使われている[PRON]を知ってたら、検索して',
#  '[AREA]の、[SZN]に食べられる[TYPE]で[INGR]か、[INGR]が使われている[PRON]があったら、探して欲しいです',
#  '[AREA]の[SZN]に食べられている、[TYPE]で[INGR]を使った[PRON]について、ご存じであれば探して頂きたいです',
#  '[AREA]の[SZN]に食べられている、[TYPE]で[INGR]を使った[PRON]があれば、教えて頂けませんか？',
#  '[AREA]の[SZN]、あるいは、[SZN]に食べられている、[TYPE]で[INGR]を使用した[PRON]を、ご存じでしたら教えて頂きたいです。',
#  '[AREA]の[SZN]、あるいは、[SZN]に食べられている、[TYPE]で[INGR]を使用した[PRON]が、あったら、教えろ。',
#  '[AREA]の[SZN]、と[SZN]に食べられている[TYPE]で[INGR]が使われている[PRON]について、知ってますか？',
#  '[AREA]の[SZN]、と[SZN]に食べられている[TYPE]で[INGR]が使われている[PRON]が、あれば検索して',
#  '[AREA]で[SZN]の[TYPE]に[INGR]を使った[PRON]を、知ってたら、探して下さい。',
#  '[AREA]で[SZN]の[TYPE]に[INGR]を使った[PRON]が、あったら探して下さい。',
#  '[AREA]で[SZN]と[SZN]の[TYPE]に[INGR]を使用した[PRON]を、ご存じであれば、検索して欲しいです。',
#  '[AREA]で[SZN]と[SZN]の[TYPE]に[INGR]を使用した[PRON]があれば検索して。',
#  '[AREA]あるいは、[AREA]で[SZN]の[TYPE]に[INGR]が使われている[PRON]について、ご存じでしたら教えてくれませんか？',
#  '[AREA]あるいは、[AREA]で[SZN]の[TYPE]に[INGR]が使われている[PRON]があれば探して下さい。',
#  '[AREA]で[SZN]に食べられる[TYPE]で[INGR]を使った、[PRON]を、ご存じであれば、教えて欲しいです。',
#  '[AREA]で[SZN]に食べられる[TYPE]で[INGR]を使った、[PRON]があれば、検索して',
#  '[AREA]で[SZN]あるいは[SZN]に食べられる[TYPE]で[INGR]を使用した[PRON]について、ご存じであれば、調べて頂けませんか？',
#  '[AREA]で[SZN]あるいは[SZN]に食べられる[TYPE]で[INGR]を使用した[PRON]があれば、調べろ。',
#  '[AREA]あるいは、[AREA]で[SZN]に食べられる[TYPE]で[INGR]が使われている[PRON]をご存じであれば探して欲しいです',
#  '[AREA]あるいは、[AREA]で[SZN]に食べられる[TYPE]で[INGR]が使われている[PRON]が、あれば、教えて頂きたいです。',
#  '[AREA]で、[SZN]に食べられている[TYPE]で[INGR]と[INGR]を使った[PRON]についてご存じであれば探して頂けませんか？',
#  '[AREA]で、[SZN]に食べられている[TYPE]で[INGR]と[INGR]を使った[PRON]があったら、調べて下さい',
#  '[AREA]で、[SZN]に食べられている[TYPE]で[INGR]を使用した[PRON]について探して欲しいです。',
#  '[AREA]で、[SZN]に食べられている[TYPE]で[INGR]を使用した[PRON]があれば検索して欲しいです。',
#  '[AREA]で[SZN]、あるいは[SZN]に食べられている[TYPE]で[INGR]が使われている、[PRON]を知ってたら、探して下さい',
#  '[AREA]で[SZN]、あるいは[SZN]に食べられている[TYPE]で[INGR]が使われている、[PRON]が、あったら、教えてくれませんか？',
#  '[AREA]で食べられる[SZN]の[TYPE]、または、[TYPE]で[INGR]を使った[PRON]について、ご存じであれば検索して',
#  '[AREA]で食べられる[SZN]の[TYPE]、または、[TYPE]で[INGR]を使った[PRON]が、あったら、調べて頂けませんか？',
#  '[AREA]または[AREA]で食べられる[SZN]の[TYPE]で[INGR]を使用した[PRON]を、検索して',
#  '[AREA]または[AREA]で食べられる[SZN]の[TYPE]で[INGR]を使用した[PRON]が、あれば調べて下さい。',
#  '[AREA]で食べられる[SZN]か[SZN]の[TYPE]で[INGR]が使われている[PRON]について、知ってたら、調べて。',
#  '[AREA]で食べられる[SZN]か[SZN]の[TYPE]で[INGR]が使われている[PRON]が、あれば探して欲しいです',
#  '[AREA]、か[AREA]で食べられている[SZN]の[TYPE]で[INGR]を使った[PRON]をご存じであれば、教えて。',
#  '[AREA]、か[AREA]で食べられている[SZN]の[TYPE]で[INGR]を使った[PRON]があったら、教えて頂けませんか？',
#  '[AREA]で食べられている[SZN]か[SZN]の[TYPE]で[INGR]を使用した[PRON]について、知ってたら、調べて下さい',
#  '[AREA]で食べられている[SZN]か[SZN]の[TYPE]で[INGR]を使用した[PRON]があれば、検索してくれませんか？',
#  '[AREA]で食べられている[SZN]の[TYPE]で[INGR]が使われている[PRON]についてご存じであれば、調べて下さい',
#  '[AREA]で食べられている[SZN]の[TYPE]で[INGR]が使われている[PRON]が、あれば、検索して？',
#  '[AREA]または[AREA]で食べられる、[SZN]の[TYPE]に[INGR]を使った[PRON]があれば、探せ',
#  '[AREA]で食べられる[SZN]の[TYPE]に[INGR]を使用した[PRON]があれば、調べてくれませんか？',
#  '[AREA]と、[AREA]で食べられる、[SZN]の[TYPE]に[INGR]が使われている[PRON]があったら、探して頂けませんか？',
#  '[AREA]で食べられている[SZN]の[TYPE]に[INGR]と[INGR]を使った[PRON]が、あれば、教えて欲しいです。',
#  '[AREA]と、[AREA]で食べられている、[SZN]の[TYPE]に[INGR]を使用した[PRON]があれば調べて頂きたいです。',
#  '[AREA]で食べられている[SZN]の[TYPE]に[INGR]が使われている[PRON]があったら、探して下さい',
#  '[AREA]に[SZN]または[SZN]の[TYPE]で[INGR]を使った[PRON]が、あったら検索して頂きたいです',
#  '[AREA]に[SZN]の[TYPE]で[INGR]を使用した[PRON]があれば、探して。',
#  '[AREA]に[SZN]と[SZN]の[TYPE]で[INGR]が使われている、[PRON]が、あれば探して頂きたいです',
#  '[AREA]の[SZN]の[INGR]を使った[TYPE]について、知ってたら、検索して',
#  '[AREA]の[SZN]の[INGR]を使った[TYPE]があれば、検索して欲しいです',
#  '[AREA]、か、[AREA]の[SZN]の[INGR]を使用した[TYPE]について知ってたら探して頂きたいです',
#  '[AREA]、か、[AREA]の[SZN]の[INGR]を使用した[TYPE]があれば、調べて下さい',
#  '[AREA]の[SZN]の[INGR]が使われている[TYPE]を、知ってたら、検索',
#  '[AREA]の[SZN]の[INGR]が使われている[TYPE]があったら、検索して下さい',
#  '[AREA]の、[SZN]に食べられる[INGR]を使った[TYPE]を探して頂けませんか？',
#  '[AREA]の、[SZN]に食べられる[INGR]を使った[TYPE]が、あったら教えて下さい',
#  '[AREA]の[SZN]に食べられる[INGR]を使用した[TYPE]について、検索して？',
#  '[AREA]の[SZN]に食べられる[INGR]を使用した[TYPE]はある？',
#  '[AREA]の[SZN]に食べられる[INGR]が使われている[TYPE]についてご存じであれば、教えて頂きたいです',
#  '[AREA]の[SZN]に食べられる[INGR]が使われている[TYPE]が、あったら調べて頂きたいです',
#  '[AREA]と[AREA]の[SZN]に食べられている、[INGR]を使った[TYPE]をご存じであれば探して欲しいです。',
#  '[AREA]と[AREA]の[SZN]に食べられている、[INGR]を使った[TYPE]があったら、調べてくれませんか？',
#  '[AREA]あるいは[AREA]の、[SZN]に食べられている[INGR]を使用した[TYPE]を、知ってたら、探して？',
#  '[AREA]あるいは[AREA]の、[SZN]に食べられている[INGR]を使用した[TYPE]があったら、検索。',
#  ...]

# %% [markdown]
# # メモ

# %% [markdown]
# ※１
# - 文頭表現だけで一つの文章として成立する可能性がある場合、文末表現のデータフレームに、`文末表現`列が空の行を用意している
# - 空の行が読み込まれると、その行の`文末表現`列の値は`NaN`となってしまう
# - `NaN`のままだと`template = sos + eos`でエラーが起きるため、`NaN`を空文字（`''`）に置き換えている
