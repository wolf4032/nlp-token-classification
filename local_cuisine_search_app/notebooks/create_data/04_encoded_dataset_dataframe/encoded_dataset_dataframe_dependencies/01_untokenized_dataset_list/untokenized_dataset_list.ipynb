# %% [markdown]
# # import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from typing import List, Dict
import random
import pandas as pd

import sys
sys.path.append('/content/drive/MyDrive/local_cuisine_search_app/modules')

from utility import load_json_obj, RandomPicker, search_strs, dump_obj_as_json

# %% [markdown]
# # 関数とクラスの定義

# %%
def create_and_save(
        templates_path: str, unify_dics_path: str, file_name: str, save_dir: str
) -> List[Dict[str, str | List[Dict[str, str | List[int]]]]]:
    """
    データセットの作成と保存

    Parameters
    ----------
    templates_path : str
        データセットのテンプレートが保存されているパス
    unify_dics_path : str
        表記ゆれ統一用辞書が保存されているパス
    file_name : str
        保存するデータセットのファイル名
    save_dir : str
        データセットの保存先ディレクトリ

    Returns
    -------
    List[Dict[str, str | List[Dict[str, str | List[int]]]]]
        データセット
    """
    templates = load_json_obj(templates_path)
    data_maker = DataMaker(unify_dics_path)

    random.seed(42)

    dataset = [data_maker.create(template) for template in templates]

    dump_obj_as_json(dataset, file_name, save_dir)

    return dataset


class DataMaker:
    """
    データ作成用のクラス

    Attributes
    ----------
    _pron_label : str
        代名詞のラベル
        固有表現として言語モデルに抽出させる表現ではないため、エンティティの作成対象ではない
    _word_pickers : Dict[str, RandomPicker]
        ラベルと、ラベルに応じた語彙のRandomPickerの辞書
    _tokens : List[str]
        全トークンのラベルのリスト
    """
    _pron_label = 'PRON'

    def __init__(self, unify_dics_path: str):
        """
        コンストラクタ

        _word_pickerと_tokensの作成

        Parameters
        ----------
        unify_dics_path : str
            表記ゆれ統一用辞書が保存されているパス
        """
        self._word_pickers = DataMaker._create_word_pickers(unify_dics_path)
        self._tokens = list(self._word_pickers.keys())

    @staticmethod
    def _create_word_pickers(unify_dics_path: str) -> Dict[str, RandomPicker]:
        """
        word_pickersの作成

        Parameters
        ----------
        unify_dics_path : str
            表記ゆれ統一用辞書が保存されているパス

        Returns
        -------
        Dict[str, RandomPicker]
            ラベルと、ラベルに応じた語彙のRandomPickerの辞書
        """
        unify_dics: Dict[str, Dict[str, str]] = load_json_obj(unify_dics_path)
        word_pickers: Dict[str, RandomPicker] = {}

        for label, unify_dic in unify_dics.items():
            words = [word for words in unify_dic.items() for word in words]
            word_pickers[label] = RandomPicker(words)

        word_pickers['SZN'] = RandomPicker(['春', '夏', '秋', '冬', '通年'])
        word_pickers[DataMaker._pron_label] = RandomPicker(
            ['料理', 'お料理', '郷土料理', 'レシピ', 'もの', 'やつ']
        )

        return word_pickers

    def create(
            self, template: str
    ) -> Dict[str, str | List[Dict[str, str | List[int]]]]:
        """
        データの作成

        Parameters
        ----------
        template : str
            データのテンプレート

        Returns
        -------
        Dict[str, str | List[Dict[str, str | List[int]]]]
            データ
            文章と、その文章に含まれる固有表現の情報を持つ
        """
        include_tokens = search_strs(template, self._tokens)

        text = template
        entities: List[Dict[str, str | List[int]]] = []
        for token in include_tokens:
            replace_word = self._pick_word(token)

            if token != DataMaker._pron_label:
                entity_dic = self._create_entity_dic(text, token, replace_word)
                entities.append(entity_dic)

            text = text.replace(f'[{token}]', replace_word, 1)

        data = {'text': text, 'entities': entities}

        return data

    def _pick_word(self, token: str) -> str:
        """
        具体的な語彙の取得

        特殊トークンに入れる具体的な語彙をランダムに取得する

        Parameters
        ----------
        token : str
            置き換え対象の特殊トークンのラベル

        Returns
        -------
        str
            具体的な語彙
        """
        picker = self._word_pickers[token]
        word = picker.pick()

        return word

    def _create_entity_dic(
            self, text: str, token: str, replace_word: str
    ) -> Dict[str, str | List[int]]:
        """
        entity_dicの作成

        データに含まれる特定の固有表現の情報を持つ辞書を作成する

        Parameters
        ----------
        text : str
            データの文章
        token : str
            固有表現のラベル
        replace_word : str
            固有表現

        Returns
        -------
        Dict[str, str | List[int]]
            データに含まれる特定の固有表現の情報を持つ辞書
        """
        name_start_idx = text.find('[')
        name_end_idx = name_start_idx + len(replace_word)
        span = [name_start_idx, name_end_idx]

        entity_dic = {'name': replace_word, 'span': span, 'type': token}

        return entity_dic

# %% [markdown]
# # 実行

# %%
templates_path = '/content/drive/MyDrive/local_cuisine_search_app/data/processed_data/04_encoded_dataset_dataframe/encoded_dataset_dataframe_dependencies/01_untokenized_dataset_list/untokenized_dataset_list_dependencies/01_dataset_template_list/dataset_template_list.json'
unify_dics_path = '/content/drive/MyDrive/local_cuisine_search_app/data/processed_data/01_unifying_dictionaries/unifying_dictionaries.json'
file_name = 'untokenized_dataset_list'
save_dir = '/content/drive/MyDrive/local_cuisine_search_app/data/processed_data/04_encoded_dataset_dataframe/encoded_dataset_dataframe_dependencies/01_untokenized_dataset_list'

dataset = create_and_save(templates_path, unify_dics_path, file_name, save_dir)

# %% [markdown]
# # 出力結果の確認

# %%
print(f'data数: {len(dataset)}\n')

dataset
# Out:
# data数: 1929
# [{'text': '山梨または、青森県のやつを、検索してくれませんか？',
#   'entities': [{'name': '山梨', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '青森県', 'span': [6, 9], 'type': 'AREA'}]},
#  {'text': '富山県または、静岡県のお料理が、あれば探して？',
#   'entities': [{'name': '富山県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '静岡県', 'span': [7, 10], 'type': 'AREA'}]},
#  {'text': '群馬と北東北で食べられる、料理を知ってたら、教えて？',
#   'entities': [{'name': '群馬', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '北東北', 'span': [3, 6], 'type': 'AREA'}]},
#  {'text': '鹿児島県と南東北で食べられる、ものが、あったら探してくれませんか？',
#   'entities': [{'name': '鹿児島県', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '南東北', 'span': [5, 8], 'type': 'AREA'}]},
#  {'text': '福島か佐賀県で食べられている、レシピを、ご存じでしたら、調べて？',
#   'entities': [{'name': '福島', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '佐賀県', 'span': [3, 6], 'type': 'AREA'}]},
#  {'text': '岩手県か岩手で食べられている、郷土料理があったら検索しろ',
#   'entities': [{'name': '岩手県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '岩手', 'span': [4, 6], 'type': 'AREA'}]},
#  {'text': 'お米料理かご飯ものについて、知ってたら、検索して頂きたいです',
#   'entities': [{'name': 'お米料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': 'ご飯もの', 'span': [5, 9], 'type': 'TYPE'}]},
#  {'text': '魚系か飯系が、あれば、検索して？',
#   'entities': [{'name': '魚系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': '飯系', 'span': [3, 5], 'type': 'TYPE'}]},
#  {'text': '通年のお料理について、知ってたら、検索しろ。',
#   'entities': [{'name': '通年', 'span': [0, 2], 'type': 'SZN'}]},
#  {'text': '冬の郷土料理が、あれば、探して下さい',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'}]},
#  {'text': '夏に食べられるものについて、ご存じでしたら探して欲しいです',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'}]},
#  {'text': '春に食べられる料理があったら、探して。',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'}]},
#  {'text': '秋に食べられているやつについて、探して？',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'}]},
#  {'text': '秋に食べられているレシピがあれば、探してくれませんか？',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'}]},
#  {'text': '茗荷を使った、郷土料理を、知ってたら探して？',
#   'entities': [{'name': '茗荷', 'span': [0, 2], 'type': 'INGR'}]},
#  {'text': '干ししいたけを使った、料理があれば調べて？',
#   'entities': [{'name': '干ししいたけ', 'span': [0, 6], 'type': 'INGR'}]},
#  {'text': 'ワカサギまたは、ねぎを使用したものについて、知ってたら教えろ',
#   'entities': [{'name': 'ワカサギ', 'span': [0, 4], 'type': 'INGR'},
#    {'name': 'ねぎ', 'span': [8, 10], 'type': 'INGR'}]},
#  {'text': 'スケトウダラまたは、出汁を使用したレシピがあれば、検索。',
#   'entities': [{'name': 'スケトウダラ', 'span': [0, 6], 'type': 'INGR'},
#    {'name': '出汁', 'span': [10, 12], 'type': 'INGR'}]},
#  {'text': 'イノシシ肉が使われているやつをご存じであれば、教えて',
#   'entities': [{'name': 'イノシシ肉', 'span': [0, 5], 'type': 'INGR'}]},
#  {'text': 'タラコが使われているお料理があったら検索して頂きたいです',
#   'entities': [{'name': 'タラコ', 'span': [0, 3], 'type': 'INGR'}]},
#  {'text': '奈良の飯料理あるいは肉料理について教えろ',
#   'entities': [{'name': '奈良', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [3, 6], 'type': 'TYPE'},
#    {'name': '肉料理', 'span': [10, 13], 'type': 'TYPE'}]},
#  {'text': '関西のお野菜料理あるいは野菜系があれば調べて',
#   'entities': [{'name': '関西', 'span': [0, 2], 'type': 'AREA'},
#    {'name': 'お野菜料理', 'span': [3, 8], 'type': 'TYPE'},
#    {'name': '野菜系', 'span': [12, 15], 'type': 'TYPE'}]},
#  {'text': '長野で食べられる魚料理について、ご存じでしたら、検索してくれませんか？',
#   'entities': [{'name': '長野', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '魚料理', 'span': [8, 11], 'type': 'TYPE'}]},
#  {'text': '山形県で食べられる飯料理があれば検索しろ',
#   'entities': [{'name': '山形県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [9, 12], 'type': 'TYPE'}]},
#  {'text': '東北で食べられている飯料理について検索して下さい',
#   'entities': [{'name': '東北', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [10, 13], 'type': 'TYPE'}]},
#  {'text': '東海地方で食べられている肉系が、あれば、調べて頂きたいです。',
#   'entities': [{'name': '東海地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '肉系', 'span': [12, 14], 'type': 'TYPE'}]},
#  {'text': '茨城県に飯料理か米料理があったら、探して頂きたいです',
#   'entities': [{'name': '茨城県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [4, 7], 'type': 'TYPE'},
#    {'name': '米料理', 'span': [8, 11], 'type': 'TYPE'}]},
#  {'text': 'お魚料理で三重のレシピを、ご存じでしたら探して頂きたいです',
#   'entities': [{'name': 'お魚料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '三重', 'span': [5, 7], 'type': 'AREA'}]},
#  {'text': '野菜料理で沖縄地方の郷土料理があれば、調べろ。',
#   'entities': [{'name': '野菜料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '沖縄地方', 'span': [5, 9], 'type': 'AREA'}]},
#  {'text': '飯料理または、お肉料理で和歌山で食べられるお料理についてご存じであれば探して下さい。',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': 'お肉料理', 'span': [7, 11], 'type': 'TYPE'},
#    {'name': '和歌山', 'span': [12, 15], 'type': 'AREA'}]},
#  {'text': '野菜料理または、魚料理で南関東地方で食べられるやつが、あれば教えて頂きたいです',
#   'entities': [{'name': '野菜料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '魚料理', 'span': [8, 11], 'type': 'TYPE'},
#    {'name': '南関東地方', 'span': [12, 17], 'type': 'AREA'}]},
#  {'text': '米系で沖縄県で食べられている料理についてご存じであれば調べて？',
#   'entities': [{'name': '米系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': '沖縄県', 'span': [3, 6], 'type': 'AREA'}]},
#  {'text': '肉料理で神奈川県で食べられているものが、あったら、調べて下さい。',
#   'entities': [{'name': '肉料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '神奈川県', 'span': [4, 8], 'type': 'AREA'}]},
#  {'text': 'お肉料理に、三重県あるいは、関東のやつは、ありますか？',
#   'entities': [{'name': 'お肉料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '三重県', 'span': [6, 9], 'type': 'AREA'},
#    {'name': '関東', 'span': [14, 16], 'type': 'AREA'}]},
#  {'text': '魚系または飯料理に甲信越で食べられる郷土料理が、あったら、教えて下さい',
#   'entities': [{'name': '魚系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': '飯料理', 'span': [5, 8], 'type': 'TYPE'},
#    {'name': '甲信越', 'span': [9, 12], 'type': 'AREA'}]},
#  {'text': '飯料理、または、飯料理に宮城県で食べられているレシピが、あったら、調べて欲しいです',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '飯料理', 'span': [8, 11], 'type': 'TYPE'},
#    {'name': '宮城県', 'span': [12, 15], 'type': 'AREA'}]},
#  {'text': '山口の、冬の料理を、知ってたら、検索して頂きたいです',
#   'entities': [{'name': '山口', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '冬', 'span': [4, 5], 'type': 'SZN'}]},
#  {'text': '福井の、通年のものが、あったら教えて下さい',
#   'entities': [{'name': '福井', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '通年', 'span': [4, 6], 'type': 'SZN'}]},
#  {'text': '福井県の夏に食べられるお料理を、ご存じでしたら検索して頂きたいです。',
#   'entities': [{'name': '福井県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '夏', 'span': [4, 5], 'type': 'SZN'}]},
#  {'text': '甲信越地方の春に食べられるお料理があれば教えて欲しいです。',
#   'entities': [{'name': '甲信越地方', 'span': [0, 5], 'type': 'AREA'},
#    {'name': '春', 'span': [6, 7], 'type': 'SZN'}]},
#  {'text': '京都または東京都の夏に食べられている、やつについてご存じであれば、教えて。',
#   'entities': [{'name': '京都', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '東京都', 'span': [5, 8], 'type': 'AREA'},
#    {'name': '夏', 'span': [9, 10], 'type': 'SZN'}]},
#  {'text': '沖縄または大阪の通年に食べられている、ものが、あったら調べて',
#   'entities': [{'name': '沖縄', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '大阪', 'span': [5, 7], 'type': 'AREA'},
#    {'name': '通年', 'span': [8, 10], 'type': 'SZN'}]},
#  {'text': '山口県で春に食べられる料理について、知ってたら、探してくれませんか？',
#   'entities': [{'name': '山口県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '春', 'span': [4, 5], 'type': 'SZN'}]},
#  {'text': '鹿児島で冬に食べられる郷土料理が、あったら、教えて頂けませんか？',
#   'entities': [{'name': '鹿児島', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '冬', 'span': [4, 5], 'type': 'SZN'}]},
#  {'text': '山形で、秋に食べられているレシピをご存じであれば、教えて頂けませんか？',
#   'entities': [{'name': '山形', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'}]},
#  {'text': '関西地方で、夏に食べられているやつが、あれば探して。',
#   'entities': [{'name': '関西地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '夏', 'span': [6, 7], 'type': 'SZN'}]},
#  {'text': '福岡県あるいは東海で食べられる春の、レシピについて知ってたら、調べろ',
#   'entities': [{'name': '福岡県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '東海', 'span': [7, 9], 'type': 'AREA'},
#    {'name': '春', 'span': [15, 16], 'type': 'SZN'}]},
#  {'text': '香川県あるいは近畿で食べられる冬の、郷土料理があれば調べて欲しいです',
#   'entities': [{'name': '香川県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '近畿', 'span': [7, 9], 'type': 'AREA'},
#    {'name': '冬', 'span': [15, 16], 'type': 'SZN'}]},
#  {'text': '南関東で食べられている秋のものについて、知ってたら調べろ。',
#   'entities': [{'name': '南関東', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '秋', 'span': [11, 12], 'type': 'SZN'}]},
#  {'text': '千葉県で食べられている通年のお料理があれば検索してくれませんか？',
#   'entities': [{'name': '千葉県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '通年', 'span': [11, 13], 'type': 'SZN'}]},
#  {'text': '東京に秋または通年の料理があれば探して下さい',
#   'entities': [{'name': '東京', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '秋', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '通年', 'span': [7, 9], 'type': 'SZN'}]},
#  {'text': '夏と春の奈良県のものについて、検索しろ',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '春', 'span': [2, 3], 'type': 'SZN'},
#    {'name': '奈良県', 'span': [4, 7], 'type': 'AREA'}]},
#  {'text': '冬と通年の千葉の郷土料理が、あれば検索しろ。',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '通年', 'span': [2, 4], 'type': 'SZN'},
#    {'name': '千葉', 'span': [5, 7], 'type': 'AREA'}]},
#  {'text': '夏の富山と福岡で食べられるお料理について知ってたら探して？',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '富山', 'span': [2, 4], 'type': 'AREA'},
#    {'name': '福岡', 'span': [5, 7], 'type': 'AREA'}]},
#  {'text': '冬の北陸と北海道で食べられるやつが、あったら調べて下さい。',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '北陸', 'span': [2, 4], 'type': 'AREA'},
#    {'name': '北海道', 'span': [5, 8], 'type': 'AREA'}]},
#  {'text': '秋の北関東か宮城で食べられている料理についてご存じであれば、探して下さい',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '北関東', 'span': [2, 5], 'type': 'AREA'},
#    {'name': '宮城', 'span': [6, 8], 'type': 'AREA'}]},
#  {'text': '春の徳島県か鳥取で食べられているレシピがあったら、検索して下さい。',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '徳島県', 'span': [2, 5], 'type': 'AREA'},
#    {'name': '鳥取', 'span': [6, 8], 'type': 'AREA'}]},
#  {'text': '夏または春に埼玉県のやつが、あれば、探して？',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '春', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '埼玉県', 'span': [6, 9], 'type': 'AREA'}]},
#  {'text': '冬に、群馬県で食べられるものを、ご存じであれば教えて下さい',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '群馬県', 'span': [3, 6], 'type': 'AREA'}]},
#  {'text': '秋に、石川県で食べられるレシピがあったら、探して',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '石川県', 'span': [3, 6], 'type': 'AREA'}]},
#  {'text': '通年、と秋に関東地方で食べられている料理について、ご存じでしたら、探して下さい。',
#   'entities': [{'name': '通年', 'span': [0, 2], 'type': 'SZN'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '関東地方', 'span': [6, 10], 'type': 'AREA'}]},
#  {'text': '夏、と通年に高知県で食べられている郷土料理が、あったら検索。',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '通年', 'span': [3, 5], 'type': 'SZN'},
#    {'name': '高知県', 'span': [6, 9], 'type': 'AREA'}]},
#  {'text': '冬に食べられる北陸地方の、お料理を、検索して頂きたいです',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '北陸地方', 'span': [7, 11], 'type': 'AREA'}]},
#  {'text': '春に食べられる岡山県の、お料理が、あれば、教えて下さい',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '岡山県', 'span': [7, 10], 'type': 'AREA'}]},
#  {'text': '春に食べられている、滋賀県の料理をご存じでしたら調べて頂きたいです。',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '滋賀県', 'span': [10, 13], 'type': 'AREA'}]},
#  {'text': '秋に食べられている、佐賀のレシピが、あれば探して欲しいです。',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '佐賀', 'span': [10, 12], 'type': 'AREA'}]},
#  {'text': '北海道のねぎかカラシを使った郷土料理について知ってたら、調べて欲しいです。',
#   'entities': [{'name': '北海道', 'span': [0, 3], 'type': 'AREA'},
#    {'name': 'ねぎ', 'span': [4, 6], 'type': 'INGR'},
#    {'name': 'カラシ', 'span': [7, 10], 'type': 'INGR'}]},
#  {'text': '石川のしろねぎか牛を使ったやつが、あったら検索して欲しいです',
#   'entities': [{'name': '石川', 'span': [0, 2], 'type': 'AREA'},
#    {'name': 'しろねぎ', 'span': [3, 7], 'type': 'INGR'},
#    {'name': '牛', 'span': [8, 9], 'type': 'INGR'}]},
#  {'text': '茨城のドジョウを使用したものを知ってたら、探せ',
#   'entities': [{'name': '茨城', 'span': [0, 2], 'type': 'AREA'},
#    {'name': 'ドジョウ', 'span': [3, 7], 'type': 'INGR'}]},
#  {'text': '滋賀の間八を使用したお料理があれば、調べて。',
#   'entities': [{'name': '滋賀', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '間八', 'span': [3, 5], 'type': 'INGR'}]},
#  {'text': '長崎県と山梨県のさとうが使われているやつについて、調べて頂きたいです',
#   'entities': [{'name': '長崎県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '山梨県', 'span': [4, 7], 'type': 'AREA'},
#    {'name': 'さとう', 'span': [8, 11], 'type': 'INGR'}]},
#  {'text': '愛媛県と愛知県のトビウオが使われているものがあったら、教えろ。',
#   'entities': [{'name': '愛媛県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '愛知県', 'span': [4, 7], 'type': 'AREA'},
#    {'name': 'トビウオ', 'span': [8, 12], 'type': 'INGR'}]},
#  {'text': '岐阜と、埼玉で食べられるしいたけを使ったレシピについてご存じでしたら、検索して。',
#   'entities': [{'name': '岐阜', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '埼玉', 'span': [4, 6], 'type': 'AREA'},
#    {'name': 'しいたけ', 'span': [12, 16], 'type': 'INGR'}]},
#  {'text': '高知と、広島で食べられるちりめんじゃこを使った郷土料理があったら、検索して',
#   'entities': [{'name': '高知', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '広島', 'span': [4, 6], 'type': 'AREA'},
#    {'name': 'ちりめんじゃこ', 'span': [12, 19], 'type': 'INGR'}]},
#  {'text': '大分か、九州で食べられる人参を使用した料理をご存じであれば、検索して？',
#   'entities': [{'name': '大分', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '九州', 'span': [4, 6], 'type': 'AREA'},
#    {'name': '人参', 'span': [12, 14], 'type': 'INGR'}]},
#  {'text': '福島県か、長崎で食べられるヒラメを使用した料理が、あれば検索して？',
#   'entities': [{'name': '福島県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '長崎', 'span': [5, 7], 'type': 'AREA'},
#    {'name': 'ヒラメ', 'span': [13, 16], 'type': 'INGR'}]},
#  {'text': '兵庫県で食べられるインゲンマメが使われている郷土料理を、ご存じであれば探して下さい。',
#   'entities': [{'name': '兵庫県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': 'インゲンマメ', 'span': [9, 15], 'type': 'INGR'}]},
#  {'text': '北関東地方で食べられるキスが使われているレシピが、あったら教えろ。',
#   'entities': [{'name': '北関東地方', 'span': [0, 5], 'type': 'AREA'},
#    {'name': 'キス', 'span': [11, 13], 'type': 'INGR'}]},
#  {'text': '宮崎で食べられているトウモロコシを使ったものについてご存じであれば、教えて欲しいです。',
#   'entities': [{'name': '宮崎', 'span': [0, 2], 'type': 'AREA'},
#    {'name': 'トウモロコシ', 'span': [10, 16], 'type': 'INGR'}]},
#  {'text': '北海道で食べられている苦瓜を使ったお料理が、あれば、検索して下さい。',
#   'entities': [{'name': '北海道', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '苦瓜', 'span': [11, 13], 'type': 'INGR'}]},
#  {'text': '北海道地方で食べられている、ぼらを使用したやつをご存じでしたら、探して下さい。',
#   'entities': [{'name': '北海道地方', 'span': [0, 5], 'type': 'AREA'},
#    {'name': 'ぼら', 'span': [14, 16], 'type': 'INGR'}]},
#  {'text': '栃木で食べられている、ふぐを使用した料理が、あったら、検索して？',
#   'entities': [{'name': '栃木', 'span': [0, 2], 'type': 'AREA'},
#    {'name': 'ふぐ', 'span': [11, 13], 'type': 'INGR'}]},
#  {'text': '長野県、と島根で食べられているシュンギクが使われているものをご存じでしたら、検索して頂きたいです。',
#   'entities': [{'name': '長野県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '島根', 'span': [5, 7], 'type': 'AREA'},
#    {'name': 'シュンギク', 'span': [15, 20], 'type': 'INGR'}]},
#  {'text': '中国地方、と近畿地方で食べられているまいたけが使われているやつがあれば調べて下さい。',
#   'entities': [{'name': '中国地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '近畿地方', 'span': [6, 10], 'type': 'AREA'},
#    {'name': 'まいたけ', 'span': [18, 22], 'type': 'INGR'}]},
#  {'text': '栃木県か、大阪府にタコを使ったお料理があったら検索',
#   'entities': [{'name': '栃木県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '大阪府', 'span': [5, 8], 'type': 'AREA'},
#    {'name': 'タコ', 'span': [9, 11], 'type': 'INGR'}]},
#  {'text': '北東北地方に銀杏、と、マダコを使用したレシピが、あったら探して欲しいです',
#   'entities': [{'name': '北東北地方', 'span': [0, 5], 'type': 'AREA'},
#    {'name': '銀杏', 'span': [6, 8], 'type': 'INGR'},
#    {'name': 'マダコ', 'span': [11, 14], 'type': 'INGR'}]},
#  {'text': '中国と宮崎県にサトウが使われている郷土料理が、あれば、検索しろ。',
#   'entities': [{'name': '中国', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '宮崎県', 'span': [3, 6], 'type': 'AREA'},
#    {'name': 'サトウ', 'span': [7, 10], 'type': 'INGR'}]},
#  {'text': 'かぼちゃあるいはいんげん豆を使った京都府のお料理について、探してくれませんか？',
#   'entities': [{'name': 'かぼちゃ', 'span': [0, 4], 'type': 'INGR'},
#    {'name': 'いんげん豆', 'span': [8, 13], 'type': 'INGR'},
#    {'name': '京都府', 'span': [17, 20], 'type': 'AREA'}]},
#  {'text': '牛蒡あるいはごま油を使った中部地方のやつがあったら、教えて',
#   'entities': [{'name': '牛蒡', 'span': [0, 2], 'type': 'INGR'},
#    {'name': 'ごま油', 'span': [6, 9], 'type': 'INGR'},
#    {'name': '中部地方', 'span': [13, 17], 'type': 'AREA'}]},
#  {'text': 'ダイコンとまだらを使用した秋田の料理を検索して頂きたいです',
#   'entities': [{'name': 'ダイコン', 'span': [0, 4], 'type': 'INGR'},
#    {'name': 'まだら', 'span': [5, 8], 'type': 'INGR'},
#    {'name': '秋田', 'span': [13, 15], 'type': 'AREA'}]},
#  {'text': 'ごまとヒラマサを使用した愛媛のものが、あれば、調べてくれませんか？',
#   'entities': [{'name': 'ごま', 'span': [0, 2], 'type': 'INGR'},
#    {'name': 'ヒラマサ', 'span': [3, 7], 'type': 'INGR'},
#    {'name': '愛媛', 'span': [12, 14], 'type': 'AREA'}]},
#  {'text': 'きのこが使われている秋田県の郷土料理について知ってたら検索して下さい。',
#   'entities': [{'name': 'きのこ', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '秋田県', 'span': [10, 13], 'type': 'AREA'}]},
#  {'text': 'いんげんが使われている静岡のレシピがあったら、調べて頂けませんか？',
#   'entities': [{'name': 'いんげん', 'span': [0, 4], 'type': 'INGR'},
#    {'name': '静岡', 'span': [11, 13], 'type': 'AREA'}]},
#  {'text': 'ワラビを使った徳島で食べられる料理をご存じでしたら、調べて？',
#   'entities': [{'name': 'ワラビ', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '徳島', 'span': [7, 9], 'type': 'AREA'}]},
#  {'text': 'だし汁を使った和歌山県で食べられるやつが、あったら、調べて。',
#   'entities': [{'name': 'だし汁', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '和歌山県', 'span': [7, 11], 'type': 'AREA'}]},
#  {'text': 'わさびを使用した、神奈川で食べられるお料理についてご存じであれば、調べて欲しいです。',
#   'entities': [{'name': 'わさび', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '神奈川', 'span': [9, 12], 'type': 'AREA'}]},
#  {'text': 'コノシロを使用した、四国で食べられるものがあれば、探して頂きたいです。',
#   'entities': [{'name': 'コノシロ', 'span': [0, 4], 'type': 'INGR'},
#    {'name': '四国', 'span': [10, 12], 'type': 'AREA'}]},
#  {'text': 'アンコウが使われている香川あるいは岡山で食べられる郷土料理についてご存じであれば探して。',
#   'entities': [{'name': 'アンコウ', 'span': [0, 4], 'type': 'INGR'},
#    {'name': '香川', 'span': [11, 13], 'type': 'AREA'},
#    {'name': '岡山', 'span': [17, 19], 'type': 'AREA'}]},
#  {'text': '鱈が使われている島根県あるいは熊本で食べられるレシピが、あれば、調べて頂けませんか？',
#   'entities': [{'name': '鱈', 'span': [0, 1], 'type': 'INGR'},
#    {'name': '島根県', 'span': [8, 11], 'type': 'AREA'},
#    {'name': '熊本', 'span': [15, 17], 'type': 'AREA'}]},
#  {'text': 'じゃがいもを使った大分県、か広島県で食べられている、郷土料理を探して',
#   'entities': [{'name': 'じゃがいも', 'span': [0, 5], 'type': 'INGR'},
#    {'name': '大分県', 'span': [9, 12], 'type': 'AREA'},
#    {'name': '広島県', 'span': [14, 17], 'type': 'AREA'}]},
#  {'text': 'ねぎを使った青森、か東北地方で食べられている、やつがあったら、検索',
#   'entities': [{'name': 'ねぎ', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '青森', 'span': [6, 8], 'type': 'AREA'},
#    {'name': '東北地方', 'span': [10, 14], 'type': 'AREA'}]},
#  {'text': 'ダシを使用した、新潟県で食べられている料理をご存じであれば調べてくれませんか？',
#   'entities': [{'name': 'ダシ', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '新潟県', 'span': [8, 11], 'type': 'AREA'}]},
#  {'text': 'ししゃもを使用した、兵庫で食べられているものがあったら探して。',
#   'entities': [{'name': 'ししゃも', 'span': [0, 4], 'type': 'INGR'},
#    {'name': '兵庫', 'span': [10, 12], 'type': 'AREA'}]},
#  {'text': 'サバが使われている愛知、と、中部で食べられているお料理をご存じであれば、教えて？',
#   'entities': [{'name': 'サバ', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '愛知', 'span': [9, 11], 'type': 'AREA'},
#    {'name': '中部', 'span': [14, 16], 'type': 'AREA'}]},
#  {'text': '山椒が使われている四国地方、と、鳥取県で食べられているレシピがあれば、探して',
#   'entities': [{'name': '山椒', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '四国地方', 'span': [9, 13], 'type': 'AREA'},
#    {'name': '鳥取県', 'span': [16, 19], 'type': 'AREA'}]},
#  {'text': '魚料理で通年または、冬のものをご存じであれば教えて頂けませんか？',
#   'entities': [{'name': '魚料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '通年', 'span': [4, 6], 'type': 'SZN'},
#    {'name': '冬', 'span': [10, 11], 'type': 'SZN'}]},
#  {'text': '飯系で夏または、春のお料理があれば、調べて頂きたいです',
#   'entities': [{'name': '飯系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': '夏', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '春', 'span': [8, 9], 'type': 'SZN'}]},
#  {'text': 'お米料理で夏に食べられる料理についてご存じであれば教えて。',
#   'entities': [{'name': 'お米料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '夏', 'span': [5, 6], 'type': 'SZN'}]},
#  {'text': '野菜料理で通年に食べられる郷土料理があったら調べて？',
#   'entities': [{'name': '野菜料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '通年', 'span': [5, 7], 'type': 'SZN'}]},
#  {'text': 'ご飯もので冬に食べられている、レシピについて、知ってたら、教えて頂きたいです。',
#   'entities': [{'name': 'ご飯もの', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '冬', 'span': [5, 6], 'type': 'SZN'}]},
#  {'text': '魚料理で秋に食べられている、やつが、あれば調べて下さい。',
#   'entities': [{'name': '魚料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'}]},
#  {'text': 'お魚料理または、肉系に通年の、レシピが、あったら、検索して頂きたいです',
#   'entities': [{'name': 'お魚料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '肉系', 'span': [8, 10], 'type': 'TYPE'},
#    {'name': '通年', 'span': [11, 13], 'type': 'SZN'}]},
#  {'text': '秋、か、春の飯料理をご存じであれば探してくれませんか？',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '春', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [6, 9], 'type': 'TYPE'}]},
#  {'text': '冬、か、夏の米系があったら、探せ。',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '夏', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '米系', 'span': [6, 8], 'type': 'TYPE'}]},
#  {'text': '春に、肉料理が、あったら検索して下さい。',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '肉料理', 'span': [3, 6], 'type': 'TYPE'}]},
#  {'text': '秋に食べられるお野菜料理について、ご存じであれば検索してくれませんか？',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'お野菜料理', 'span': [7, 12], 'type': 'TYPE'}]},
#  {'text': '冬に食べられる飯料理があれば、調べて欲しいです。',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [7, 10], 'type': 'TYPE'}]},
#  {'text': '通年に食べられている、野菜料理について、探して欲しいです',
#   'entities': [{'name': '通年', 'span': [0, 2], 'type': 'SZN'},
#    {'name': '野菜料理', 'span': [11, 15], 'type': 'TYPE'}]},
#  {'text': '夏に食べられている、米料理があったら調べて頂けませんか？',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '米料理', 'span': [10, 13], 'type': 'TYPE'}]},
#  {'text': '肉料理と野菜系で酢を使った料理を、知ってたら検索して頂けませんか？',
#   'entities': [{'name': '肉料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '野菜系', 'span': [4, 7], 'type': 'TYPE'},
#    {'name': '酢', 'span': [8, 9], 'type': 'INGR'}]},
#  {'text': '肉料理と魚料理で味噌を使った郷土料理が、あったら検索しろ',
#   'entities': [{'name': '肉料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '魚料理', 'span': [4, 7], 'type': 'TYPE'},
#    {'name': '味噌', 'span': [8, 10], 'type': 'INGR'}]},
#  {'text': '野菜系で白菜または、猪肉を使用した、ものを、知ってたら検索してくれませんか？',
#   'entities': [{'name': '野菜系', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '白菜', 'span': [4, 6], 'type': 'INGR'},
#    {'name': '猪肉', 'span': [10, 12], 'type': 'INGR'}]},
#  {'text': 'お肉料理で猪肉または、あなごを使用した、お料理が、あれば、検索',
#   'entities': [{'name': 'お肉料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '猪肉', 'span': [5, 7], 'type': 'INGR'},
#    {'name': 'あなご', 'span': [11, 14], 'type': 'INGR'}]},
#  {'text': '飯料理でさといもが使われているやつを、調べて。',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': 'さといも', 'span': [4, 8], 'type': 'INGR'}]},
#  {'text': '野菜料理でしゅんぎくが使われているお料理が、あれば検索してくれませんか？',
#   'entities': [{'name': '野菜料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': 'しゅんぎく', 'span': [5, 10], 'type': 'INGR'}]},
#  {'text': '飯料理にインゲンを使った、ものが、あったら検索しろ。',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': 'インゲン', 'span': [4, 8], 'type': 'INGR'}]},
#  {'text': '飯系に、インゲン豆を使用したレシピが、あれば、探して頂きたいです',
#   'entities': [{'name': '飯系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': 'インゲン豆', 'span': [4, 9], 'type': 'INGR'}]},
#  {'text': 'お魚料理にカズノコが使われているやつがあったら検索して下さい。',
#   'entities': [{'name': 'お魚料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': 'カズノコ', 'span': [5, 9], 'type': 'INGR'}]},
#  {'text': 'ギンナンかサケを使った、飯料理について探せ。',
#   'entities': [{'name': 'ギンナン', 'span': [0, 4], 'type': 'INGR'},
#    {'name': 'サケ', 'span': [5, 7], 'type': 'INGR'},
#    {'name': '飯料理', 'span': [12, 15], 'type': 'TYPE'}]},
#  {'text': '蓮根か蜆を使った、飯料理があったら教えて欲しいです',
#   'entities': [{'name': '蓮根', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '蜆', 'span': [3, 4], 'type': 'INGR'},
#    {'name': '飯料理', 'span': [9, 12], 'type': 'TYPE'}]},
#  {'text': 'ドジョウを使用したご飯もの、か飯料理をご存じでしたら、検索してくれませんか？',
#   'entities': [{'name': 'ドジョウ', 'span': [0, 4], 'type': 'INGR'},
#    {'name': 'ご飯もの', 'span': [9, 13], 'type': 'TYPE'},
#    {'name': '飯料理', 'span': [15, 18], 'type': 'TYPE'}]},
#  {'text': 'ハモを使用した野菜料理、か肉料理があったら、調べろ。',
#   'entities': [{'name': 'ハモ', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '野菜料理', 'span': [7, 11], 'type': 'TYPE'},
#    {'name': '肉料理', 'span': [13, 16], 'type': 'TYPE'}]},
#  {'text': 'ゴーヤが使われている米料理を、知ってたら探して頂きたいです。',
#   'entities': [{'name': 'ゴーヤ', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '米料理', 'span': [10, 13], 'type': 'TYPE'}]},
#  {'text': '豚が使われている魚料理が、あれば教えて欲しいです',
#   'entities': [{'name': '豚', 'span': [0, 1], 'type': 'INGR'},
#    {'name': '魚料理', 'span': [8, 11], 'type': 'TYPE'}]},
#  {'text': '夏の、キンメダイを使った郷土料理について、ご存じであれば探してくれませんか？',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'キンメダイ', 'span': [3, 8], 'type': 'INGR'}]},
#  {'text': '冬の、葱を使った料理が、あれば検索して。',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '葱', 'span': [3, 4], 'type': 'INGR'}]},
#  {'text': '秋のナマズを使用したレシピについて知ってたら、教えて？',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'ナマズ', 'span': [2, 5], 'type': 'INGR'}]},
#  {'text': '通年の豚肉を使用した料理が、あれば、調べて',
#   'entities': [{'name': '通年', 'span': [0, 2], 'type': 'SZN'},
#    {'name': '豚肉', 'span': [3, 5], 'type': 'INGR'}]},
#  {'text': '春のくりかまいわしが使われているお料理を、知ってたら、検索してくれませんか？',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'くり', 'span': [2, 4], 'type': 'INGR'},
#    {'name': 'まいわし', 'span': [5, 9], 'type': 'INGR'}]},
#  {'text': '春のメダイかアナゴが使われているやつが、あったら検索して下さい',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'メダイ', 'span': [2, 5], 'type': 'INGR'},
#    {'name': 'アナゴ', 'span': [6, 9], 'type': 'INGR'}]},
#  {'text': '冬または秋に食べられるシシャモを使った郷土料理について知ってたら教えてくれませんか？',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'},
#    {'name': 'シシャモ', 'span': [11, 15], 'type': 'INGR'}]},
#  {'text': '通年または夏に食べられるあじを使ったものが、あったら、検索して下さい。',
#   'entities': [{'name': '通年', 'span': [0, 2], 'type': 'SZN'},
#    {'name': '夏', 'span': [5, 6], 'type': 'SZN'},
#    {'name': 'あじ', 'span': [12, 14], 'type': 'INGR'}]},
#  {'text': '冬に食べられる米かしょうゆを使用したものを、ご存じでしたら、検索して頂きたいです',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '米', 'span': [7, 8], 'type': 'INGR'},
#    {'name': 'しょうゆ', 'span': [9, 13], 'type': 'INGR'}]},
#  {'text': '夏に食べられるあわびかイサキを使用した料理が、あれば、調べて欲しいです。',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'あわび', 'span': [7, 10], 'type': 'INGR'},
#    {'name': 'イサキ', 'span': [11, 14], 'type': 'INGR'}]},
#  {'text': '通年に食べられる、さめが使われているレシピを知ってたら教えろ。',
#   'entities': [{'name': '通年', 'span': [0, 2], 'type': 'SZN'},
#    {'name': 'さめ', 'span': [9, 11], 'type': 'INGR'}]},
#  {'text': '春に食べられる、スケトウダラが使われているやつがあれば、調べて頂けませんか？',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'スケトウダラ', 'span': [8, 14], 'type': 'INGR'}]},
#  {'text': '秋に食べられているホッキを使った郷土料理を、ご存じであれば、教えて下さい',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'ホッキ', 'span': [9, 12], 'type': 'INGR'}]},
#  {'text': '冬に食べられているすけとうだらを使ったお料理が、あったら教えてくれませんか？',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'すけとうだら', 'span': [9, 15], 'type': 'INGR'}]},
#  {'text': '夏、か、秋に食べられているますを使用したやつについてご存じでしたら調べて下さい。',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'},
#    {'name': 'ます', 'span': [13, 15], 'type': 'INGR'}]},
#  {'text': '春、か、通年に食べられているホッキ貝を使用したものが、あれば検索して欲しいです。',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '通年', 'span': [4, 6], 'type': 'SZN'},
#    {'name': 'ホッキ貝', 'span': [14, 18], 'type': 'INGR'}]},
#  {'text': '春に食べられているヒラメが使われている、郷土料理を、ご存じであれば、調べて。',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'ヒラメ', 'span': [9, 12], 'type': 'INGR'}]},
#  {'text': '秋に食べられているカニが使われている、レシピが、あれば、教えて欲しいです。',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': 'カニ', 'span': [9, 11], 'type': 'INGR'}]},
#  {'text': '鰰を使った冬のお料理について知ってますか',
#   'entities': [{'name': '鰰', 'span': [0, 1], 'type': 'INGR'},
#    {'name': '冬', 'span': [5, 6], 'type': 'SZN'}]},
#  {'text': 'スルメを使った夏の料理が、あったら、調べて下さい',
#   'entities': [{'name': 'スルメ', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '夏', 'span': [7, 8], 'type': 'SZN'}]},
#  {'text': 'キクラゲを使用した、通年の郷土料理を知ってたら、教えてくれませんか？',
#   'entities': [{'name': 'キクラゲ', 'span': [0, 4], 'type': 'INGR'},
#    {'name': '通年', 'span': [10, 12], 'type': 'SZN'}]},
#  {'text': 'だしを使用した、通年のレシピが、あったら、調べて頂きたいです',
#   'entities': [{'name': 'だし', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '通年', 'span': [8, 10], 'type': 'SZN'}]},
#  {'text': '椎茸、あるいは、シメジが使われている秋のお料理について、ご存じでしたら、探して頂けませんか？',
#   'entities': [{'name': '椎茸', 'span': [0, 2], 'type': 'INGR'},
#    {'name': 'シメジ', 'span': [8, 11], 'type': 'INGR'},
#    {'name': '秋', 'span': [18, 19], 'type': 'SZN'}]},
#  {'text': 'エンドウ、あるいは、茸が使われている春の料理が、あったら、探せ。',
#   'entities': [{'name': 'エンドウ', 'span': [0, 4], 'type': 'INGR'},
#    {'name': '茸', 'span': [10, 11], 'type': 'INGR'},
#    {'name': '春', 'span': [18, 19], 'type': 'SZN'}]},
#  {'text': 'さんまを使った冬か、夏に食べられるやつについて、調べて下さい。',
#   'entities': [{'name': 'さんま', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '冬', 'span': [7, 8], 'type': 'SZN'},
#    {'name': '夏', 'span': [10, 11], 'type': 'SZN'}]},
#  {'text': 'メダイを使った通年か、夏に食べられるものがあれば、教えて頂きたいです',
#   'entities': [{'name': 'メダイ', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '通年', 'span': [7, 9], 'type': 'SZN'},
#    {'name': '夏', 'span': [11, 12], 'type': 'SZN'}]},
#  {'text': 'しおを使用した秋に食べられる、お料理を知ってたら調べて下さい。',
#   'entities': [{'name': 'しお', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '秋', 'span': [7, 8], 'type': 'SZN'}]},
#  {'text': '春菊を使用した春に食べられる、料理があれば探して下さい。',
#   'entities': [{'name': '春菊', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '春', 'span': [7, 8], 'type': 'SZN'}]},
#  {'text': '平鰤が使われている冬に食べられるレシピについてご存じであれば検索して頂けませんか？',
#   'entities': [{'name': '平鰤', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '冬', 'span': [9, 10], 'type': 'SZN'}]},
#  {'text': 'かつおぶしが使われている冬に食べられる郷土料理があれば教えろ。',
#   'entities': [{'name': 'かつおぶし', 'span': [0, 5], 'type': 'INGR'},
#    {'name': '冬', 'span': [12, 13], 'type': 'SZN'}]},
#  {'text': 'さけを使った、春に食べられているやつについてご存じでしたら教えて下さい。',
#   'entities': [{'name': 'さけ', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '春', 'span': [7, 8], 'type': 'SZN'}]},
#  {'text': 'さつま芋を使った、秋に食べられているものはありますか？',
#   'entities': [{'name': 'さつま芋', 'span': [0, 4], 'type': 'INGR'},
#    {'name': '秋', 'span': [9, 10], 'type': 'SZN'}]},
#  {'text': 'コイを使用した通年に食べられているものについてご存じであれば検索して',
#   'entities': [{'name': 'コイ', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '通年', 'span': [7, 9], 'type': 'SZN'}]},
#  {'text': 'シラコを使用した夏に食べられているレシピが、あれば探して下さい',
#   'entities': [{'name': 'シラコ', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '夏', 'span': [8, 9], 'type': 'SZN'}]},
#  {'text': 'イワナが使われている秋に食べられているお料理について知ってたら、探して欲しいです。',
#   'entities': [{'name': 'イワナ', 'span': [0, 3], 'type': 'INGR'},
#    {'name': '秋', 'span': [10, 11], 'type': 'SZN'}]},
#  {'text': '真鯛が使われている通年に食べられているやつが、あれば探して頂きたいです。',
#   'entities': [{'name': '真鯛', 'span': [0, 2], 'type': 'INGR'},
#    {'name': '通年', 'span': [9, 11], 'type': 'SZN'}]},
#  {'text': '岐阜県の、肉系で夏の料理を知ってたら探して頂けませんか？',
#   'entities': [{'name': '岐阜県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '肉系', 'span': [5, 7], 'type': 'TYPE'},
#    {'name': '夏', 'span': [8, 9], 'type': 'SZN'}]},
#  {'text': '南東北地方の、お米料理で冬の郷土料理が、あったら、教えてくれませんか？',
#   'entities': [{'name': '南東北地方', 'span': [0, 5], 'type': 'AREA'},
#    {'name': 'お米料理', 'span': [7, 11], 'type': 'TYPE'},
#    {'name': '冬', 'span': [12, 13], 'type': 'SZN'}]},
#  {'text': '九州地方の魚系または、米系で春に食べられるお料理について、ご存じでしたら、教えて',
#   'entities': [{'name': '九州地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '魚系', 'span': [5, 7], 'type': 'TYPE'},
#    {'name': '米系', 'span': [11, 13], 'type': 'TYPE'},
#    {'name': '春', 'span': [14, 15], 'type': 'SZN'}]},
#  {'text': '新潟のお野菜料理または、米料理で夏に食べられる料理が、あったら、探して下さい。',
#   'entities': [{'name': '新潟', 'span': [0, 2], 'type': 'AREA'},
#    {'name': 'お野菜料理', 'span': [3, 8], 'type': 'TYPE'},
#    {'name': '米料理', 'span': [12, 15], 'type': 'TYPE'},
#    {'name': '夏', 'span': [16, 17], 'type': 'SZN'}]},
#  {'text': '沖縄の野菜系で冬に食べられているやつについて、ご存じであれば、調べてくれませんか？',
#   'entities': [{'name': '沖縄', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '野菜系', 'span': [3, 6], 'type': 'TYPE'},
#    {'name': '冬', 'span': [7, 8], 'type': 'SZN'}]},
#  {'text': '熊本県の飯料理で春に食べられているレシピが、あったら検索して頂きたいです。',
#   'entities': [{'name': '熊本県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [4, 7], 'type': 'TYPE'},
#    {'name': '春', 'span': [8, 9], 'type': 'SZN'}]},
#  {'text': '北東北の魚料理に秋のものがあったら調べろ。',
#   'entities': [{'name': '北東北', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '魚料理', 'span': [4, 7], 'type': 'TYPE'},
#    {'name': '秋', 'span': [8, 9], 'type': 'SZN'}]},
#  {'text': '鳥取県で飯系または、野菜料理に、通年の郷土料理があれば教えろ',
#   'entities': [{'name': '鳥取県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '飯系', 'span': [4, 6], 'type': 'TYPE'},
#    {'name': '野菜料理', 'span': [10, 14], 'type': 'TYPE'},
#    {'name': '通年', 'span': [16, 18], 'type': 'SZN'}]},
#  {'text': '甲信越か近畿で食べられる、魚系で通年のやつを、ご存じであれば調べて下さい',
#   'entities': [{'name': '甲信越', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '近畿', 'span': [4, 6], 'type': 'AREA'},
#    {'name': '魚系', 'span': [13, 15], 'type': 'TYPE'},
#    {'name': '通年', 'span': [16, 18], 'type': 'SZN'}]},
#  {'text': '北海道か徳島で食べられる、野菜料理で夏のレシピがあれば検索しろ。',
#   'entities': [{'name': '北海道', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '徳島', 'span': [4, 6], 'type': 'AREA'},
#    {'name': '野菜料理', 'span': [13, 17], 'type': 'TYPE'},
#    {'name': '夏', 'span': [18, 19], 'type': 'SZN'}]},
#  {'text': '山梨で食べられている飯料理で秋のものについて、ご存じでしたら、調べて頂けませんか？',
#   'entities': [{'name': '山梨', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [10, 13], 'type': 'TYPE'},
#    {'name': '秋', 'span': [14, 15], 'type': 'SZN'}]},
#  {'text': '青森県で食べられている肉系で冬の郷土料理が、あれば、教えて下さい。',
#   'entities': [{'name': '青森県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '肉系', 'span': [11, 13], 'type': 'TYPE'},
#    {'name': '冬', 'span': [14, 15], 'type': 'SZN'}]},
#  {'text': '鹿児島で食べられる肉料理に春の、お料理はある？',
#   'entities': [{'name': '鹿児島', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '肉料理', 'span': [9, 12], 'type': 'TYPE'},
#    {'name': '春', 'span': [13, 14], 'type': 'SZN'}]},
#  {'text': '沖縄地方で食べられている飯料理に通年の料理が、あったら検索して頂けませんか？',
#   'entities': [{'name': '沖縄地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [12, 15], 'type': 'TYPE'},
#    {'name': '通年', 'span': [16, 18], 'type': 'SZN'}]},
#  {'text': '九州あるいは大阪にお魚料理で春の、料理があれば、教えて欲しいです',
#   'entities': [{'name': '九州', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '大阪', 'span': [6, 8], 'type': 'AREA'},
#    {'name': 'お魚料理', 'span': [9, 13], 'type': 'TYPE'},
#    {'name': '春', 'span': [14, 15], 'type': 'SZN'}]},
#  {'text': '大分県の秋のお米料理について、ご存じであれば検索して下さい。',
#   'entities': [{'name': '大分県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'},
#    {'name': 'お米料理', 'span': [6, 10], 'type': 'TYPE'}]},
#  {'text': '中国の冬のご飯ものがあれば検索して？',
#   'entities': [{'name': '中国', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '冬', 'span': [3, 4], 'type': 'SZN'},
#    {'name': 'ご飯もの', 'span': [5, 9], 'type': 'TYPE'}]},
#  {'text': '宮城県の夏にお肉料理が、あったら教えて？',
#   'entities': [{'name': '宮城県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '夏', 'span': [4, 5], 'type': 'SZN'},
#    {'name': 'お肉料理', 'span': [6, 10], 'type': 'TYPE'}]},
#  {'text': '愛知の夏または通年に食べられる飯料理を、ご存じであれば教えて下さい。',
#   'entities': [{'name': '愛知', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '夏', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '通年', 'span': [7, 9], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [15, 18], 'type': 'TYPE'}]},
#  {'text': '三重県の秋または冬に食べられるお野菜料理があれば調べて頂きたいです',
#   'entities': [{'name': '三重県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '冬', 'span': [8, 9], 'type': 'SZN'},
#    {'name': 'お野菜料理', 'span': [15, 20], 'type': 'TYPE'}]},
#  {'text': '新潟県の春または、冬に食べられている米系を、ご存じであれば探して',
#   'entities': [{'name': '新潟県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '春', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '冬', 'span': [9, 10], 'type': 'SZN'},
#    {'name': '米系', 'span': [18, 20], 'type': 'TYPE'}]},
#  {'text': '中部地方の春または、秋に食べられている飯料理があったら調べて。',
#   'entities': [{'name': '中部地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '春', 'span': [5, 6], 'type': 'SZN'},
#    {'name': '秋', 'span': [10, 11], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [19, 22], 'type': 'TYPE'}]},
#  {'text': '北海道地方か、山形で夏に食べられる肉料理を、ご存じであれば検索して。',
#   'entities': [{'name': '北海道地方', 'span': [0, 5], 'type': 'AREA'},
#    {'name': '山形', 'span': [7, 9], 'type': 'AREA'},
#    {'name': '夏', 'span': [10, 11], 'type': 'SZN'},
#    {'name': '肉料理', 'span': [17, 20], 'type': 'TYPE'}]},
#  {'text': '富山か、山梨県で通年に食べられる魚料理が、あったら教えて頂きたいです。',
#   'entities': [{'name': '富山', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '山梨県', 'span': [4, 7], 'type': 'AREA'},
#    {'name': '通年', 'span': [8, 10], 'type': 'SZN'},
#    {'name': '魚料理', 'span': [16, 19], 'type': 'TYPE'}]},
#  {'text': '富山県、あるいは、群馬県で冬に食べられている魚料理を、知ってたら、検索。',
#   'entities': [{'name': '富山県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '群馬県', 'span': [9, 12], 'type': 'AREA'},
#    {'name': '冬', 'span': [13, 14], 'type': 'SZN'},
#    {'name': '魚料理', 'span': [22, 25], 'type': 'TYPE'}]},
#  {'text': '栃木県、あるいは、宮崎で夏に食べられている野菜系が、あれば調べて。',
#   'entities': [{'name': '栃木県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '宮崎', 'span': [9, 11], 'type': 'AREA'},
#    {'name': '夏', 'span': [12, 13], 'type': 'SZN'},
#    {'name': '野菜系', 'span': [21, 24], 'type': 'TYPE'}]},
#  {'text': '北陸地方で食べられる秋の、肉料理について、ご存じであれば検索して下さい',
#   'entities': [{'name': '北陸地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '秋', 'span': [10, 11], 'type': 'SZN'},
#    {'name': '肉料理', 'span': [13, 16], 'type': 'TYPE'}]},
#  {'text': '神奈川で食べられる春の、飯料理があったら、調べて。',
#   'entities': [{'name': '神奈川', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '春', 'span': [9, 10], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [12, 15], 'type': 'TYPE'}]},
#  {'text': '大阪府で食べられている通年の、飯系について、ご存じでしたら、検索して頂けませんか？',
#   'entities': [{'name': '大阪府', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '通年', 'span': [11, 13], 'type': 'SZN'},
#    {'name': '飯系', 'span': [15, 17], 'type': 'TYPE'}]},
#  {'text': '兵庫で食べられている通年の、お野菜料理が、あったら、教えて？',
#   'entities': [{'name': '兵庫', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '通年', 'span': [10, 12], 'type': 'SZN'},
#    {'name': 'お野菜料理', 'span': [14, 19], 'type': 'TYPE'}]},
#  {'text': '広島県に夏の飯料理が、あったら、探して。',
#   'entities': [{'name': '広島県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '夏', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [6, 9], 'type': 'TYPE'}]},
#  {'text': '肉料理で近畿地方の冬の郷土料理についてご存じでしたら、調べて下さい',
#   'entities': [{'name': '肉料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '近畿地方', 'span': [4, 8], 'type': 'AREA'},
#    {'name': '冬', 'span': [9, 10], 'type': 'SZN'}]},
#  {'text': '米系で関西の秋のお料理が、あれば、調べて頂きたいです',
#   'entities': [{'name': '米系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': '関西', 'span': [3, 5], 'type': 'AREA'},
#    {'name': '秋', 'span': [6, 7], 'type': 'SZN'}]},
#  {'text': 'お魚料理で東北地方で春に食べられるものについて知ってたら検索して欲しいです',
#   'entities': [{'name': 'お魚料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '東北地方', 'span': [5, 9], 'type': 'AREA'},
#    {'name': '春', 'span': [10, 11], 'type': 'SZN'}]},
#  {'text': '野菜料理で香川県で秋に食べられるレシピがあれば教えて頂けませんか？',
#   'entities': [{'name': '野菜料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '香川県', 'span': [5, 8], 'type': 'AREA'},
#    {'name': '秋', 'span': [9, 10], 'type': 'SZN'}]},
#  {'text': '野菜料理で甲信越地方で冬に食べられているやつについて、ご存じでしたら、探して頂きたいです',
#   'entities': [{'name': '野菜料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '甲信越地方', 'span': [5, 10], 'type': 'AREA'},
#    {'name': '冬', 'span': [11, 12], 'type': 'SZN'}]},
#  {'text': '肉系で長崎で春に食べられているレシピが、あったら、探して頂きたいです',
#   'entities': [{'name': '肉系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': '長崎', 'span': [3, 5], 'type': 'AREA'},
#    {'name': '春', 'span': [6, 7], 'type': 'SZN'}]},
#  {'text': '飯料理で、北陸で食べられる通年、または、夏のものについてご存じであれば探してくれませんか？',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '北陸', 'span': [5, 7], 'type': 'AREA'},
#    {'name': '通年', 'span': [13, 15], 'type': 'SZN'},
#    {'name': '夏', 'span': [20, 21], 'type': 'SZN'}]},
#  {'text': 'お米料理で、宮崎県で食べられる秋、または、通年のやつが、あれば、探せ',
#   'entities': [{'name': 'お米料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '宮崎県', 'span': [6, 9], 'type': 'AREA'},
#    {'name': '秋', 'span': [15, 16], 'type': 'SZN'},
#    {'name': '通年', 'span': [21, 23], 'type': 'SZN'}]},
#  {'text': 'ご飯もので北関東地方で食べられている夏のお料理を、教えて',
#   'entities': [{'name': 'ご飯もの', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '北関東地方', 'span': [5, 10], 'type': 'AREA'},
#    {'name': '夏', 'span': [18, 19], 'type': 'SZN'}]},
#  {'text': '米料理で茨城で食べられている冬の郷土料理が、あれば検索。',
#   'entities': [{'name': '米料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '茨城', 'span': [4, 6], 'type': 'AREA'},
#    {'name': '冬', 'span': [14, 15], 'type': 'SZN'}]},
#  {'text': '飯料理と魚料理に関東地方の、春の料理があれば、探して欲しいです',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '魚料理', 'span': [4, 7], 'type': 'TYPE'},
#    {'name': '関東地方', 'span': [8, 12], 'type': 'AREA'},
#    {'name': '春', 'span': [14, 15], 'type': 'SZN'}]},
#  {'text': '飯料理に熊本県で食べられる秋のお料理があったら、教えて下さい',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '熊本県', 'span': [4, 7], 'type': 'AREA'},
#    {'name': '秋', 'span': [13, 14], 'type': 'SZN'}]},
#  {'text': '魚系か、お肉料理に、島根県で食べられている冬のレシピがあったら検索して下さい',
#   'entities': [{'name': '魚系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': 'お肉料理', 'span': [4, 8], 'type': 'TYPE'},
#    {'name': '島根県', 'span': [10, 13], 'type': 'AREA'},
#    {'name': '冬', 'span': [21, 22], 'type': 'SZN'}]},
#  {'text': 'ご飯もので通年の、滋賀県の料理についてご存じであれば、探して欲しいです。',
#   'entities': [{'name': 'ご飯もの', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '通年', 'span': [5, 7], 'type': 'SZN'},
#    {'name': '滋賀県', 'span': [9, 12], 'type': 'AREA'}]},
#  {'text': '野菜料理で春の、福島県の郷土料理が、あれば、探して頂けませんか？',
#   'entities': [{'name': '野菜料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '春', 'span': [5, 6], 'type': 'SZN'},
#    {'name': '福島県', 'span': [8, 11], 'type': 'AREA'}]},
#  {'text': '野菜系で夏の南関東または、岐阜県で食べられるやつについてご存じでしたら探して下さい。',
#   'entities': [{'name': '野菜系', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '夏', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '南関東', 'span': [6, 9], 'type': 'AREA'},
#    {'name': '岐阜県', 'span': [13, 16], 'type': 'AREA'}]},
#  {'text': '魚系で冬の青森または、群馬で食べられるものが、あったら調べて？',
#   'entities': [{'name': '魚系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': '冬', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '青森', 'span': [5, 7], 'type': 'AREA'},
#    {'name': '群馬', 'span': [11, 13], 'type': 'AREA'}]},
#  {'text': '飯料理で、通年の京都で食べられている郷土料理を、ご存じでしたら教えて。',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '通年', 'span': [5, 7], 'type': 'SZN'},
#    {'name': '京都', 'span': [8, 10], 'type': 'AREA'}]},
#  {'text': '肉料理で、夏の関西地方で食べられているやつが、あったら調べろ',
#   'entities': [{'name': '肉料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '夏', 'span': [5, 6], 'type': 'SZN'},
#    {'name': '関西地方', 'span': [7, 11], 'type': 'AREA'}]},
#  {'text': '野菜料理で秋に中国地方または山口で食べられる、レシピを知ってたら検索',
#   'entities': [{'name': '野菜料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '秋', 'span': [5, 6], 'type': 'SZN'},
#    {'name': '中国地方', 'span': [7, 11], 'type': 'AREA'},
#    {'name': '山口', 'span': [14, 16], 'type': 'AREA'}]},
#  {'text': 'お野菜料理で春に奈良県または岡山県で食べられる、お料理があったら教えてくれませんか？',
#   'entities': [{'name': 'お野菜料理', 'span': [0, 5], 'type': 'TYPE'},
#    {'name': '春', 'span': [6, 7], 'type': 'SZN'},
#    {'name': '奈良県', 'span': [8, 11], 'type': 'AREA'},
#    {'name': '岡山県', 'span': [14, 17], 'type': 'AREA'}]},
#  {'text': '飯料理で春に、石川県で食べられているものを知ってたら検索して。',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '春', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '石川県', 'span': [7, 10], 'type': 'AREA'}]},
#  {'text': '飯料理で秋に、福井で食べられている料理が、あったら、探して頂きたいです。',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '福井', 'span': [7, 9], 'type': 'AREA'}]},
#  {'text': '魚料理で冬に食べられる島根のやつを探せ',
#   'entities': [{'name': '魚料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '冬', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '島根', 'span': [11, 13], 'type': 'AREA'}]},
#  {'text': '魚料理で通年に食べられる埼玉県のお料理が、あったら、教えろ。',
#   'entities': [{'name': '魚料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '通年', 'span': [4, 6], 'type': 'SZN'},
#    {'name': '埼玉県', 'span': [12, 15], 'type': 'AREA'}]},
#  {'text': 'お米料理で、夏に食べられている佐賀県の郷土料理を、教えて頂きたいです。',
#   'entities': [{'name': 'お米料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '夏', 'span': [6, 7], 'type': 'SZN'},
#    {'name': '佐賀県', 'span': [15, 18], 'type': 'AREA'}]},
#  {'text': '飯料理で、春に食べられている神奈川県のレシピが、あったら探せ',
#   'entities': [{'name': '飯料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '春', 'span': [5, 6], 'type': 'SZN'},
#    {'name': '神奈川県', 'span': [14, 18], 'type': 'AREA'}]},
#  {'text': '飯系に夏の香川の料理があれば教えて？',
#   'entities': [{'name': '飯系', 'span': [0, 2], 'type': 'TYPE'},
#    {'name': '夏', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '香川', 'span': [5, 7], 'type': 'AREA'}]},
#  {'text': 'お肉料理に冬の千葉県で食べられるものが、あれば教えて。',
#   'entities': [{'name': 'お肉料理', 'span': [0, 4], 'type': 'TYPE'},
#    {'name': '冬', 'span': [5, 6], 'type': 'SZN'},
#    {'name': '千葉県', 'span': [7, 10], 'type': 'AREA'}]},
#  {'text': '肉料理に通年あるいは秋の、和歌山県で食べられているレシピがあったら、探して？',
#   'entities': [{'name': '肉料理', 'span': [0, 3], 'type': 'TYPE'},
#    {'name': '通年', 'span': [4, 6], 'type': 'SZN'},
#    {'name': '秋', 'span': [10, 11], 'type': 'SZN'},
#    {'name': '和歌山県', 'span': [13, 17], 'type': 'AREA'}]},
#  {'text': '秋の埼玉の米系をご存じでしたら検索して？',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '埼玉', 'span': [2, 4], 'type': 'AREA'},
#    {'name': '米系', 'span': [5, 7], 'type': 'TYPE'}]},
#  {'text': '冬の沖縄のお魚料理が、あれば教えて',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '沖縄', 'span': [2, 4], 'type': 'AREA'},
#    {'name': 'お魚料理', 'span': [5, 9], 'type': 'TYPE'}]},
#  {'text': '春の北関東で食べられる米料理を、知ってたら検索して。',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '北関東', 'span': [2, 5], 'type': 'AREA'},
#    {'name': '米料理', 'span': [11, 14], 'type': 'TYPE'}]},
#  {'text': '通年の広島で食べられる飯料理があったら教えて欲しいです。',
#   'entities': [{'name': '通年', 'span': [0, 2], 'type': 'SZN'},
#    {'name': '広島', 'span': [3, 5], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [11, 14], 'type': 'TYPE'}]},
#  {'text': '夏か夏の茨城県で食べられている肉系を、知ってたら探せ',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '夏', 'span': [2, 3], 'type': 'SZN'},
#    {'name': '茨城県', 'span': [4, 7], 'type': 'AREA'},
#    {'name': '肉系', 'span': [15, 17], 'type': 'TYPE'}]},
#  {'text': '春か秋の山形県で食べられている野菜料理が、あれば、調べて欲しいです',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '秋', 'span': [2, 3], 'type': 'SZN'},
#    {'name': '山形県', 'span': [4, 7], 'type': 'AREA'},
#    {'name': '野菜料理', 'span': [15, 19], 'type': 'TYPE'}]},
#  {'text': '通年に長崎県で食べられるお魚料理を、ご存じであれば調べて',
#   'entities': [{'name': '通年', 'span': [0, 2], 'type': 'SZN'},
#    {'name': '長崎県', 'span': [3, 6], 'type': 'AREA'},
#    {'name': 'お魚料理', 'span': [12, 16], 'type': 'TYPE'}]},
#  {'text': '冬に中部で食べられるお野菜料理があれば調べて頂けませんか？',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '中部', 'span': [2, 4], 'type': 'AREA'},
#    {'name': 'お野菜料理', 'span': [10, 15], 'type': 'TYPE'}]},
#  {'text': '冬、か、通年に岡山で食べられている、飯料理について、ご存じであれば調べて頂きたいです。',
#   'entities': [{'name': '冬', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '通年', 'span': [4, 6], 'type': 'SZN'},
#    {'name': '岡山', 'span': [7, 9], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [18, 21], 'type': 'TYPE'}]},
#  {'text': '秋、か、夏に岐阜で食べられている、飯料理が、あったら検索',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '夏', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '岐阜', 'span': [6, 8], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [17, 20], 'type': 'TYPE'}]},
#  {'text': '春に食べられる東海の飯料理について教えて',
#   'entities': [{'name': '春', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '東海', 'span': [7, 9], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [10, 13], 'type': 'TYPE'}]},
#  {'text': '夏に食べられる新潟の飯料理があれば検索',
#   'entities': [{'name': '夏', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '新潟', 'span': [7, 9], 'type': 'AREA'},
#    {'name': '飯料理', 'span': [10, 13], 'type': 'TYPE'}]},
#  {'text': '秋に食べられている静岡県の米料理、か、肉料理を教えて頂けませんか？',
#   'entities': [{'name': '秋', 'span': [0, 1], 'type': 'SZN'},
#    {'name': '静岡県', 'span': [9, 12], 'type': 'AREA'},
# ...
#    {'name': 'えび', 'span': [14, 16], 'type': 'INGR'}]},
#  {'text': '群馬あるいは、宮崎県で冬の野菜料理にマダイが使われているレシピについて、ご存じでしたら教えてくれませんか？',
#   'entities': [{'name': '群馬', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '宮崎県', 'span': [7, 10], 'type': 'AREA'},
#    {'name': '冬', 'span': [11, 12], 'type': 'SZN'},
#    {'name': '野菜料理', 'span': [13, 17], 'type': 'TYPE'},
#    {'name': 'マダイ', 'span': [18, 21], 'type': 'INGR'}]},
#  {'text': '徳島県あるいは、和歌山で春の米系にちりめんじゃこが使われているお料理があれば探して下さい。',
#   'entities': [{'name': '徳島県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '和歌山', 'span': [8, 11], 'type': 'AREA'},
#    {'name': '春', 'span': [12, 13], 'type': 'SZN'},
#    {'name': '米系', 'span': [14, 16], 'type': 'TYPE'},
#    {'name': 'ちりめんじゃこ', 'span': [17, 24], 'type': 'INGR'}]},
#  {'text': '北陸で秋に食べられる飯料理で苦瓜を使った、郷土料理を、ご存じであれば、教えて欲しいです。',
#   'entities': [{'name': '北陸', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '秋', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [10, 13], 'type': 'TYPE'},
#    {'name': '苦瓜', 'span': [14, 16], 'type': 'INGR'}]},
#  {'text': '青森で夏に食べられる野菜料理でミリンを使った、料理があれば、検索して',
#   'entities': [{'name': '青森', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '夏', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '野菜料理', 'span': [10, 14], 'type': 'TYPE'},
#    {'name': 'ミリン', 'span': [15, 18], 'type': 'INGR'}]},
#  {'text': '新潟県で秋あるいは冬に食べられるお米料理でねぎを使用したやつについて、ご存じであれば、調べて頂けませんか？',
#   'entities': [{'name': '新潟県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '冬', 'span': [9, 10], 'type': 'SZN'},
#    {'name': 'お米料理', 'span': [16, 20], 'type': 'TYPE'},
#    {'name': 'ねぎ', 'span': [21, 23], 'type': 'INGR'}]},
#  {'text': '福岡で通年あるいは夏に食べられるご飯もので猪肉を使用したものがあれば、調べろ。',
#   'entities': [{'name': '福岡', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '通年', 'span': [3, 5], 'type': 'SZN'},
#    {'name': '夏', 'span': [9, 10], 'type': 'SZN'},
#    {'name': 'ご飯もの', 'span': [16, 20], 'type': 'TYPE'},
#    {'name': '猪肉', 'span': [21, 23], 'type': 'INGR'}]},
#  {'text': '三重県あるいは、三重で春に食べられる魚料理でちりめんじゃこが使われているものをご存じであれば探して欲しいです',
#   'entities': [{'name': '三重県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '三重', 'span': [8, 10], 'type': 'AREA'},
#    {'name': '春', 'span': [11, 12], 'type': 'SZN'},
#    {'name': '魚料理', 'span': [18, 21], 'type': 'TYPE'},
#    {'name': 'ちりめんじゃこ', 'span': [22, 29], 'type': 'INGR'}]},
#  {'text': '熊本県あるいは、奈良で冬に食べられるお魚料理でしいたけが使われている郷土料理が、あれば、教えて頂きたいです。',
#   'entities': [{'name': '熊本県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '奈良', 'span': [8, 10], 'type': 'AREA'},
#    {'name': '冬', 'span': [11, 12], 'type': 'SZN'},
#    {'name': 'お魚料理', 'span': [18, 22], 'type': 'TYPE'},
#    {'name': 'しいたけ', 'span': [23, 27], 'type': 'INGR'}]},
#  {'text': '佐賀県で、秋に食べられている肉系で胡瓜と真鱈を使った料理についてご存じであれば探して頂けませんか？',
#   'entities': [{'name': '佐賀県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '秋', 'span': [5, 6], 'type': 'SZN'},
#    {'name': '肉系', 'span': [14, 16], 'type': 'TYPE'},
#    {'name': '胡瓜', 'span': [17, 19], 'type': 'INGR'},
#    {'name': '真鱈', 'span': [20, 22], 'type': 'INGR'}]},
#  {'text': '富山県で、春に食べられている飯料理で法蓮草とごま油を使ったお料理があったら、調べて下さい',
#   'entities': [{'name': '富山県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '春', 'span': [5, 6], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [14, 17], 'type': 'TYPE'},
#    {'name': '法蓮草', 'span': [18, 21], 'type': 'INGR'},
#    {'name': 'ごま油', 'span': [22, 25], 'type': 'INGR'}]},
#  {'text': '関東地方で、夏に食べられている飯料理でニシンを使用したレシピについて探して欲しいです。',
#   'entities': [{'name': '関東地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '夏', 'span': [6, 7], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [15, 18], 'type': 'TYPE'},
#    {'name': 'ニシン', 'span': [19, 22], 'type': 'INGR'}]},
#  {'text': '岡山で、通年に食べられている魚料理でカズノコを使用したやつがあれば検索して欲しいです。',
#   'entities': [{'name': '岡山', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '通年', 'span': [4, 6], 'type': 'SZN'},
#    {'name': '魚料理', 'span': [14, 17], 'type': 'TYPE'},
#    {'name': 'カズノコ', 'span': [18, 22], 'type': 'INGR'}]},
#  {'text': '北関東で春、あるいは夏に食べられている魚系でもち米が使われている、料理を知ってたら、探して下さい',
#   'entities': [{'name': '北関東', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '春', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '夏', 'span': [10, 11], 'type': 'SZN'},
#    {'name': '魚系', 'span': [19, 21], 'type': 'TYPE'},
#    {'name': 'もち米', 'span': [22, 25], 'type': 'INGR'}]},
#  {'text': '四国で秋、あるいは通年に食べられている肉料理で鰹が使われている、お料理が、あったら、教えてくれませんか？',
#   'entities': [{'name': '四国', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '秋', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '通年', 'span': [9, 11], 'type': 'SZN'},
#    {'name': '肉料理', 'span': [19, 22], 'type': 'TYPE'},
#    {'name': '鰹', 'span': [23, 24], 'type': 'INGR'}]},
#  {'text': '東北地方で食べられる冬の野菜系、または、お肉料理でたけのこを使ったレシピについて、ご存じであれば検索して',
#   'entities': [{'name': '東北地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '冬', 'span': [10, 11], 'type': 'SZN'},
#    {'name': '野菜系', 'span': [12, 15], 'type': 'TYPE'},
#    {'name': 'お肉料理', 'span': [20, 24], 'type': 'TYPE'},
#    {'name': 'たけのこ', 'span': [25, 29], 'type': 'INGR'}]},
#  {'text': '九州で食べられる春の肉料理、または、飯料理で蝦虎魚を使った郷土料理が、あったら、調べて頂けませんか？',
#   'entities': [{'name': '九州', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '春', 'span': [8, 9], 'type': 'SZN'},
#    {'name': '肉料理', 'span': [10, 13], 'type': 'TYPE'},
#    {'name': '飯料理', 'span': [18, 21], 'type': 'TYPE'},
#    {'name': '蝦虎魚', 'span': [22, 25], 'type': 'INGR'}]},
#  {'text': '中国地方または鹿児島県で食べられる冬の魚料理でスルメを使用したものを、検索して',
#   'entities': [{'name': '中国地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '鹿児島県', 'span': [7, 11], 'type': 'AREA'},
#    {'name': '冬', 'span': [17, 18], 'type': 'SZN'},
#    {'name': '魚料理', 'span': [19, 22], 'type': 'TYPE'},
#    {'name': 'スルメ', 'span': [23, 26], 'type': 'INGR'}]},
#  {'text': '香川または栃木で食べられる通年のお魚料理でねぎを使用したやつが、あれば調べて下さい。',
#   'entities': [{'name': '香川', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '栃木', 'span': [5, 7], 'type': 'AREA'},
#    {'name': '通年', 'span': [13, 15], 'type': 'SZN'},
#    {'name': 'お魚料理', 'span': [16, 20], 'type': 'TYPE'},
#    {'name': 'ねぎ', 'span': [21, 23], 'type': 'INGR'}]},
#  {'text': '群馬県で食べられる夏か秋のお米料理でしらうおが使われているお料理について、知ってたら、調べて。',
#   'entities': [{'name': '群馬県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '夏', 'span': [9, 10], 'type': 'SZN'},
#    {'name': '秋', 'span': [11, 12], 'type': 'SZN'},
#    {'name': 'お米料理', 'span': [13, 17], 'type': 'TYPE'},
#    {'name': 'しらうお', 'span': [18, 22], 'type': 'INGR'}]},
#  {'text': '愛知県で食べられる通年か夏のお肉料理でだしが使われているものが、あれば探して欲しいです',
#   'entities': [{'name': '愛知県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '通年', 'span': [9, 11], 'type': 'SZN'},
#    {'name': '夏', 'span': [12, 13], 'type': 'SZN'},
#    {'name': 'お肉料理', 'span': [14, 18], 'type': 'TYPE'},
#    {'name': 'だし', 'span': [19, 21], 'type': 'INGR'}]},
#  {'text': '兵庫、か神奈川県で食べられている春の魚料理でシジミを使った郷土料理をご存じであれば、教えて。',
#   'entities': [{'name': '兵庫', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '神奈川県', 'span': [4, 8], 'type': 'AREA'},
#    {'name': '春', 'span': [16, 17], 'type': 'SZN'},
#    {'name': '魚料理', 'span': [18, 21], 'type': 'TYPE'},
#    {'name': 'シジミ', 'span': [22, 25], 'type': 'INGR'}]},
#  {'text': '北海道地方、か島根県で食べられている秋の飯系で麦を使ったやつがあったら、教えて頂けませんか？',
#   'entities': [{'name': '北海道地方', 'span': [0, 5], 'type': 'AREA'},
#    {'name': '島根県', 'span': [7, 10], 'type': 'AREA'},
#    {'name': '秋', 'span': [18, 19], 'type': 'SZN'},
#    {'name': '飯系', 'span': [20, 22], 'type': 'TYPE'},
#    {'name': '麦', 'span': [23, 24], 'type': 'INGR'}]},
#  {'text': '茨城で食べられている冬か通年の魚系でタケノコを使用した料理について、知ってたら、調べて下さい',
#   'entities': [{'name': '茨城', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '冬', 'span': [10, 11], 'type': 'SZN'},
#    {'name': '通年', 'span': [12, 14], 'type': 'SZN'},
#    {'name': '魚系', 'span': [15, 17], 'type': 'TYPE'},
#    {'name': 'タケノコ', 'span': [18, 22], 'type': 'INGR'}]},
#  {'text': '南関東地方で食べられている春か冬の野菜系でねぎを使用したレシピがあれば、検索してくれませんか？',
#   'entities': [{'name': '南関東地方', 'span': [0, 5], 'type': 'AREA'},
#    {'name': '春', 'span': [13, 14], 'type': 'SZN'},
#    {'name': '冬', 'span': [15, 16], 'type': 'SZN'},
#    {'name': '野菜系', 'span': [17, 20], 'type': 'TYPE'},
#    {'name': 'ねぎ', 'span': [21, 23], 'type': 'INGR'}]},
#  {'text': '岐阜県で食べられている秋の飯料理でマイタケが使われているレシピについてご存じであれば、調べて下さい',
#   'entities': [{'name': '岐阜県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '秋', 'span': [11, 12], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [13, 16], 'type': 'TYPE'},
#    {'name': 'マイタケ', 'span': [17, 21], 'type': 'INGR'}]},
#  {'text': '秋田県で食べられている夏の飯料理で豚肉が使われている郷土料理が、あれば、検索して？',
#   'entities': [{'name': '秋田県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '夏', 'span': [11, 12], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [13, 16], 'type': 'TYPE'},
#    {'name': '豚肉', 'span': [17, 19], 'type': 'INGR'}]},
#  {'text': '愛媛県または広島で食べられる、冬の野菜料理に生しいたけを使った料理があれば、探せ',
#   'entities': [{'name': '愛媛県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '広島', 'span': [6, 8], 'type': 'AREA'},
#    {'name': '冬', 'span': [15, 16], 'type': 'SZN'},
#    {'name': '野菜料理', 'span': [17, 21], 'type': 'TYPE'},
#    {'name': '生しいたけ', 'span': [22, 27], 'type': 'INGR'}]},
#  {'text': '秋田で食べられる春の米料理に海鷂魚を使用したやつがあれば、調べてくれませんか？',
#   'entities': [{'name': '秋田', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '春', 'span': [8, 9], 'type': 'SZN'},
#    {'name': '米料理', 'span': [10, 13], 'type': 'TYPE'},
#    {'name': '海鷂魚', 'span': [14, 17], 'type': 'INGR'}]},
#  {'text': '新潟と、愛媛で食べられる、秋の肉料理に鱈子が使われているものがあったら、探して頂けませんか？',
#   'entities': [{'name': '新潟', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '愛媛', 'span': [4, 6], 'type': 'AREA'},
#    {'name': '秋', 'span': [13, 14], 'type': 'SZN'},
#    {'name': '肉料理', 'span': [15, 18], 'type': 'TYPE'},
#    {'name': '鱈子', 'span': [19, 21], 'type': 'INGR'}]},
#  {'text': '埼玉で食べられている通年の肉系にきのこと青葱を使ったお料理が、あれば、教えて欲しいです。',
#   'entities': [{'name': '埼玉', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '通年', 'span': [10, 12], 'type': 'SZN'},
#    {'name': '肉系', 'span': [13, 15], 'type': 'TYPE'},
#    {'name': 'きのこ', 'span': [16, 19], 'type': 'INGR'},
#    {'name': '青葱', 'span': [20, 22], 'type': 'INGR'}]},
#  {'text': '北海道と、中部で食べられている、夏の野菜料理にごまあぶらを使用したレシピがあれば調べて頂きたいです。',
#   'entities': [{'name': '北海道', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '中部', 'span': [5, 7], 'type': 'AREA'},
#    {'name': '夏', 'span': [16, 17], 'type': 'SZN'},
#    {'name': '野菜料理', 'span': [18, 22], 'type': 'TYPE'},
#    {'name': 'ごまあぶら', 'span': [23, 28], 'type': 'INGR'}]},
#  {'text': '南東北で食べられている夏の飯料理にレンコンが使われている料理があったら、探して下さい',
#   'entities': [{'name': '南東北', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '夏', 'span': [11, 12], 'type': 'SZN'},
#    {'name': '飯料理', 'span': [13, 16], 'type': 'TYPE'},
#    {'name': 'レンコン', 'span': [17, 21], 'type': 'INGR'}]},
#  {'text': '富山に春または冬の肉料理で縮緬を使ったやつが、あったら検索して頂きたいです',
#   'entities': [{'name': '富山', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '春', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '冬', 'span': [7, 8], 'type': 'SZN'},
#    {'name': '肉料理', 'span': [9, 12], 'type': 'TYPE'},
#    {'name': '縮緬', 'span': [13, 15], 'type': 'INGR'}]},
#  {'text': '埼玉県に通年のご飯ものでイワナを使用したお料理があれば、探して。',
#   'entities': [{'name': '埼玉県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '通年', 'span': [4, 6], 'type': 'SZN'},
#    {'name': 'ご飯もの', 'span': [7, 11], 'type': 'TYPE'},
#    {'name': 'イワナ', 'span': [12, 15], 'type': 'INGR'}]},
#  {'text': '甲信越に秋と冬のお野菜料理でねぎが使われている、ものが、あれば探して頂きたいです',
#   'entities': [{'name': '甲信越', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '秋', 'span': [4, 5], 'type': 'SZN'},
#    {'name': '冬', 'span': [6, 7], 'type': 'SZN'},
#    {'name': 'お野菜料理', 'span': [8, 13], 'type': 'TYPE'},
#    {'name': 'ねぎ', 'span': [14, 16], 'type': 'INGR'}]},
#  {'text': '兵庫県の春のクジラを使った飯料理について、知ってたら、検索して',
#   'entities': [{'name': '兵庫県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '春', 'span': [4, 5], 'type': 'SZN'},
#    {'name': 'クジラ', 'span': [6, 9], 'type': 'INGR'},
#    {'name': '飯料理', 'span': [13, 16], 'type': 'TYPE'}]},
#  {'text': '長崎の秋のすし飯を使った米系があれば、検索して欲しいです',
#   'entities': [{'name': '長崎', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '秋', 'span': [3, 4], 'type': 'SZN'},
#    {'name': 'すし飯', 'span': [5, 8], 'type': 'INGR'},
#    {'name': '米系', 'span': [12, 14], 'type': 'TYPE'}]},
#  {'text': '熊本、か、関西の通年の太刀魚を使用した飯料理について知ってたら探して頂きたいです',
#   'entities': [{'name': '熊本', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '関西', 'span': [5, 7], 'type': 'AREA'},
#    {'name': '通年', 'span': [8, 10], 'type': 'SZN'},
#    {'name': '太刀魚', 'span': [11, 14], 'type': 'INGR'},
#    {'name': '飯料理', 'span': [19, 22], 'type': 'TYPE'}]},
#  {'text': '大阪府、か、大分県の夏のかますを使用した肉料理があれば、調べて下さい',
#   'entities': [{'name': '大阪府', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '大分県', 'span': [6, 9], 'type': 'AREA'},
#    {'name': '夏', 'span': [10, 11], 'type': 'SZN'},
#    {'name': 'かます', 'span': [12, 15], 'type': 'INGR'},
#    {'name': '肉料理', 'span': [20, 23], 'type': 'TYPE'}]},
#  {'text': '宮崎の冬のタマネギが使われている魚系を、知ってたら、検索',
#   'entities': [{'name': '宮崎', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '冬', 'span': [3, 4], 'type': 'SZN'},
#    {'name': 'タマネギ', 'span': [5, 9], 'type': 'INGR'},
#    {'name': '魚系', 'span': [16, 18], 'type': 'TYPE'}]},
#  {'text': '佐賀の春の米が使われている飯料理があったら、検索して下さい',
#   'entities': [{'name': '佐賀', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '春', 'span': [3, 4], 'type': 'SZN'},
#    {'name': '米', 'span': [5, 6], 'type': 'INGR'},
#    {'name': '飯料理', 'span': [13, 16], 'type': 'TYPE'}]},
#  {'text': '岡山県の、秋に食べられるきすを使ったお米料理を探して頂けませんか？',
#   'entities': [{'name': '岡山県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '秋', 'span': [5, 6], 'type': 'SZN'},
#    {'name': 'きす', 'span': [12, 14], 'type': 'INGR'},
#    {'name': 'お米料理', 'span': [18, 22], 'type': 'TYPE'}]},
#  {'text': '岩手県の、通年に食べられる鮭を使った飯料理が、あったら教えて下さい',
#   'entities': [{'name': '岩手県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '通年', 'span': [5, 7], 'type': 'SZN'},
#    {'name': '鮭', 'span': [13, 14], 'type': 'INGR'},
#    {'name': '飯料理', 'span': [18, 21], 'type': 'TYPE'}]},
#  {'text': '岐阜の夏に食べられるいのしし肉を使用した魚料理について、検索して？',
#   'entities': [{'name': '岐阜', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '夏', 'span': [3, 4], 'type': 'SZN'},
#    {'name': 'いのしし肉', 'span': [10, 15], 'type': 'INGR'},
#    {'name': '魚料理', 'span': [20, 23], 'type': 'TYPE'}]},
#  {'text': '山梨の通年に食べられる酢を使用したお野菜料理はある？',
#   'entities': [{'name': '山梨', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '通年', 'span': [3, 5], 'type': 'SZN'},
#    {'name': '酢', 'span': [11, 12], 'type': 'INGR'},
#    {'name': 'お野菜料理', 'span': [17, 22], 'type': 'TYPE'}]},
#  {'text': '和歌山県の夏に食べられるあおねぎが使われている肉系についてご存じであれば、教えて頂きたいです',
#   'entities': [{'name': '和歌山県', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '夏', 'span': [5, 6], 'type': 'SZN'},
#    {'name': 'あおねぎ', 'span': [12, 16], 'type': 'INGR'},
#    {'name': '肉系', 'span': [23, 25], 'type': 'TYPE'}]},
#  {'text': '広島県の冬に食べられるハマグリが使われている飯料理が、あったら調べて頂きたいです',
#   'entities': [{'name': '広島県', 'span': [0, 3], 'type': 'AREA'},
#    {'name': '冬', 'span': [4, 5], 'type': 'SZN'},
#    {'name': 'ハマグリ', 'span': [11, 15], 'type': 'INGR'},
#    {'name': '飯料理', 'span': [22, 25], 'type': 'TYPE'}]},
#  {'text': '高知と山口の秋に食べられている、サトイモを使った肉料理をご存じであれば探して欲しいです。',
#   'entities': [{'name': '高知', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '山口', 'span': [3, 5], 'type': 'AREA'},
#    {'name': '秋', 'span': [6, 7], 'type': 'SZN'},
#    {'name': 'サトイモ', 'span': [16, 20], 'type': 'INGR'},
#    {'name': '肉料理', 'span': [24, 27], 'type': 'TYPE'}]},
#  {'text': '近畿地方と北海道の春に食べられている、さめを使ったお肉料理があったら、調べてくれませんか？',
#   'entities': [{'name': '近畿地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '北海道', 'span': [5, 8], 'type': 'AREA'},
#    {'name': '春', 'span': [9, 10], 'type': 'SZN'},
#    {'name': 'さめ', 'span': [19, 21], 'type': 'INGR'},
#    {'name': 'お肉料理', 'span': [25, 29], 'type': 'TYPE'}]},
#  {'text': '岩手あるいは北関東地方の、通年に食べられている米を使用した米系を、知ってたら、探して？',
#   'entities': [{'name': '岩手', 'span': [0, 2], 'type': 'AREA'},
#    {'name': '北関東地方', 'span': [6, 11], 'type': 'AREA'},
#    {'name': '通年', 'span': [13, 15], 'type': 'SZN'},
#    {'name': '米', 'span': [23, 24], 'type': 'INGR'},
#    {'name': '米系', 'span': [29, 31], 'type': 'TYPE'}]},
#  {'text': '関西地方あるいは四国地方の、秋に食べられているしいらを使用した魚料理があったら、検索。',
#   'entities': [{'name': '関西地方', 'span': [0, 4], 'type': 'AREA'},
#    {'name': '四国地方', 'span': [8, 12], 'type': 'AREA'},
#    {'name': '秋', 'span': [14, 15], 'type': 'SZN'},
#    {'name': 'しいら', 'span': [23, 26], 'type': 'INGR'},
#    {'name': '魚料理', 'span': [31, 34], 'type': 'TYPE'}]},
#  ...]
